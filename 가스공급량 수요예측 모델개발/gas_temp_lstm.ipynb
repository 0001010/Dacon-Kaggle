# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

total = pd.read_csv('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/train.csv', encoding = 'cp949')
total.head()
# Out:
#           연월일  시간 구분       공급량
# 0  2013-01-01   1  A  2497.129
# 1  2013-01-01   2  A  2363.265
# 2  2013-01-01   3  A  2258.505
# 3  2013-01-01   4  A  2243.969
# 4  2013-01-01   5  A  2344.105

# %%
total['구분'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'G', 'H'], dtype=object)

# %%
d_map = dict()
for i, d in enumerate(total['구분'].unique()):
  d_map[d] = i
# 라벨 인코딩

total['구분'] = total['구분'].map(d_map)

total
# Out:
#                연월일  시간  구분       공급량
# 0       2013-01-01   1   0  2497.129
# 1       2013-01-01   2   0  2363.265
# 2       2013-01-01   3   0  2258.505
# 3       2013-01-01   4   0  2243.969
# 4       2013-01-01   5   0  2344.105
# ...            ...  ..  ..       ...
# 368083  2018-12-31  20   6   681.033
# 368084  2018-12-31  21   6   669.961
# 368085  2018-12-31  22   6   657.941
# 368086  2018-12-31  23   6   610.953
# 368087  2018-12-31  24   6   560.896
#
# [368088 rows x 4 columns]

# %%
total[total['공급량']==total['공급량'].min()]['연월일'].unique()
#total.iloc[2229:]

# 이슈
# min값이 수상함 이거 수정하고 이상치 값 수정
# 13년 8월 -> 14,15,16,17년의 평균값으로 대치
# max값은 음.. 이것도 하나하나찔러보자
# 아니면 isolation forest 돌리는데 이것도 문제있으면 좀...
# 바로 수작업
# Out:
# array(['2013-08-12', '2013-08-13', '2013-08-14', '2013-08-15',
#        '2013-08-16', '2013-08-17', '2013-08-18', '2013-08-19',
#        '2013-08-20', '2013-08-21', '2013-08-22', '2013-08-23',
#        '2013-08-24', '2013-08-25', '2013-08-26', '2013-08-27',
#        '2013-08-28', '2013-08-29', '2013-08-30', '2013-08-31',
#        '2013-09-01', '2013-09-02', '2014-04-21', '2014-04-22',
#        '2014-04-23', '2014-04-24', '2014-04-25', '2014-04-26',
#        '2014-04-27', '2014-04-28', '2014-04-29', '2014-04-30',
#        '2014-05-01', '2014-05-02', '2014-05-03', '2014-05-04',
#        '2014-05-05', '2014-05-06', '2014-05-07', '2014-05-08',
#        '2014-12-09', '2014-12-10', '2014-12-11', '2015-05-12',
#        '2015-05-13', '2015-05-14', '2015-05-15', '2015-05-16',
#        '2015-05-17', '2015-05-18', '2015-05-19', '2015-05-20',
#        '2015-05-21', '2015-05-22', '2015-05-23', '2015-05-24',
#        '2015-05-25', '2015-05-26', '2015-05-27', '2015-05-28',
#        '2016-05-09', '2016-05-10', '2016-05-11', '2016-05-12',
#        '2016-05-13', '2016-05-14', '2016-05-15', '2016-05-16',
#        '2016-05-17', '2016-05-18', '2016-05-19', '2016-05-20',
#        '2016-05-21', '2016-05-22', '2016-05-23', '2016-08-11',
#        '2016-08-12', '2017-06-15', '2017-06-16', '2017-06-20',
#        '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-24',
#        '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28',
#        '2017-06-29', '2017-06-30'], dtype=object)

# %%
total['연월일'] = pd.to_datetime(total['연월일'])

total['year'] = total['연월일'].dt.year
total['month'] = total['연월일'].dt.month
total['day'] = total['연월일'].dt.day
total['weekday'] = total['연월일'].dt.weekday

# %%
f, ax = plt.subplots(figsize = (6,3))
total['공급량'].plot()

# %% [markdown]
# - 시계열 데이터라 그런지 뭔가 일정한 패턴이 있어보인다.

# %%
import os

os.chdir('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발')

for lists in os.listdir():
  if lists[5:9]=='2013' or lists[5:9]=='2014' or lists[5:9]=='2015' or lists[5:9]=='2016' or lists[5:9]=='2017' or lists[5:9]=='2018' or lists[5:9]=='2019':
    datas = pd.read_csv(lists, encoding = 'euc-kr')
    datas = datas[['기온(°C)', '풍속(m/s)','강수량(mm)', '적설(cm)']]

    globals()['temp_{}'.format(lists[5:9])] = datas

total_temp = pd.DataFrame()
temp = [temp_2013, temp_2014, temp_2015, temp_2016, temp_2017, temp_2018]

# 시계열 결측치 보간
# 기온은 value값으로 보간 사용
# 나머지 것들은 측정되지 않은 값이므로 0으로 채워도 상관없을듯함
for i in temp:
  i['기온(°C)'] = i['기온(°C)'].interpolate(method = 'values')
  i = i.fillna(0)
  total_temp = pd.concat([total_temp, i])

for i in range(7):
  globals()['total_gu_{}'.format(i)] = total[total['구분']==i]
lists = [total_gu_0, total_gu_1, total_gu_2, total_gu_3, total_gu_4, total_gu_5, total_gu_6]

total_temps = pd.DataFrame()

for j in lists:
  s = pd.concat([j.reset_index(drop = True), total_temp.reset_index(drop = True)], axis = 1)
  total_temps = pd.concat([total_temps.reset_index(drop = True), s.reset_index(drop = True)], axis = 0)


# 날씨 부분에 null값이 있어서 그것을 먼저 해결
# 기온 부분만 해결하고 나머지 부분은 없는부분이니 0으로 채워도 무방할듯함

# %%
total_temps.isnull().sum()
# Out:
# 연월일        0
# 시간         0
# 구분         0
# 공급량        0
# year       0
# month      0
# day        0
# weekday    0
# 기온(°C)     0
# 풍속(m/s)    0
# 강수량(mm)    0
# 적설(cm)     0
# dtype: int64

# %%
train_years = [2013, 2014, 2015, 2016, 2017]
val_years = [2018] # 시계열 데이터이므로 2018년 1년치의 데이터를 예측, test data set에는 2019년 데이터를 예측

train = total_temps[total_temps['year'].isin(train_years)]
val = total_temps[total_temps['year'].isin(val_years)]

# %%
print('초과 이상치 ',train[train['공급량']>=7000]['구분'].unique())
print('미만 이상치 ',train[train['공급량']<=3]['구분'].unique())
# 이상치 값을 추출하고 평년 공급량으로 맞출예정
# Out:
# 초과 이상치  [0 5]
# 미만 이상치  [2 6]

# %%
print('미만 이상치_val', val[val['공급량']<=3]['구분'].unique())
# Out:
# 미만 이상치_val [2]

# %% [markdown]
# 구분에 2번 공급처는 건드리면 안될거같고 <br>
# 나머지 것들만 정리를 해보겠다.

# %%
outlier_index = train[train['공급량']>=7000].index
train.iloc[outlier_index]
# Out:
#              연월일  시간  구분        공급량  year  month  day  weekday  기온(°C)  \
# 2230  2013-04-03  23   0  11593.617  2013      4    3        2     7.3
# 623   2013-01-26  24   6    616.988  2013      1   26        5    -9.3
# 16367 2014-11-13  24   6    375.476  2014     11   13        3    -1.0
# 25285 2015-11-20  14   6    206.244  2015     11   20        4    12.3
# 35929 2017-02-06   2   6    322.980  2017      2    6        0    -1.8
#
#        풍속(m/s)  강수량(mm)  적설(cm)
# 2230       2.8      0.0     0.0
# 623        2.3      0.0     0.0
# 16367      0.9      0.0     0.0
# 25285      1.9      0.0     0.0
# 35929      2.9      0.0     0.0

# %%
train.replace(train.iloc[outlier_index[0]]['공급량'], train.query("month==4 and day==3 and year!=2013 and 시간==23 and 구분==0")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[1]]['공급량'], train.query("month==1 and day==27 and year!=2013 and 시간==24 and 구분==5")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[2]]['공급량'], train.query("month==11 and day==14 and year!=2014 and 시간==24 and 구분==5")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[3]]['공급량'], train.query("month==11 and day==21 and year!=2015 and 시간==14 and 구분==5")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[4]]['공급량'], train.query("month==2 and day==7 and year!=2017 and 시간==2 and 구분==5")['공급량'].mean(),inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
def outliter_fill(num, data):
  if num>=1000:
    outlier_index = data[data['공급량']>=num].index
  else:
    outlier_index = data[data['공급량']<=num].index

  df = data.iloc[outlier_index]

  for number in range(len(outlier_index)):
    s = data.iloc[outlier_index[i]]
    data.replace(s['공급량'], data.query("month==" + str(s['month'] + 
                                                      " and day==" + str(s['day']) + 
                                                      " and year!=" + str(s['year']) + 
                                                      " and 시간==" + str(s['시간']) + 
                                                      " and 구분==" + str(s['구분'])['공급량'].mean(), inplace = True)))

  return s

# %%
train[train['구분']==0][['공급량']].reset_index(drop = True).plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44553 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Isolation Forest

"""total[total['구분']==0]

from sklearn.ensemble import IsolationForest

outliers = []
isolation_forest =  IsolationForest(contamination = 0.004)
for i in range(7):
  isolation_forest.fit(total[total['구분']==i][['공급량']])
  outliers.append(isolation_forest.predict(total[['공급량']]))
"""
# Out:
# "total[total['구분']==0]\n\nfrom sklearn.ensemble import IsolationForest\n\noutliers = []\nisolation_forest =  IsolationForest(contamination = 0.004)\nfor i in range(7):\n  isolation_forest.fit(total[total['구분']==i][['공급량']])\n  outliers.append(isolation_forest.predict(total[['공급량']]))\n"

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

scaler_num = ['scaler_0','scaler_1','scaler_2','scaler_3','scaler_4','scaler_5','scaler_6']

for i in range(7):
  #scaler = MinMaxScaler()
  
  scaler_num[i] = MinMaxScaler()
  globals()['train_{}'.format(i)] = scaler_num[i].fit_transform(train[train['구분']==i][['공급량','기온(°C)', '풍속(m/s)', '강수량(mm)','적설(cm)']].reset_index(drop = True))
  globals()['val_{}'.format(i)] = scaler_num[i].transform(val[val['구분']==i][['공급량','기온(°C)', '풍속(m/s)', '강수량(mm)','적설(cm)']].reset_index(drop = True))
  

print(train_0.shape, val_0.shape)
# Out:
# (43824, 5) (8760, 5)

# %%
scaler_num[0].inverse_transform(train_0)
# Out:
# array([[ 2.497129e+03, -8.300000e+00,  3.600000e+00,  0.000000e+00,
#          6.400000e+00],
#        [ 2.363265e+03, -8.500000e+00,  4.000000e+00,  0.000000e+00,
#          6.400000e+00],
#        [ 2.258505e+03, -8.400000e+00,  4.000000e+00,  0.000000e+00,
#          6.400000e+00],
#        ...,
#        [ 2.054192e+03, -1.600000e+00,  1.000000e+00,  0.000000e+00,
#          0.000000e+00],
#        [ 1.981397e+03, -2.100000e+00,  1.700000e+00,  0.000000e+00,
#          0.000000e+00],
#        [ 1.897268e+03, -2.600000e+00,  6.000000e-01,  0.000000e+00,
#          0.000000e+00]])

# %% [markdown]
# - 딥러닝을 사용할 예정이라서 전체 데이터를 전부 넣어도 무방하지만 모델을 더 돌려보자는 취지에서 각 구분별로 모델정의 즉, 7개의 모델을 생성예정
# - 그에 따라 스케일러도 7개 생성

# %%
def create_dataset (X, look_back = 1):
    Xs, ys, rem_data = [], [], []
 
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back][0])
        rem_data.append(X[i+look_back][1:])
 
    return np.array(Xs), np.array(ys), np.array(rem_data)

LOOK_BACK = 24

x_train_0, y_train_0, re_y_train_0 = create_dataset(train_0, LOOK_BACK)
x_val_0, y_val_0, re_y_val_0 = create_dataset(val_0, LOOK_BACK)

#################################################################

x_train_1, y_train_1, re_y_train_1 = create_dataset(train_1, LOOK_BACK)
x_val_1, y_val_1, re_y_val_1 = create_dataset(val_1, LOOK_BACK)

#################################################################

x_train_2, y_train_2, re_y_train_2 = create_dataset(train_2, LOOK_BACK)
x_val_2, y_val_2, re_y_val_2 = create_dataset(val_2, LOOK_BACK)

#################################################################

x_train_3, y_train_3, re_y_train_3 = create_dataset(train_3, LOOK_BACK)
x_val_3, y_val_3, re_y_val_3 = create_dataset(val_3, LOOK_BACK)

#################################################################

x_train_4, y_train_4, re_y_train_4 = create_dataset(train_4, LOOK_BACK)
x_val_4, y_val_4, re_y_val_4 = create_dataset(val_4, LOOK_BACK)

#################################################################

x_train_5, y_train_5, re_y_train_5 = create_dataset(train_5, LOOK_BACK)
x_val_5, y_val_5, re_y_val_5 = create_dataset(val_5, LOOK_BACK)

#################################################################

x_train_6, y_train_6, re_y_train_6 = create_dataset(train_6, LOOK_BACK)
x_val_6, y_val_6, re_y_val_6 = create_dataset(val_6, LOOK_BACK)

# %% [markdown]
# - LOOKBACK을 24로 정하고(시간단위 데이터인데 24시간마다 어떠한 주기가 나타날 것이라고 추측) 데이터변형

# %%
from tensorflow.python.keras.callbacks import History
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping


def create_bilstm(units, x_train):
  inputs = Input(shape = (x_train.shape[1], x_train.shape[2]))
  hidden1 = Bidirectional(LSTM(units = units, return_sequences=True))(inputs)
  hidden2 = Bidirectional(LSTM(units = units))(hidden1)
  output = Dense(1)(hidden2)
  model = Model(inputs = inputs, outputs = output)
  model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_error'])

  return model

def create_gru(units, x_train):
  inputs = Input(shape = (x_train.shape[1], x_train.shape[2]))
  hidden1 = GRU(units = units, return_sequences=True)(inputs)
  hidden2 = GRU(units = units)(hidden1)
  output = Dense(1)(hidden2)
  model = Model(inputs = inputs, outputs = output)
  model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_percentage_error'])

  return model


def fit_model(model,x_train, y_train, epoch, x_val,y_val):
  early_stop = EarlyStopping(monitor = 'val_loss',
                             patience = 7)
  
  history = model.fit(x_train, y_train, 
                      epochs = epoch, 
                      validation_data = (x_val, y_val),
                      batch_size = 64,
                      shuffle = False,
                      callbacks = [early_stop])
  return history

# %% [markdown]
# - 양방향 LSTM, GRU를 비교할 예정

# %%
from sklearn.metrics import mean_squared_error

def mape(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 


# train_0 학습
model_lstm_0 = create_bilstm(64, x_train_0)
history_lstm_0 = fit_model(model_lstm_0, x_train_0, y_train_0, 50, x_val_0, y_val_0)


pred_lstm_0 = model_lstm_0.predict(x_val_0) # 2018년 예측
re_y_val_0 = np.insert(re_y_val_0, 0, pred_lstm_0.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_0 = scaler_num[0].inverse_transform(re_y_val_0) # inverse transform


re_y_val_0 = np.delete(re_y_val_0,0,1)
re_y_val_0 = np.insert(re_y_val_0, 0, y_val_0.T, axis = 1)

y_val_0 = scaler_num[0].inverse_transform(re_y_val_0)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_0.T[0], y_val_0.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_0.T[0],  y_val_0.T[0])))
# Out:
# Epoch 1/50
# 685/685 [==============================] - 63s 70ms/step - loss: 0.0047 - mean_absolute_error: 0.0450 - val_loss: 0.0021 - val_mean_absolute_error: 0.0406
# Epoch 2/50
# 685/685 [==============================] - 44s 64ms/step - loss: 8.1684e-04 - mean_absolute_error: 0.0204 - val_loss: 9.6644e-04 - val_mean_absolute_error: 0.0245
# Epoch 3/50
# 685/685 [==============================] - 45s 66ms/step - loss: 6.6093e-04 - mean_absolute_error: 0.0183 - val_loss: 9.3022e-04 - val_mean_absolute_error: 0.0250
# Epoch 4/50
# 685/685 [==============================] - 43s 62ms/step - loss: 5.8469e-04 - mean_absolute_error: 0.0172 - val_loss: 7.7223e-04 - val_mean_absolute_error: 0.0223
# Epoch 5/50
# 685/685 [==============================] - 43s 62ms/step - loss: 5.4221e-04 - mean_absolute_error: 0.0166 - val_loss: 6.2366e-04 - val_mean_absolute_error: 0.0189
# Epoch 6/50
# 685/685 [==============================] - 43s 63ms/step - loss: 4.9568e-04 - mean_absolute_error: 0.0158 - val_loss: 5.3986e-04 - val_mean_absolute_error: 0.0171
# Epoch 7/50
# 685/685 [==============================] - 51s 74ms/step - loss: 4.5040e-04 - mean_absolute_error: 0.0150 - val_loss: 4.6750e-04 - val_mean_absolute_error: 0.0156
# Epoch 8/50
# 685/685 [==============================] - 46s 67ms/step - loss: 4.1079e-04 - mean_absolute_error: 0.0143 - val_loss: 4.1512e-04 - val_mean_absolute_error: 0.0147
# Epoch 9/50
# 685/685 [==============================] - 45s 66ms/step - loss: 3.7858e-04 - mean_absolute_error: 0.0137 - val_loss: 3.8103e-04 - val_mean_absolute_error: 0.0142
# Epoch 10/50
# 685/685 [==============================] - 49s 72ms/step - loss: 3.5426e-04 - mean_absolute_error: 0.0131 - val_loss: 3.7833e-04 - val_mean_absolute_error: 0.0145
# Epoch 11/50
# 685/685 [==============================] - 44s 64ms/step - loss: 3.3753e-04 - mean_absolute_error: 0.0128 - val_loss: 4.1610e-04 - val_mean_absolute_error: 0.0161
# Epoch 12/50
# 685/685 [==============================] - 49s 71ms/step - loss: 3.2743e-04 - mean_absolute_error: 0.0125 - val_loss: 4.7429e-04 - val_mean_absolute_error: 0.0176
# Epoch 13/50
# 685/685 [==============================] - 46s 67ms/step - loss: 3.2056e-04 - mean_absolute_error: 0.0123 - val_loss: 5.4752e-04 - val_mean_absolute_error: 0.0189
# Epoch 14/50
# 685/685 [==============================] - 45s 66ms/step - loss: 3.1684e-04 - mean_absolute_error: 0.0123 - val_loss: 5.6337e-04 - val_mean_absolute_error: 0.0191
# Epoch 15/50
# 685/685 [==============================] - 45s 66ms/step - loss: 3.1068e-04 - mean_absolute_error: 0.0121 - val_loss: 5.6960e-04 - val_mean_absolute_error: 0.0192
# Epoch 16/50
# 685/685 [==============================] - 45s 66ms/step - loss: 3.0161e-04 - mean_absolute_error: 0.0120 - val_loss: 5.9876e-04 - val_mean_absolute_error: 0.0198
# Epoch 17/50
# 685/685 [==============================] - 44s 64ms/step - loss: 2.9531e-04 - mean_absolute_error: 0.0118 - val_loss: 6.1009e-04 - val_mean_absolute_error: 0.0202
# LSTM의 RMSE : 95.69264349196024
#  LSTM의 MAPE : 8.472068588275938

# %%
def loss_vis(history, model_name):
  f, ax = plt.subplots(figsize = (6, 3))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend(['Train_Loss', 'Val_Loss'])
  plt.title(model_name)

loss_vis(history_lstm_0, 'Bi_LSTM')

# %%
def pred_vis(pred_model, model_name, y_val):
  f, ax = plt.subplots(figsize = (15,8))
  plt.plot(pred_model, label = 'Prediction',  alpha = 0.5)
  plt.plot(y_val, label = 'Val_data',  alpha = 0.3)
  plt.xlabel('Time')
  plt.ylabel('Value')
  plt.legend()
  plt.title(model_name)

# %%
# train_1 학습
model_1 = create_bilstm(64, x_train_1)
history_lstm_1 = fit_model(model_1, x_train_1, y_train_1, 70, x_val_1, y_val_1)
print('-'*150)

pred_lstm_1 = model_1.predict(x_val_1) # 2018년 예측
re_y_val_1 = np.insert(re_y_val_1, 0, pred_lstm_1.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_1 = scaler_num[1].inverse_transform(re_y_val_1) # inverse transform


re_y_val_1 = np.delete(re_y_val_1,0,1)
re_y_val_1 = np.insert(re_y_val_1, 0, y_val_1.T, axis = 1)

y_val_1 = scaler_num[1].inverse_transform(re_y_val_1)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_1.T[0], y_val_1.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_1.T[0],  y_val_1.T[0])))
print('-'*150)

# train_2 학습
model_2 = create_bilstm(64, x_train_2)
history_lstm_2 = fit_model(model_2, x_train_2, y_train_2, 70, x_val_2, y_val_2)
print('-'*150)

pred_lstm_2 = model_2.predict(x_val_2) # 2018년 예측
re_y_val_2 = np.insert(re_y_val_2, 0, pred_lstm_2.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_2 = scaler_num[2].inverse_transform(re_y_val_2) # inverse transform


re_y_val_2 = np.delete(re_y_val_2,0,1)
re_y_val_2 = np.insert(re_y_val_2, 0, y_val_2.T, axis = 1)

y_val_2 = scaler_num[2].inverse_transform(re_y_val_2)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_2.T[0], y_val_2.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_2.T[0],  y_val_2.T[0])))
print('-'*150)

# train_3 학습
model_3 = create_bilstm(64, x_train_3)
history_lstm_3 = fit_model(model_3, x_train_3, y_train_3, 70, x_val_3, y_val_3)
print('-'*150)

pred_lstm_3 = model_3.predict(x_val_3) # 2018년 예측
re_y_val_3 = np.insert(re_y_val_3, 0, pred_lstm_3.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_3 = scaler_num[3].inverse_transform(re_y_val_3) # inverse transform


re_y_val_3 = np.delete(re_y_val_3,0,1)
re_y_val_3 = np.insert(re_y_val_3, 0, y_val_3.T, axis = 1)

y_val_3 = scaler_num[3].inverse_transform(re_y_val_3)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_3.T[0], y_val_3.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_3.T[0],  y_val_3.T[0])))
print('-'*150)
# Out:
# Epoch 1/70
# 685/685 [==============================] - 61s 68ms/step - loss: 0.0044 - mean_absolute_error: 0.0420 - val_loss: 0.0021 - val_mean_absolute_error: 0.0385
# Epoch 2/70
# 685/685 [==============================] - 51s 75ms/step - loss: 9.1337e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0015 - val_mean_absolute_error: 0.0329
# Epoch 3/70
# 685/685 [==============================] - 44s 64ms/step - loss: 6.7194e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0017 - val_mean_absolute_error: 0.0359
# Epoch 4/70
# 685/685 [==============================] - 45s 65ms/step - loss: 6.3383e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0015 - val_mean_absolute_error: 0.0335
# Epoch 5/70
# 685/685 [==============================] - 44s 65ms/step - loss: 5.8104e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0013 - val_mean_absolute_error: 0.0320
# Epoch 6/70
# 685/685 [==============================] - 46s 67ms/step - loss: 5.3763e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0012 - val_mean_absolute_error: 0.0301
# Epoch 7/70
# 685/685 [==============================] - 47s 69ms/step - loss: 5.1202e-04 - mean_absolute_error: 0.0150 - val_loss: 9.7515e-04 - val_mean_absolute_error: 0.0268
# Epoch 8/70
# 685/685 [==============================] - 45s 66ms/step - loss: 4.9914e-04 - mean_absolute_error: 0.0147 - val_loss: 7.3645e-04 - val_mean_absolute_error: 0.0226
# Epoch 9/70
# 685/685 [==============================] - 46s 67ms/step - loss: 4.8872e-04 - mean_absolute_error: 0.0145 - val_loss: 5.9121e-04 - val_mean_absolute_error: 0.0197
# Epoch 10/70
# 685/685 [==============================] - 47s 69ms/step - loss: 4.7609e-04 - mean_absolute_error: 0.0143 - val_loss: 5.2874e-04 - val_mean_absolute_error: 0.0184
# Epoch 11/70
# 685/685 [==============================] - 47s 68ms/step - loss: 4.5194e-04 - mean_absolute_error: 0.0139 - val_loss: 6.0167e-04 - val_mean_absolute_error: 0.0196
# Epoch 12/70
# 685/685 [==============================] - 46s 67ms/step - loss: 4.2576e-04 - mean_absolute_error: 0.0135 - val_loss: 6.9710e-04 - val_mean_absolute_error: 0.0212
# Epoch 13/70
# 685/685 [==============================] - 46s 66ms/step - loss: 4.0745e-04 - mean_absolute_error: 0.0131 - val_loss: 7.6017e-04 - val_mean_absolute_error: 0.0223
# Epoch 14/70
# 685/685 [==============================] - 46s 67ms/step - loss: 3.9374e-04 - mean_absolute_error: 0.0129 - val_loss: 7.2073e-04 - val_mean_absolute_error: 0.0219
# Epoch 15/70
# 685/685 [==============================] - 46s 67ms/step - loss: 3.8286e-04 - mean_absolute_error: 0.0127 - val_loss: 6.6401e-04 - val_mean_absolute_error: 0.0213
# Epoch 16/70
# 685/685 [==============================] - 46s 67ms/step - loss: 3.7338e-04 - mean_absolute_error: 0.0125 - val_loss: 6.2271e-04 - val_mean_absolute_error: 0.0208
# Epoch 17/70
# 685/685 [==============================] - 45s 66ms/step - loss: 3.6425e-04 - mean_absolute_error: 0.0124 - val_loss: 5.9504e-04 - val_mean_absolute_error: 0.0205
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 91.0031599213162
#  LSTM의 MAPE : 11.461201312704954
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/70
# 685/685 [==============================] - 56s 70ms/step - loss: 0.0079 - mean_absolute_error: 0.0559 - val_loss: 0.0048 - val_mean_absolute_error: 0.0610
# Epoch 2/70
# 685/685 [==============================] - 46s 67ms/step - loss: 0.0017 - mean_absolute_error: 0.0289 - val_loss: 0.0028 - val_mean_absolute_error: 0.0463
# Epoch 3/70
# 685/685 [==============================] - 46s 67ms/step - loss: 9.1343e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0016 - val_mean_absolute_error: 0.0359
# Epoch 4/70
# 685/685 [==============================] - 46s 67ms/step - loss: 7.6698e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0014 - val_mean_absolute_error: 0.0329
# Epoch 5/70
# 685/685 [==============================] - 46s 67ms/step - loss: 6.8644e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0012 - val_mean_absolute_error: 0.0311
# Epoch 6/70
# 685/685 [==============================] - 46s 67ms/step - loss: 6.2232e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0011 - val_mean_absolute_error: 0.0292
# Epoch 7/70
# 685/685 [==============================] - 45s 66ms/step - loss: 5.6219e-04 - mean_absolute_error: 0.0165 - val_loss: 9.6882e-04 - val_mean_absolute_error: 0.0272
# Epoch 8/70
# 685/685 [==============================] - 45s 65ms/step - loss: 5.0885e-04 - mean_absolute_error: 0.0157 - val_loss: 8.5427e-04 - val_mean_absolute_error: 0.0253
# Epoch 9/70
# 685/685 [==============================] - 45s 65ms/step - loss: 4.6540e-04 - mean_absolute_error: 0.0150 - val_loss: 7.6310e-04 - val_mean_absolute_error: 0.0237
# Epoch 10/70
# 685/685 [==============================] - 45s 66ms/step - loss: 4.3147e-04 - mean_absolute_error: 0.0144 - val_loss: 6.9593e-04 - val_mean_absolute_error: 0.0224
# Epoch 11/70
# 685/685 [==============================] - 48s 70ms/step - loss: 4.0646e-04 - mean_absolute_error: 0.0140 - val_loss: 6.5601e-04 - val_mean_absolute_error: 0.0215
# Epoch 12/70
# 685/685 [==============================] - 49s 72ms/step - loss: 3.8968e-04 - mean_absolute_error: 0.0138 - val_loss: 6.3772e-04 - val_mean_absolute_error: 0.0211
# Epoch 13/70
# 685/685 [==============================] - 46s 67ms/step - loss: 3.7777e-04 - mean_absolute_error: 0.0136 - val_loss: 6.2518e-04 - val_mean_absolute_error: 0.0207
# Epoch 14/70
# 685/685 [==============================] - 45s 66ms/step - loss: 3.6818e-04 - mean_absolute_error: 0.0134 - val_loss: 6.2719e-04 - val_mean_absolute_error: 0.0207
# Epoch 15/70
# 685/685 [==============================] - 45s 66ms/step - loss: 3.6053e-04 - mean_absolute_error: 0.0133 - val_loss: 6.2388e-04 - val_mean_absolute_error: 0.0205
# Epoch 16/70
# 685/685 [==============================] - 45s 66ms/step - loss: 3.4961e-04 - mean_absolute_error: 0.0130 - val_loss: 6.1772e-04 - val_mean_absolute_error: 0.0202
# Epoch 17/70
# 685/685 [==============================] - 45s 66ms/step - loss: 3.4174e-04 - mean_absolute_error: 0.0129 - val_loss: 6.2859e-04 - val_mean_absolute_error: 0.0204
# Epoch 18/70
# 685/685 [==============================] - 45s 65ms/step - loss: 3.2941e-04 - mean_absolute_error: 0.0126 - val_loss: 6.0208e-04 - val_mean_absolute_error: 0.0197
# Epoch 19/70
# 685/685 [==============================] - 44s 65ms/step - loss: 3.2504e-04 - mean_absolute_error: 0.0126 - val_loss: 6.4882e-04 - val_mean_absolute_error: 0.0207
# Epoch 20/70
# 685/685 [==============================] - 46s 67ms/step - loss: 3.1341e-04 - mean_absolute_error: 0.0123 - val_loss: 5.7511e-04 - val_mean_absolute_error: 0.0196
# Epoch 21/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.9025e-04 - mean_absolute_error: 0.0118 - val_loss: 5.6826e-04 - val_mean_absolute_error: 0.0195
# Epoch 22/70
# 685/685 [==============================] - 44s 65ms/step - loss: 2.6864e-04 - mean_absolute_error: 0.0115 - val_loss: 4.6854e-04 - val_mean_absolute_error: 0.0167
# Epoch 23/70
# 685/685 [==============================] - 44s 65ms/step - loss: 2.6183e-04 - mean_absolute_error: 0.0114 - val_loss: 4.4247e-04 - val_mean_absolute_error: 0.0161
# Epoch 24/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.5423e-04 - mean_absolute_error: 0.0112 - val_loss: 4.3988e-04 - val_mean_absolute_error: 0.0163
# Epoch 25/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.5260e-04 - mean_absolute_error: 0.0111 - val_loss: 6.4382e-04 - val_mean_absolute_error: 0.0209
# Epoch 26/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.5347e-04 - mean_absolute_error: 0.0111 - val_loss: 6.3851e-04 - val_mean_absolute_error: 0.0191
# Epoch 27/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.4844e-04 - mean_absolute_error: 0.0110 - val_loss: 7.6721e-04 - val_mean_absolute_error: 0.0219
# Epoch 28/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.4825e-04 - mean_absolute_error: 0.0110 - val_loss: 8.0916e-04 - val_mean_absolute_error: 0.0222
# Epoch 29/70
# 685/685 [==============================] - 45s 65ms/step - loss: 2.3815e-04 - mean_absolute_error: 0.0107 - val_loss: 8.6853e-04 - val_mean_absolute_error: 0.0230
# Epoch 30/70
# 685/685 [==============================] - 47s 69ms/step - loss: 2.3629e-04 - mean_absolute_error: 0.0107 - val_loss: 8.4930e-04 - val_mean_absolute_error: 0.0229
# Epoch 31/70
# 685/685 [==============================] - 47s 69ms/step - loss: 2.3737e-04 - mean_absolute_error: 0.0106 - val_loss: 9.1357e-04 - val_mean_absolute_error: 0.0243
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 9.744619746849946
#  LSTM의 MAPE : 11.95231495065366
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/70
# 685/685 [==============================] - 58s 74ms/step - loss: 0.0037 - mean_absolute_error: 0.0397 - val_loss: 0.0055 - val_mean_absolute_error: 0.0664
# Epoch 2/70
# 685/685 [==============================] - 48s 70ms/step - loss: 0.0011 - mean_absolute_error: 0.0226 - val_loss: 0.0012 - val_mean_absolute_error: 0.0294
# Epoch 3/70
# 685/685 [==============================] - 49s 71ms/step - loss: 6.9955e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0014 - val_mean_absolute_error: 0.0312
# Epoch 4/70
# 685/685 [==============================] - 46s 67ms/step - loss: 6.5804e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0014 - val_mean_absolute_error: 0.0310
# Epoch 5/70
# 685/685 [==============================] - 45s 66ms/step - loss: 6.2343e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 6/70
# 685/685 [==============================] - 46s 68ms/step - loss: 5.8146e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 7/70
# 685/685 [==============================] - 48s 70ms/step - loss: 5.4146e-04 - mean_absolute_error: 0.0165 - val_loss: 8.9293e-04 - val_mean_absolute_error: 0.0244
# Epoch 8/70
# 685/685 [==============================] - 50s 74ms/step - loss: 5.0618e-04 - mean_absolute_error: 0.0160 - val_loss: 7.9661e-04 - val_mean_absolute_error: 0.0229
# Epoch 9/70
# 685/685 [==============================] - 48s 71ms/step - loss: 4.7543e-04 - mean_absolute_error: 0.0155 - val_loss: 7.1695e-04 - val_mean_absolute_error: 0.0215
# Epoch 10/70
# 685/685 [==============================] - 49s 72ms/step - loss: 4.4759e-04 - mean_absolute_error: 0.0150 - val_loss: 6.5108e-04 - val_mean_absolute_error: 0.0203
# Epoch 11/70
# 685/685 [==============================] - 50s 73ms/step - loss: 4.1762e-04 - mean_absolute_error: 0.0145 - val_loss: 5.9694e-04 - val_mean_absolute_error: 0.0194
# Epoch 12/70
# 685/685 [==============================] - 50s 73ms/step - loss: 3.8747e-04 - mean_absolute_error: 0.0138 - val_loss: 6.2517e-04 - val_mean_absolute_error: 0.0203
# Epoch 13/70
# 685/685 [==============================] - 50s 73ms/step - loss: 3.6089e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
# Epoch 14/70
# 685/685 [==============================] - 49s 71ms/step - loss: 3.5101e-04 - mean_absolute_error: 0.0131 - val_loss: 8.9144e-04 - val_mean_absolute_error: 0.0244
# Epoch 15/70
# 685/685 [==============================] - 49s 71ms/step - loss: 3.4451e-04 - mean_absolute_error: 0.0129 - val_loss: 9.5590e-04 - val_mean_absolute_error: 0.0246
# Epoch 16/70
# 685/685 [==============================] - 48s 70ms/step - loss: 3.3196e-04 - mean_absolute_error: 0.0127 - val_loss: 9.5546e-04 - val_mean_absolute_error: 0.0245
# Epoch 17/70
# 685/685 [==============================] - 48s 70ms/step - loss: 3.1713e-04 - mean_absolute_error: 0.0124 - val_loss: 9.3673e-04 - val_mean_absolute_error: 0.0228
# Epoch 18/70
# 685/685 [==============================] - 48s 71ms/step - loss: 2.9578e-04 - mean_absolute_error: 0.0120 - val_loss: 7.2912e-04 - val_mean_absolute_error: 0.0214
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 61.555582668258744
#  LSTM의 MAPE : 10.08294874860971
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# train_4 학습
model_4 = create_bilstm(64, x_train_4)
history_lstm_4 = fit_model(model_4, x_train_4, y_train_4, 50, x_val_4, y_val_4)

print('-'*150)
pred_lstm_4 = model_4.predict(x_val_4) # 2018년 예측
re_y_val_4 = np.insert(re_y_val_4, 0, pred_lstm_4.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_4 = scaler_num[4].inverse_transform(re_y_val_4) # inverse transform


re_y_val_4 = np.delete(re_y_val_4,0,1)
re_y_val_4 = np.insert(re_y_val_4, 0, y_val_4.T, axis = 1)

y_val_4 = scaler_num[4].inverse_transform(re_y_val_4)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_4.T[0], y_val_4.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_4.T[0],  y_val_4.T[0])))
print('-'*150)



# train_5 학습
model_5 = create_bilstm(64, x_train_5)
history_lstm_5 = fit_model(model_5, x_train_5, y_train_5, 50, x_val_5, y_val_5)

print('-'*150)
pred_lstm_5 = model_5.predict(x_val_5) # 2018년 예측
re_y_val_5 = np.insert(re_y_val_5, 0, pred_lstm_5.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_5 = scaler_num[5].inverse_transform(re_y_val_5) # inverse transform


re_y_val_5 = np.delete(re_y_val_5,0,1)
re_y_val_5 = np.insert(re_y_val_5, 0, y_val_5.T, axis = 1)

y_val_5 = scaler_num[5].inverse_transform(re_y_val_5)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_5.T[0], y_val_5.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_5.T[0],  y_val_5.T[0])))
print('-'*150)


# train_6 학습
model_6 = create_bilstm(64, x_train_6)
history_lstm_6 = fit_model(model_6, x_train_6, y_train_6, 50, x_val_6, y_val_6)
print('-'*150)

pred_lstm_6 = model_6.predict(x_val_6) # 2018년 예측
re_y_val_6 = np.insert(re_y_val_6, 0, pred_lstm_6.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_6 = scaler_num[6].inverse_transform(re_y_val_6) # inverse transform


re_y_val_6 = np.delete(re_y_val_6,0,1)
re_y_val_6 = np.insert(re_y_val_6, 0, y_val_6.T, axis = 1)

y_val_6 = scaler_num[6].inverse_transform(re_y_val_6)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_6.T[0], y_val_6.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_6.T[0],  y_val_6.T[0])))
print('-'*150)
# Out:
# Epoch 1/50
# 685/685 [==============================] - 64s 73ms/step - loss: 0.0081 - mean_absolute_error: 0.0581 - val_loss: 0.0318 - val_mean_absolute_error: 0.1602
# Epoch 2/50
# 685/685 [==============================] - 49s 71ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - val_loss: 0.0080 - val_mean_absolute_error: 0.0795
# Epoch 3/50
# 685/685 [==============================] - 48s 70ms/step - loss: 6.2455e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0049 - val_mean_absolute_error: 0.0616
# Epoch 4/50
# 685/685 [==============================] - 46s 68ms/step - loss: 5.6681e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0026 - val_mean_absolute_error: 0.0457
# Epoch 5/50
# 685/685 [==============================] - 46s 67ms/step - loss: 5.4780e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0017 - val_mean_absolute_error: 0.0356
# Epoch 6/50
# 685/685 [==============================] - 45s 66ms/step - loss: 5.1239e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0013 - val_mean_absolute_error: 0.0299
# Epoch 7/50
# 685/685 [==============================] - 48s 70ms/step - loss: 4.7673e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0011 - val_mean_absolute_error: 0.0272
# Epoch 8/50
# 685/685 [==============================] - 46s 68ms/step - loss: 4.4048e-04 - mean_absolute_error: 0.0148 - val_loss: 9.4248e-04 - val_mean_absolute_error: 0.0248
# Epoch 9/50
# 685/685 [==============================] - 46s 67ms/step - loss: 4.0055e-04 - mean_absolute_error: 0.0142 - val_loss: 8.2217e-04 - val_mean_absolute_error: 0.0230
# Epoch 10/50
# 685/685 [==============================] - 46s 67ms/step - loss: 3.5948e-04 - mean_absolute_error: 0.0135 - val_loss: 7.2964e-04 - val_mean_absolute_error: 0.0217
# Epoch 11/50
# 685/685 [==============================] - 45s 66ms/step - loss: 3.2372e-04 - mean_absolute_error: 0.0129 - val_loss: 7.1393e-04 - val_mean_absolute_error: 0.0222
# Epoch 12/50
# 685/685 [==============================] - 46s 67ms/step - loss: 3.0471e-04 - mean_absolute_error: 0.0126 - val_loss: 7.7394e-04 - val_mean_absolute_error: 0.0237
# Epoch 13/50
# 685/685 [==============================] - 46s 67ms/step - loss: 2.9541e-04 - mean_absolute_error: 0.0124 - val_loss: 7.7127e-04 - val_mean_absolute_error: 0.0237
# Epoch 14/50
# 685/685 [==============================] - 45s 65ms/step - loss: 2.8360e-04 - mean_absolute_error: 0.0122 - val_loss: 7.2185e-04 - val_mean_absolute_error: 0.0221
# Epoch 15/50
# 685/685 [==============================] - 44s 65ms/step - loss: 2.7842e-04 - mean_absolute_error: 0.0121 - val_loss: 9.1489e-04 - val_mean_absolute_error: 0.0239
# Epoch 16/50
# 685/685 [==============================] - 46s 67ms/step - loss: 2.7311e-04 - mean_absolute_error: 0.0120 - val_loss: 8.8118e-04 - val_mean_absolute_error: 0.0235
# Epoch 17/50
# 685/685 [==============================] - 46s 68ms/step - loss: 2.6687e-04 - mean_absolute_error: 0.0118 - val_loss: 7.5892e-04 - val_mean_absolute_error: 0.0217
# Epoch 18/50
# 685/685 [==============================] - 46s 67ms/step - loss: 2.5778e-04 - mean_absolute_error: 0.0116 - val_loss: 5.8167e-04 - val_mean_absolute_error: 0.0189
# Epoch 19/50
# 685/685 [==============================] - 45s 66ms/step - loss: 2.4687e-04 - mean_absolute_error: 0.0114 - val_loss: 4.9858e-04 - val_mean_absolute_error: 0.0173
# Epoch 20/50
# 685/685 [==============================] - 45s 66ms/step - loss: 2.3740e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6656e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/50
# 685/685 [==============================] - 45s 66ms/step - loss: 2.2898e-04 - mean_absolute_error: 0.0110 - val_loss: 4.6714e-04 - val_mean_absolute_error: 0.0165
# Epoch 22/50
# 685/685 [==============================] - 53s 78ms/step - loss: 2.1733e-04 - mean_absolute_error: 0.0106 - val_loss: 5.5090e-04 - val_mean_absolute_error: 0.0189
# Epoch 23/50
# 685/685 [==============================] - 51s 74ms/step - loss: 1.9868e-04 - mean_absolute_error: 0.0101 - val_loss: 6.9387e-04 - val_mean_absolute_error: 0.0219
# Epoch 24/50
# 685/685 [==============================] - 52s 76ms/step - loss: 1.8442e-04 - mean_absolute_error: 0.0097 - val_loss: 7.6112e-04 - val_mean_absolute_error: 0.0235
# Epoch 25/50
# 685/685 [==============================] - 53s 78ms/step - loss: 1.7377e-04 - mean_absolute_error: 0.0094 - val_loss: 8.8266e-04 - val_mean_absolute_error: 0.0256
# Epoch 26/50
# 685/685 [==============================] - 50s 72ms/step - loss: 1.6885e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 27/50
# 685/685 [==============================] - 48s 70ms/step - loss: 1.6602e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0299
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 164.01032214802504
#  LSTM의 MAPE : 13.64403536052397
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 56s 72ms/step - loss: 0.0037 - mean_absolute_error: 0.0379 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 2/50
# 685/685 [==============================] - 47s 69ms/step - loss: 6.0670e-04 - mean_absolute_error: 0.0175 - val_loss: 5.0276e-04 - val_mean_absolute_error: 0.0171
# Epoch 3/50
# 685/685 [==============================] - 48s 70ms/step - loss: 3.5259e-04 - mean_absolute_error: 0.0130 - val_loss: 4.0704e-04 - val_mean_absolute_error: 0.0162
# Epoch 4/50
# 685/685 [==============================] - 47s 68ms/step - loss: 3.0280e-04 - mean_absolute_error: 0.0119 - val_loss: 5.0691e-04 - val_mean_absolute_error: 0.0191
# Epoch 5/50
# 685/685 [==============================] - 47s 68ms/step - loss: 2.7641e-04 - mean_absolute_error: 0.0112 - val_loss: 3.5540e-04 - val_mean_absolute_error: 0.0157
# Epoch 6/50
# 685/685 [==============================] - 46s 66ms/step - loss: 2.5303e-04 - mean_absolute_error: 0.0106 - val_loss: 2.7994e-04 - val_mean_absolute_error: 0.0137
# Epoch 7/50
# 685/685 [==============================] - 45s 65ms/step - loss: 2.3522e-04 - mean_absolute_error: 0.0101 - val_loss: 2.4567e-04 - val_mean_absolute_error: 0.0126
# Epoch 8/50
# 685/685 [==============================] - 44s 65ms/step - loss: 2.1808e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4987e-04 - val_mean_absolute_error: 0.0128
# Epoch 9/50
# 685/685 [==============================] - 46s 67ms/step - loss: 2.0078e-04 - mean_absolute_error: 0.0090 - val_loss: 3.6801e-04 - val_mean_absolute_error: 0.0156
# Epoch 10/50
# 685/685 [==============================] - 45s 66ms/step - loss: 1.8224e-04 - mean_absolute_error: 0.0084 - val_loss: 3.6861e-04 - val_mean_absolute_error: 0.0156
# Epoch 11/50
# 685/685 [==============================] - 44s 64ms/step - loss: 1.7458e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9048e-04 - val_mean_absolute_error: 0.0133
# Epoch 12/50
# 685/685 [==============================] - 45s 65ms/step - loss: 1.8544e-04 - mean_absolute_error: 0.0085 - val_loss: 2.6199e-04 - val_mean_absolute_error: 0.0130
# Epoch 13/50
# 685/685 [==============================] - 46s 68ms/step - loss: 1.6718e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3764e-04 - val_mean_absolute_error: 0.0124
# Epoch 14/50
# 685/685 [==============================] - 48s 70ms/step - loss: 1.5851e-04 - mean_absolute_error: 0.0077 - val_loss: 2.3155e-04 - val_mean_absolute_error: 0.0123
# Epoch 15/50
# 685/685 [==============================] - 48s 70ms/step - loss: 1.5282e-04 - mean_absolute_error: 0.0075 - val_loss: 2.3593e-04 - val_mean_absolute_error: 0.0124
# Epoch 16/50
# 685/685 [==============================] - 51s 74ms/step - loss: 1.4645e-04 - mean_absolute_error: 0.0073 - val_loss: 2.4255e-04 - val_mean_absolute_error: 0.0127
# Epoch 17/50
# 685/685 [==============================] - 47s 69ms/step - loss: 1.3988e-04 - mean_absolute_error: 0.0071 - val_loss: 2.6274e-04 - val_mean_absolute_error: 0.0133
# Epoch 18/50
# 685/685 [==============================] - 48s 69ms/step - loss: 1.3426e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9586e-04 - val_mean_absolute_error: 0.0143
# Epoch 19/50
# 685/685 [==============================] - 48s 70ms/step - loss: 1.2909e-04 - mean_absolute_error: 0.0068 - val_loss: 3.3037e-04 - val_mean_absolute_error: 0.0154
# Epoch 20/50
# 685/685 [==============================] - 50s 72ms/step - loss: 1.2389e-04 - mean_absolute_error: 0.0067 - val_loss: 3.1498e-04 - val_mean_absolute_error: 0.0151
# Epoch 21/50
# 685/685 [==============================] - 47s 68ms/step - loss: 1.2019e-04 - mean_absolute_error: 0.0066 - val_loss: 2.3301e-04 - val_mean_absolute_error: 0.0128
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 151.36445073019033
#  LSTM의 MAPE : 8.259484599665848
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 55s 71ms/step - loss: 3.0593e-04 - mean_absolute_error: 0.0105 - val_loss: 8.9713e-04 - val_mean_absolute_error: 0.0270
# Epoch 2/50
# 685/685 [==============================] - 48s 70ms/step - loss: 1.4262e-04 - mean_absolute_error: 0.0072 - val_loss: 5.5244e-04 - val_mean_absolute_error: 0.0213
# Epoch 3/50
# 685/685 [==============================] - 49s 72ms/step - loss: 1.0585e-04 - mean_absolute_error: 0.0052 - val_loss: 2.6999e-04 - val_mean_absolute_error: 0.0147
# Epoch 4/50
# 685/685 [==============================] - 46s 68ms/step - loss: 8.8937e-05 - mean_absolute_error: 0.0041 - val_loss: 2.3978e-04 - val_mean_absolute_error: 0.0138
# Epoch 5/50
# 685/685 [==============================] - 46s 67ms/step - loss: 8.3043e-05 - mean_absolute_error: 0.0038 - val_loss: 2.0972e-04 - val_mean_absolute_error: 0.0129
# Epoch 6/50
# 685/685 [==============================] - 46s 67ms/step - loss: 7.9998e-05 - mean_absolute_error: 0.0037 - val_loss: 2.1385e-04 - val_mean_absolute_error: 0.0131
# Epoch 7/50
# 685/685 [==============================] - 45s 66ms/step - loss: 7.8359e-05 - mean_absolute_error: 0.0036 - val_loss: 2.5410e-04 - val_mean_absolute_error: 0.0142
# Epoch 8/50
# 685/685 [==============================] - 47s 68ms/step - loss: 7.6062e-05 - mean_absolute_error: 0.0035 - val_loss: 3.0109e-04 - val_mean_absolute_error: 0.0155
# Epoch 9/50
# 685/685 [==============================] - 46s 67ms/step - loss: 7.3233e-05 - mean_absolute_error: 0.0034 - val_loss: 3.0928e-04 - val_mean_absolute_error: 0.0157
# Epoch 10/50
# 685/685 [==============================] - 46s 67ms/step - loss: 7.0863e-05 - mean_absolute_error: 0.0032 - val_loss: 2.9909e-04 - val_mean_absolute_error: 0.0155
# Epoch 11/50
# 685/685 [==============================] - 46s 67ms/step - loss: 6.8888e-05 - mean_absolute_error: 0.0031 - val_loss: 3.0114e-04 - val_mean_absolute_error: 0.0155
# Epoch 12/50
# 685/685 [==============================] - 46s 67ms/step - loss: 6.7816e-05 - mean_absolute_error: 0.0030 - val_loss: 2.9633e-04 - val_mean_absolute_error: 0.0154
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 114.33806028661185
#  LSTM의 MAPE : 36.301689166455034
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
model_list = [model_lstm_0, model_1, model_2, model_3, model_4, model_5, model_6]
num = 0
for i in model_list:
  i.save('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'_0711_2' + '.h5')
  num+=1

# %% [markdown]
# - 코랩 무료 gpu의 한계로 모델을 저장하고 불러오는 방법 선택

# %%
from tensorflow.keras.models import load_model
model_list = ['model_0', 'model_1', 'model_2', 'model_3', 'model_4', 'model_5', 'model_6']
num = 0

for i in model_list:
  globals()['{}'.format(i)] = load_model('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'_0711_2'+'.h5')
  num+=1

# %%
from sklearn.metrics import mean_squared_error

def mape(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

y_val_0 = scaler_num[0].inverse_transform(y_val_0)
pred_lstm_0 = scaler_num[0].inverse_transform(model_0.predict(x_val_0))

print('RMSE : {}'.format(mean_squared_error(y_val_0, pred_lstm_0)**0.5))

y_val_1 = scaler_num[1].inverse_transform(y_val_1)
pred_lstm_1 = scaler_num[1].inverse_transform(model_1.predict(x_val_1))

print('RMSE : {}'.format(mean_squared_error(y_val_1, pred_lstm_1)**0.5))

y_val_2 = scaler_num[2].inverse_transform(y_val_2)
pred_lstm_2 = scaler_num[2].inverse_transform(model_2.predict(x_val_2))

print('RMSE : {}'.format(mean_squared_error(y_val_2, pred_lstm_2)**0.5))

y_val_3 = scaler_num[3].inverse_transform(y_val_3)
pred_lstm_3 = scaler_num[3].inverse_transform(model_3.predict(x_val_3))

print('RMSE : {}'.format(mean_squared_error(y_val_3, pred_lstm_3)**0.5))

y_val_4 = scaler_num[4].inverse_transform(y_val_4)
pred_lstm_4 = scaler_num[4].inverse_transform(model_4.predict(x_val_4))

print('RMSE : {}'.format(mean_squared_error(y_val_4, pred_lstm_4)**0.5))

y_val_5 = scaler_num[5].inverse_transform(y_val_5)
pred_lstm_5 = scaler_num[5].inverse_transform(model_5.predict(x_val_5))

print('RMSE : {}'.format(mean_squared_error(y_val_5, pred_lstm_5)**0.5))

y_val_6 = scaler_num[6].inverse_transform(y_val_6)
pred_lstm_6 = scaler_num[6].inverse_transform(model_6.predict(x_val_6))

print('RMSE : {}'.format(mean_squared_error(y_val_6, pred_lstm_6)**0.5))

# %%
y_val_total = (np.concatenate((y_val_0.T[0], y_val_1.T[0], y_val_2.T[0], y_val_3.T[0], y_val_4.T[0], y_val_5.T[0], y_val_6.T[0]), axis=0))
pred_lstm_total = (np.concatenate((pred_lstm_0.T[0], pred_lstm_1.T[0], pred_lstm_2.T[0], pred_lstm_3.T[0], pred_lstm_4.T[0], pred_lstm_5.T[0], pred_lstm_6.T[0]), axis=0))

print('RMSE : {}'.format(mean_squared_error(y_val_total, pred_lstm_total)**0.5))
print('MAPE : {}'.format(mape(y_val_total, pred_lstm_total)))
# Out:
# RMSE : 109.67906379969284
# MAPE : 25.92721708878895

# %% [markdown]
# - 온도를 추가하기전 lstm보다 성능이 더 안좋아졌다.
# RMSE 기준 약 70이었는데 지금은 RMSE기준 109이다.

# %%
pred_vis(pred_lstm_0.T[0], 'Bi_LSTM_0', y_val_0.T[0])
pred_vis(pred_lstm_1.T[0], 'Bi_LSTM_1', y_val_1.T[0])
pred_vis(pred_lstm_2.T[0], 'Bi_LSTM_2', y_val_2.T[0])

# %%
pred_vis(pred_lstm_3.T[0], 'Bi_LSTM_3', y_val_3.T[0])
pred_vis(pred_lstm_4.T[0], 'Bi_LSTM_4', y_val_4.T[0])
pred_vis(pred_lstm_5.T[0], 'Bi_LSTM_5', y_val_5.T[0])

# %%
pred_vis(pred_lstm_6.T[0], 'Bi_LSTM_6', y_val_6.T[0])
pred_vis(pred_lstm_total, 'Bi_LSTM_total', y_val_total)

# %% [markdown]
# - 온도를 추가했는데 이게 지역에 따른 온도를 다르게 추가한것이 아니라서 예측하는데 어려웠나보다.
# - 노멀한 Bi LSTM보다 더 성능이 안좋다.
