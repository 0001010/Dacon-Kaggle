# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting attention
#   Downloading attention-4.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: tensorflow>=2.1 in /usr/local/lib/python3.8/dist-packages (from attention) (2.9.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.8/dist-packages (from attention) (1.21.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (3.19.6)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.12)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (57.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.51.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (14.0.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (4.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (21.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (0.28.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (1.15.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.1->attention) (2.9.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1->attention) (0.38.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (2.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.1->attention) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow>=2.1->attention) (3.0.9)
# Installing collected packages: attention
# Successfully installed attention-4.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import random
import torch
import os

def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

class config:
    seed = 42
    device = "cuda:0"    
        
    lr = 1e-3
    epochs = 25
    batch_size = 32
    num_workers = 4
    train_5_folds = True
    
seed_everything(config.seed)

total = pd.read_csv('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/train.csv', encoding = 'cp949')
total.head()
# Out:
#           연월일  시간 구분       공급량
# 0  2013-01-01   1  A  2497.129
# 1  2013-01-01   2  A  2363.265
# 2  2013-01-01   3  A  2258.505
# 3  2013-01-01   4  A  2243.969
# 4  2013-01-01   5  A  2344.105

# %%
total['구분'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'G', 'H'], dtype=object)

# %%
d_map = dict()
for i, d in enumerate(total['구분'].unique()):
  d_map[d] = i
# 라벨 인코딩

total['구분'] = total['구분'].map(d_map)

total
# Out:
#                연월일  시간  구분       공급량
# 0       2013-01-01   1   0  2497.129
# 1       2013-01-01   2   0  2363.265
# 2       2013-01-01   3   0  2258.505
# 3       2013-01-01   4   0  2243.969
# 4       2013-01-01   5   0  2344.105
# ...            ...  ..  ..       ...
# 368083  2018-12-31  20   6   681.033
# 368084  2018-12-31  21   6   669.961
# 368085  2018-12-31  22   6   657.941
# 368086  2018-12-31  23   6   610.953
# 368087  2018-12-31  24   6   560.896
#
# [368088 rows x 4 columns]

# %%
total[total['공급량']==total['공급량'].min()]['연월일'].unique()
#total.iloc[2229:]

# 이슈
# min값이 수상함 이거 수정하고 이상치 값 수정
# 13년 8월 -> 14,15,16,17년의 평균값으로 대치
# max값은 음.. 이것도 하나하나찔러보자
# 아니면 isolation forest 돌리는데 이것도 문제있으면 좀...
# 바로 수작업
# Out:
# array(['2013-08-12', '2013-08-13', '2013-08-14', '2013-08-15',
#        '2013-08-16', '2013-08-17', '2013-08-18', '2013-08-19',
#        '2013-08-20', '2013-08-21', '2013-08-22', '2013-08-23',
#        '2013-08-24', '2013-08-25', '2013-08-26', '2013-08-27',
#        '2013-08-28', '2013-08-29', '2013-08-30', '2013-08-31',
#        '2013-09-01', '2013-09-02', '2014-04-21', '2014-04-22',
#        '2014-04-23', '2014-04-24', '2014-04-25', '2014-04-26',
#        '2014-04-27', '2014-04-28', '2014-04-29', '2014-04-30',
#        '2014-05-01', '2014-05-02', '2014-05-03', '2014-05-04',
#        '2014-05-05', '2014-05-06', '2014-05-07', '2014-05-08',
#        '2014-12-09', '2014-12-10', '2014-12-11', '2015-05-12',
#        '2015-05-13', '2015-05-14', '2015-05-15', '2015-05-16',
#        '2015-05-17', '2015-05-18', '2015-05-19', '2015-05-20',
#        '2015-05-21', '2015-05-22', '2015-05-23', '2015-05-24',
#        '2015-05-25', '2015-05-26', '2015-05-27', '2015-05-28',
#        '2016-05-09', '2016-05-10', '2016-05-11', '2016-05-12',
#        '2016-05-13', '2016-05-14', '2016-05-15', '2016-05-16',
#        '2016-05-17', '2016-05-18', '2016-05-19', '2016-05-20',
#        '2016-05-21', '2016-05-22', '2016-05-23', '2016-08-11',
#        '2016-08-12', '2017-06-15', '2017-06-16', '2017-06-20',
#        '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-24',
#        '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28',
#        '2017-06-29', '2017-06-30'], dtype=object)

# %%
total['연월일'] = pd.to_datetime(total['연월일'])

total['year'] = total['연월일'].dt.year
total['month'] = total['연월일'].dt.month
total['day'] = total['연월일'].dt.day
total['weekday'] = total['연월일'].dt.weekday

# %%
f, ax = plt.subplots(figsize = (6,3))
total['공급량'].plot()

# %% [markdown]
# - 시계열 데이터라 그런지 뭔가 일정한 패턴이 있어보인다.

# %%
import os

os.chdir('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발')

for lists in os.listdir():
  if lists[5:9]=='2013' or lists[5:9]=='2014' or lists[5:9]=='2015' or lists[5:9]=='2016' or lists[5:9]=='2017' or lists[5:9]=='2018' or lists[5:9]=='2019':
    datas = pd.read_csv(lists, encoding = 'euc-kr')
    datas = datas[['기온(°C)']]

    globals()['temp_{}'.format(lists[5:9])] = datas

total_temp = pd.DataFrame()
temp = [temp_2013, temp_2014, temp_2015, temp_2016, temp_2017, temp_2018]

# 시계열 결측치 보간
# 기온은 value값으로 보간 사용
# 나머지 것들은 측정되지 않은 값이므로 0으로 채워도 상관없을듯함
for i in temp:
  i['기온(°C)'] = i['기온(°C)'].interpolate(method = 'values')
  i = i.fillna(0)
  total_temp = pd.concat([total_temp, i])

for i in range(7):
  globals()['total_gu_{}'.format(i)] = total[total['구분']==i]
lists = [total_gu_0, total_gu_1, total_gu_2, total_gu_3, total_gu_4, total_gu_5, total_gu_6]

total_temps = pd.DataFrame()

for j in lists:
  s = pd.concat([j.reset_index(drop = True), total_temp.reset_index(drop = True)], axis = 1)
  total_temps = pd.concat([total_temps.reset_index(drop = True), s.reset_index(drop = True)], axis = 0)


# 날씨 부분에 null값이 있어서 그것을 먼저 해결
# 기온 부분만 해결하고 나머지 부분은 없는부분이니 0으로 채워도 무방할듯함

# %%
total_temps.isnull().sum()
# Out:
# 연월일        0
# 시간         0
# 구분         0
# 공급량        0
# year       0
# month      0
# day        0
# weekday    0
# 기온(°C)     0
# dtype: int64

# %%
train_years = [2013, 2014, 2015, 2016, 2017]
val_years = [2018] # 시계열 데이터이므로 2018년 1년치의 데이터를 예측, test data set에는 2019년 데이터를 예측

train = total_temps[total_temps['year'].isin(train_years)]
val = total_temps[total_temps['year'].isin(val_years)]

# %%
print('초과 이상치 ',train[train['공급량']>=7000]['구분'].unique())
print('미만 이상치 ',train[train['공급량']<=3]['구분'].unique())
# 이상치 값을 추출하고 평년 공급량으로 맞출예정
# Out:
# 초과 이상치  [0 5]
# 미만 이상치  [2 6]

# %%
print('미만 이상치_val', val[val['공급량']<=3]['구분'].unique())
# Out:
# 미만 이상치_val [2]

# %% [markdown]
# 구분에 2번 공급처는 건드리면 안될거같고 <br>
# 나머지 것들만 정리를 해보겠다.

# %%
outlier_index = train[train['공급량']>=7000].index
train.iloc[outlier_index]
# Out:
#              연월일  시간  구분        공급량  year  month  day  weekday  기온(°C)
# 2230  2013-04-03  23   0  11593.617  2013      4    3        2     7.3
# 623   2013-01-26  24   6    616.988  2013      1   26        5    -9.3
# 16367 2014-11-13  24   6    375.476  2014     11   13        3    -1.0
# 25285 2015-11-20  14   6    206.244  2015     11   20        4    12.3
# 35929 2017-02-06   2   6    322.980  2017      2    6        0    -1.8

# %%
train.replace(train.iloc[outlier_index[0]]['공급량'], train.query("month==4 and day==3 and year!=2013 and 시간==23 and 구분==0")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[1]]['공급량'], train.query("month==1 and day==27 and year!=2013 and 시간==24 and 구분==5")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[2]]['공급량'], train.query("month==11 and day==14 and year!=2014 and 시간==24 and 구분==5")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[3]]['공급량'], train.query("month==11 and day==21 and year!=2015 and 시간==14 and 구분==5")['공급량'].mean(), inplace = True)
train.replace(train.iloc[outlier_index[4]]['공급량'], train.query("month==2 and day==7 and year!=2017 and 시간==2 and 구분==5")['공급량'].mean(),inplace = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
def outliter_fill(num, data):
  if num>=1000:
    outlier_index = data[data['공급량']>=num].index
  else:
    outlier_index = data[data['공급량']<=num].index

  df = data.iloc[outlier_index]

  for number in range(len(outlier_index)):
    s = data.iloc[outlier_index[i]]
    data.replace(s['공급량'], data.query("month==" + str(s['month'] + 
                                                      " and day==" + str(s['day']) + 
                                                      " and year!=" + str(s['year']) + 
                                                      " and 시간==" + str(s['시간']) + 
                                                      " and 구분==" + str(s['구분'])['공급량'].mean(), inplace = True)))

  return s

# %%
train[train['구분']==0][['공급량']].reset_index(drop = True).plot()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44553 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# Isolation Forest

"""total[total['구분']==0]

from sklearn.ensemble import IsolationForest

outliers = []
isolation_forest =  IsolationForest(contamination = 0.004)
for i in range(7):
  isolation_forest.fit(total[total['구분']==i][['공급량']])
  outliers.append(isolation_forest.predict(total[['공급량']]))
"""
# Out:
# "total[total['구분']==0]\n\nfrom sklearn.ensemble import IsolationForest\n\noutliers = []\nisolation_forest =  IsolationForest(contamination = 0.004)\nfor i in range(7):\n  isolation_forest.fit(total[total['구분']==i][['공급량']])\n  outliers.append(isolation_forest.predict(total[['공급량']]))\n"

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

scaler_num = ['scaler_0','scaler_1','scaler_2','scaler_3','scaler_4','scaler_5','scaler_6']

for i in range(7):
  #scaler = MinMaxScaler()
  
  scaler_num[i] = MinMaxScaler()
  globals()['train_{}'.format(i)] = scaler_num[i].fit_transform(train[train['구분']==i][['공급량']].reset_index(drop = True))
  globals()['val_{}'.format(i)] = scaler_num[i].transform(val[val['구분']==i][['공급량']].reset_index(drop = True))
  

print(train_0.shape, val_0.shape)
# Out:
# (43824, 1) (8760, 1)

# %%
scaler_num[0].inverse_transform(train_0)
# Out:
# array([[2497.129],
#        [2363.265],
#        [2258.505],
#        ...,
#        [2054.192],
#        [1981.397],
#        [1897.268]])

# %% [markdown]
# - 딥러닝을 사용할 예정이라서 전체 데이터를 전부 넣어도 무방하지만 모델을 더 돌려보자는 취지에서 각 구분별로 모델정의 즉, 7개의 모델을 생성예정
# - 그에 따라 스케일러도 7개 생성

# %%
def create_dataset (X, look_back = 1):
    Xs, ys, rem_data = [], [], []
 
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back][0])
        rem_data.append(X[i+look_back][1:])
 
    return np.array(Xs), np.array(ys), np.array(rem_data)

LOOK_BACK = 24

x_train_0, y_train_0, re_y_train_0 = create_dataset(train_0, LOOK_BACK)
x_val_0, y_val_0, re_y_val_0 = create_dataset(val_0, LOOK_BACK)

#################################################################

x_train_1, y_train_1, re_y_train_1 = create_dataset(train_1, LOOK_BACK)
x_val_1, y_val_1, re_y_val_1 = create_dataset(val_1, LOOK_BACK)

#################################################################

x_train_2, y_train_2, re_y_train_2 = create_dataset(train_2, LOOK_BACK)
x_val_2, y_val_2, re_y_val_2 = create_dataset(val_2, LOOK_BACK)

#################################################################

x_train_3, y_train_3, re_y_train_3 = create_dataset(train_3, LOOK_BACK)
x_val_3, y_val_3, re_y_val_3 = create_dataset(val_3, LOOK_BACK)

#################################################################

x_train_4, y_train_4, re_y_train_4 = create_dataset(train_4, LOOK_BACK)
x_val_4, y_val_4, re_y_val_4 = create_dataset(val_4, LOOK_BACK)

#################################################################

x_train_5, y_train_5, re_y_train_5 = create_dataset(train_5, LOOK_BACK)
x_val_5, y_val_5, re_y_val_5 = create_dataset(val_5, LOOK_BACK)

#################################################################

x_train_6, y_train_6, re_y_train_6 = create_dataset(train_6, LOOK_BACK)
x_val_6, y_val_6, re_y_val_6 = create_dataset(val_6, LOOK_BACK)

# %% [markdown]
# - LOOKBACK을 24로 정하고(시간단위 데이터인데 24시간마다 어떠한 주기가 나타날 것이라고 추측) 데이터변형

# %%
import attention
from tensorflow.python.keras.callbacks import History
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from attention import Attention

def create_bilstm(units, x_train):
  inputs = Input(shape = (x_train.shape[1], x_train.shape[2]))
  hidden1 = Bidirectional(LSTM(units = units, return_sequences=True))(inputs)
  hidden2 = Bidirectional(LSTM(units = units, return_sequences=True))(hidden1)
  attention2 = Attention(units = units//2)(hidden2)
  output = Dense(1)(attention2)
  model = Model(inputs = inputs, outputs = output)
  adam = tf.keras.optimizers.RMSprop(learning_rate = 0.001)
  model.compile(loss = 'mean_squared_error', optimizer = adam, metrics = ['mean_absolute_error'])

  return model

def create_gru(units, x_train):
  inputs = Input(shape = (x_train.shape[1], x_train.shape[2]))
  hidden1 = Bidirectional(GRU(units = units, return_sequences=True))(inputs)
  hidden2 = Bidirectional(GRU(units = units, return_sequences=True))(hidden1)
  attention2 = Attention(units = units//2)(hidden2)
  output = Dense(1)(attention2)
  model = Model(inputs = inputs, outputs = output)
  adam = tf.keras.optimizers.RMSprop(learning_rate = 0.001)
  model.compile(loss = 'mean_squared_error', optimizer = adam, metrics = ['mean_absolute_error'])


  return model


def fit_model(model,x_train, y_train, epoch, x_val,y_val):
  early_stop = EarlyStopping(monitor = 'val_loss',
                             patience = 7)
  
  history = model.fit(x_train, y_train, 
                      epochs = epoch, 
                      validation_data = (x_val, y_val),
                      batch_size = 64,
                      shuffle = False)
  return history

# %% [markdown]
# - 양방향 LSTM, GRU를 비교할 예정

# %%
from sklearn.metrics import mean_squared_error

def mape(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 


# train_0 학습
model_lstm_0 = create_bilstm(64, x_train_0)
history_lstm_0 = fit_model(model_lstm_0, x_train_0, y_train_0, 50, x_val_0, y_val_0)
model_gru_0 = create_gru(64, x_train_0)
history_gru_0 = fit_model(model_gru_0, x_train_0, y_train_0, 50, x_val_0, y_val_0)

pred_lstm_0 = model_lstm_0.predict(x_val_0) # 2018년 예측
pred_gru_0 = model_gru_0.predict(x_val_0) # 2018년 예측
re_y_val_0 = np.insert(re_y_val_0, 0, pred_lstm_0.T, axis = 1) # min-max inverse transform을 하기위한 전처리
re_y_val_1_0 = np.insert(re_y_val_0, 0, pred_gru_0.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_0 = scaler_num[0].inverse_transform(re_y_val_0) # inverse transform
pred_gru_0 = scaler_num[0].inverse_transform(re_y_val_1_0) # inverse transform

re_y_val_0 = np.delete(re_y_val_0,0,1)
re_y_val_0 = np.insert(re_y_val_0, 0, y_val_0.T, axis = 1)

y_val_0 = scaler_num[0].inverse_transform(re_y_val_0)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_0.T[0], y_val_0.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_0.T[0],  y_val_0.T[0])))
print("GRU의 RMSE : {}".format(mean_squared_error(pred_gru_0.T[0], y_val_0.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_gru_0.T[0],  y_val_0.T[0])))
# Out:
# Epoch 1/50
# 685/685 [==============================] - 34s 18ms/step - loss: 0.0037 - mean_absolute_error: 0.0352 - val_loss: 0.0011 - val_mean_absolute_error: 0.0283
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.2511e-04 - mean_absolute_error: 0.0199 - val_loss: 9.9813e-04 - val_mean_absolute_error: 0.0268
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3136e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0010 - val_mean_absolute_error: 0.0274
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.3225e-04 - mean_absolute_error: 0.0158 - val_loss: 9.0376e-04 - val_mean_absolute_error: 0.0249
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9284e-04 - mean_absolute_error: 0.0152 - val_loss: 8.6227e-04 - val_mean_absolute_error: 0.0240
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.7045e-04 - mean_absolute_error: 0.0147 - val_loss: 8.6879e-04 - val_mean_absolute_error: 0.0238
# Epoch 7/50
# 685/685 [==============================] - 14s 20ms/step - loss: 4.4916e-04 - mean_absolute_error: 0.0144 - val_loss: 7.2120e-04 - val_mean_absolute_error: 0.0210
# Epoch 8/50
# 685/685 [==============================] - 13s 18ms/step - loss: 4.3114e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1167e-04 - val_mean_absolute_error: 0.0208
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.1505e-04 - mean_absolute_error: 0.0138 - val_loss: 7.4149e-04 - val_mean_absolute_error: 0.0213
# Epoch 10/50
# 685/685 [==============================] - 12s 17ms/step - loss: 3.9576e-04 - mean_absolute_error: 0.0134 - val_loss: 6.5972e-04 - val_mean_absolute_error: 0.0200
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.5360e-04 - mean_absolute_error: 0.0127 - val_loss: 4.2225e-04 - val_mean_absolute_error: 0.0161
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.0256e-04 - mean_absolute_error: 0.0118 - val_loss: 3.9995e-04 - val_mean_absolute_error: 0.0158
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7712e-04 - mean_absolute_error: 0.0113 - val_loss: 4.0730e-04 - val_mean_absolute_error: 0.0162
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5935e-04 - mean_absolute_error: 0.0110 - val_loss: 3.7565e-04 - val_mean_absolute_error: 0.0155
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4722e-04 - mean_absolute_error: 0.0107 - val_loss: 3.3183e-04 - val_mean_absolute_error: 0.0143
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.3765e-04 - mean_absolute_error: 0.0105 - val_loss: 3.3808e-04 - val_mean_absolute_error: 0.0145
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2931e-04 - mean_absolute_error: 0.0102 - val_loss: 3.9342e-04 - val_mean_absolute_error: 0.0159
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2199e-04 - mean_absolute_error: 0.0100 - val_loss: 4.4025e-04 - val_mean_absolute_error: 0.0169
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1446e-04 - mean_absolute_error: 0.0099 - val_loss: 4.5150e-04 - val_mean_absolute_error: 0.0171
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0562e-04 - mean_absolute_error: 0.0096 - val_loss: 4.5642e-04 - val_mean_absolute_error: 0.0172
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9778e-04 - mean_absolute_error: 0.0095 - val_loss: 4.2409e-04 - val_mean_absolute_error: 0.0166
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9035e-04 - mean_absolute_error: 0.0093 - val_loss: 3.6001e-04 - val_mean_absolute_error: 0.0150
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8197e-04 - mean_absolute_error: 0.0090 - val_loss: 3.3494e-04 - val_mean_absolute_error: 0.0145
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7489e-04 - mean_absolute_error: 0.0089 - val_loss: 2.6327e-04 - val_mean_absolute_error: 0.0126
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6936e-04 - mean_absolute_error: 0.0087 - val_loss: 3.2059e-04 - val_mean_absolute_error: 0.0142
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6436e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0125e-04 - val_mean_absolute_error: 0.0137
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5972e-04 - mean_absolute_error: 0.0085 - val_loss: 3.0767e-04 - val_mean_absolute_error: 0.0138
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5617e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1003e-04 - val_mean_absolute_error: 0.0138
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5185e-04 - mean_absolute_error: 0.0083 - val_loss: 3.2361e-04 - val_mean_absolute_error: 0.0140
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4751e-04 - mean_absolute_error: 0.0082 - val_loss: 3.2741e-04 - val_mean_absolute_error: 0.0141
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4369e-04 - mean_absolute_error: 0.0081 - val_loss: 3.1913e-04 - val_mean_absolute_error: 0.0138
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4020e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0947e-04 - val_mean_absolute_error: 0.0135
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3693e-04 - mean_absolute_error: 0.0078 - val_loss: 3.1224e-04 - val_mean_absolute_error: 0.0136
# Epoch 34/50
# 685/685 [==============================] - 14s 20ms/step - loss: 1.3385e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0660e-04 - val_mean_absolute_error: 0.0134
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3137e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0079e-04 - val_mean_absolute_error: 0.0132
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2923e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9613e-04 - val_mean_absolute_error: 0.0131
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2691e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8464e-04 - val_mean_absolute_error: 0.0128
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2516e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8654e-04 - val_mean_absolute_error: 0.0129
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2280e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9646e-04 - val_mean_absolute_error: 0.0131
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2046e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0311e-04 - val_mean_absolute_error: 0.0133
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1830e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1984e-04 - val_mean_absolute_error: 0.0137
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1600e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1124e-04 - val_mean_absolute_error: 0.0134
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1466e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1805e-04 - val_mean_absolute_error: 0.0135
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1310e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0563e-04 - val_mean_absolute_error: 0.0132
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1147e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0309e-04 - val_mean_absolute_error: 0.0131
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1011e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9407e-04 - val_mean_absolute_error: 0.0129
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0884e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8758e-04 - val_mean_absolute_error: 0.0128
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0723e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8719e-04 - val_mean_absolute_error: 0.0128
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0468e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7539e-04 - val_mean_absolute_error: 0.0126
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0436e-04 - mean_absolute_error: 0.0070 - val_loss: 2.6328e-04 - val_mean_absolute_error: 0.0122
# Epoch 1/50
# 685/685 [==============================] - 19s 18ms/step - loss: 0.0028 - mean_absolute_error: 0.0313 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.8899e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307
# Epoch 3/50
# 685/685 [==============================] - 11s 15ms/step - loss: 6.9791e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0013 - val_mean_absolute_error: 0.0304
# Epoch 4/50
# 685/685 [==============================] - 10s 15ms/step - loss: 6.2357e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 5/50
# 685/685 [==============================] - 10s 15ms/step - loss: 5.8083e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.4303e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 7/50
# 685/685 [==============================] - 11s 15ms/step - loss: 4.9150e-04 - mean_absolute_error: 0.0152 - val_loss: 8.5462e-04 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 685/685 [==============================] - 11s 15ms/step - loss: 4.3883e-04 - mean_absolute_error: 0.0144 - val_loss: 7.4713e-04 - val_mean_absolute_error: 0.0221
# Epoch 9/50
# 685/685 [==============================] - 11s 15ms/step - loss: 3.8764e-04 - mean_absolute_error: 0.0136 - val_loss: 6.0571e-04 - val_mean_absolute_error: 0.0195
# Epoch 10/50
# 685/685 [==============================] - 13s 19ms/step - loss: 3.3816e-04 - mean_absolute_error: 0.0127 - val_loss: 5.1240e-04 - val_mean_absolute_error: 0.0176
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.0793e-04 - mean_absolute_error: 0.0121 - val_loss: 4.7419e-04 - val_mean_absolute_error: 0.0168
# Epoch 12/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.8821e-04 - mean_absolute_error: 0.0116 - val_loss: 4.2378e-04 - val_mean_absolute_error: 0.0157
# Epoch 13/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.6776e-04 - mean_absolute_error: 0.0112 - val_loss: 4.0365e-04 - val_mean_absolute_error: 0.0152
# Epoch 14/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.5326e-04 - mean_absolute_error: 0.0109 - val_loss: 3.6412e-04 - val_mean_absolute_error: 0.0145
# Epoch 15/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.3912e-04 - mean_absolute_error: 0.0105 - val_loss: 3.5511e-04 - val_mean_absolute_error: 0.0144
# Epoch 16/50
# 685/685 [==============================] - 10s 15ms/step - loss: 2.2530e-04 - mean_absolute_error: 0.0101 - val_loss: 3.6549e-04 - val_mean_absolute_error: 0.0146
# Epoch 17/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.1235e-04 - mean_absolute_error: 0.0098 - val_loss: 4.1549e-04 - val_mean_absolute_error: 0.0158
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0144e-04 - mean_absolute_error: 0.0095 - val_loss: 4.3171e-04 - val_mean_absolute_error: 0.0166
# Epoch 19/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.9342e-04 - mean_absolute_error: 0.0093 - val_loss: 4.1086e-04 - val_mean_absolute_error: 0.0161
# Epoch 20/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.8528e-04 - mean_absolute_error: 0.0091 - val_loss: 3.8006e-04 - val_mean_absolute_error: 0.0153
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7877e-04 - mean_absolute_error: 0.0089 - val_loss: 2.9544e-04 - val_mean_absolute_error: 0.0127
# Epoch 22/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.7001e-04 - mean_absolute_error: 0.0087 - val_loss: 3.7356e-04 - val_mean_absolute_error: 0.0147
# Epoch 23/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.6414e-04 - mean_absolute_error: 0.0085 - val_loss: 3.7700e-04 - val_mean_absolute_error: 0.0148
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5800e-04 - mean_absolute_error: 0.0084 - val_loss: 3.8570e-04 - val_mean_absolute_error: 0.0153
# Epoch 25/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5433e-04 - mean_absolute_error: 0.0083 - val_loss: 3.7883e-04 - val_mean_absolute_error: 0.0152
# Epoch 26/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.4965e-04 - mean_absolute_error: 0.0082 - val_loss: 3.6698e-04 - val_mean_absolute_error: 0.0150
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4599e-04 - mean_absolute_error: 0.0081 - val_loss: 3.1511e-04 - val_mean_absolute_error: 0.0136
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4131e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2414e-04 - val_mean_absolute_error: 0.0139
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3784e-04 - mean_absolute_error: 0.0079 - val_loss: 2.4451e-04 - val_mean_absolute_error: 0.0115
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3489e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4352e-04 - val_mean_absolute_error: 0.0115
# Epoch 31/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.3187e-04 - mean_absolute_error: 0.0077 - val_loss: 2.4914e-04 - val_mean_absolute_error: 0.0118
# Epoch 32/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2832e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7519e-04 - val_mean_absolute_error: 0.0126
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2698e-04 - mean_absolute_error: 0.0076 - val_loss: 2.2040e-04 - val_mean_absolute_error: 0.0109
# Epoch 34/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2400e-04 - mean_absolute_error: 0.0075 - val_loss: 2.2230e-04 - val_mean_absolute_error: 0.0111
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2207e-04 - mean_absolute_error: 0.0074 - val_loss: 2.2563e-04 - val_mean_absolute_error: 0.0112
# Epoch 36/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2074e-04 - mean_absolute_error: 0.0074 - val_loss: 2.3413e-04 - val_mean_absolute_error: 0.0115
# Epoch 37/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1968e-04 - mean_absolute_error: 0.0073 - val_loss: 2.3790e-04 - val_mean_absolute_error: 0.0116
# Epoch 38/50
# 685/685 [==============================] - 13s 19ms/step - loss: 1.1781e-04 - mean_absolute_error: 0.0073 - val_loss: 2.5277e-04 - val_mean_absolute_error: 0.0120
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1665e-04 - mean_absolute_error: 0.0072 - val_loss: 2.3696e-04 - val_mean_absolute_error: 0.0115
# Epoch 40/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1608e-04 - mean_absolute_error: 0.0072 - val_loss: 2.4139e-04 - val_mean_absolute_error: 0.0116
# Epoch 41/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1461e-04 - mean_absolute_error: 0.0071 - val_loss: 2.1967e-04 - val_mean_absolute_error: 0.0107
# Epoch 42/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1323e-04 - mean_absolute_error: 0.0071 - val_loss: 2.1054e-04 - val_mean_absolute_error: 0.0106
# Epoch 43/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1195e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0607e-04 - val_mean_absolute_error: 0.0133
# Epoch 44/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1113e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2352e-04 - val_mean_absolute_error: 0.0136
# Epoch 45/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1115e-04 - mean_absolute_error: 0.0070 - val_loss: 2.5501e-04 - val_mean_absolute_error: 0.0119
# Epoch 46/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1178e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1167e-04 - val_mean_absolute_error: 0.0132
# Epoch 47/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1073e-04 - mean_absolute_error: 0.0070 - val_loss: 3.3118e-04 - val_mean_absolute_error: 0.0136
# Epoch 48/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0888e-04 - mean_absolute_error: 0.0069 - val_loss: 3.3611e-04 - val_mean_absolute_error: 0.0138
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0957e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8737e-04 - val_mean_absolute_error: 0.0125
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0945e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0497e-04 - val_mean_absolute_error: 0.0128
# 273/273 [==============================] - 3s 5ms/step
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 62.86254970265201
#  LSTM의 MAPE : 5.224761835417877
# GRU의 RMSE : 67.65690101569159
#  LSTM의 MAPE : 5.0821122287472

# %%
def loss_vis(history, model_name):
  f, ax = plt.subplots(figsize = (6, 3))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend(['Train_Loss', 'Val_Loss'])
  plt.title(model_name)

loss_vis(history_lstm_0, 'Bi_LSTM')

# %%
def pred_vis(pred_model, model_name, y_val):
  f, ax = plt.subplots(figsize = (15,8))
  plt.plot(pred_model, label = 'Prediction',  alpha = 0.5)
  plt.plot(y_val, label = 'Val_data',  alpha = 0.3)
  plt.xlabel('Time')
  plt.ylabel('Value')
  plt.legend()
  plt.title(model_name)

# %%
# train_1 학습
model_1 = create_bilstm(64, x_train_1)
history_lstm_1 = fit_model(model_1, x_train_1, y_train_1, 50, x_val_1, y_val_1)
print('-'*150)

pred_lstm_1 = model_1.predict(x_val_1) # 2018년 예측
re_y_val_1 = np.insert(re_y_val_1, 0, pred_lstm_1.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_1 = scaler_num[1].inverse_transform(re_y_val_1) # inverse transform


re_y_val_1 = np.delete(re_y_val_1,0,1)
re_y_val_1 = np.insert(re_y_val_1, 0, y_val_1.T, axis = 1)

y_val_1 = scaler_num[1].inverse_transform(re_y_val_1)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_1.T[0], y_val_1.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_1.T[0],  y_val_1.T[0])))
print('-'*150)

# train_2 학습
model_2 = create_bilstm(64, x_train_2)
history_lstm_2 = fit_model(model_2, x_train_2, y_train_2, 50, x_val_2, y_val_2)
print('-'*150)

pred_lstm_2 = model_2.predict(x_val_2) # 2018년 예측
re_y_val_2 = np.insert(re_y_val_2, 0, pred_lstm_2.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_2 = scaler_num[2].inverse_transform(re_y_val_2) # inverse transform


re_y_val_2 = np.delete(re_y_val_2,0,1)
re_y_val_2 = np.insert(re_y_val_2, 0, y_val_2.T, axis = 1)

y_val_2 = scaler_num[2].inverse_transform(re_y_val_2)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_2.T[0], y_val_2.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_2.T[0],  y_val_2.T[0])))
print('-'*150)

# train_3 학습
model_3 = create_bilstm(64, x_train_3)
history_lstm_3 = fit_model(model_3, x_train_3, y_train_3, 50, x_val_3, y_val_3)
print('-'*150)

pred_lstm_3 = model_3.predict(x_val_3) # 2018년 예측
re_y_val_3 = np.insert(re_y_val_3, 0, pred_lstm_3.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_3 = scaler_num[3].inverse_transform(re_y_val_3) # inverse transform


re_y_val_3 = np.delete(re_y_val_3,0,1)
re_y_val_3 = np.insert(re_y_val_3, 0, y_val_3.T, axis = 1)

y_val_3 = scaler_num[3].inverse_transform(re_y_val_3)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_3.T[0], y_val_3.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_3.T[0],  y_val_3.T[0])))
print('-'*150)
# Out:
# Epoch 1/50
# 685/685 [==============================] - 19s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0322 - val_loss: 0.0018 - val_mean_absolute_error: 0.0370
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.8821e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0017 - val_mean_absolute_error: 0.0359
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.3570e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0014 - val_mean_absolute_error: 0.0319
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.5252e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0011 - val_mean_absolute_error: 0.0276
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.9580e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.6663e-04 - mean_absolute_error: 0.0153 - val_loss: 9.1397e-04 - val_mean_absolute_error: 0.0248
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.3254e-04 - mean_absolute_error: 0.0149 - val_loss: 8.0271e-04 - val_mean_absolute_error: 0.0231
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9731e-04 - mean_absolute_error: 0.0144 - val_loss: 6.9623e-04 - val_mean_absolute_error: 0.0214
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.7145e-04 - mean_absolute_error: 0.0140 - val_loss: 6.4651e-04 - val_mean_absolute_error: 0.0207
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.4705e-04 - mean_absolute_error: 0.0137 - val_loss: 5.3426e-04 - val_mean_absolute_error: 0.0185
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.2715e-04 - mean_absolute_error: 0.0135 - val_loss: 5.4250e-04 - val_mean_absolute_error: 0.0189
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.1266e-04 - mean_absolute_error: 0.0132 - val_loss: 5.0914e-04 - val_mean_absolute_error: 0.0185
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.9702e-04 - mean_absolute_error: 0.0128 - val_loss: 4.3801e-04 - val_mean_absolute_error: 0.0173
# Epoch 14/50
# 685/685 [==============================] - 12s 18ms/step - loss: 3.6419e-04 - mean_absolute_error: 0.0121 - val_loss: 3.4215e-04 - val_mean_absolute_error: 0.0150
# Epoch 15/50
# 685/685 [==============================] - 12s 18ms/step - loss: 3.3175e-04 - mean_absolute_error: 0.0114 - val_loss: 3.2337e-04 - val_mean_absolute_error: 0.0147
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.1375e-04 - mean_absolute_error: 0.0111 - val_loss: 3.3341e-04 - val_mean_absolute_error: 0.0150
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.9810e-04 - mean_absolute_error: 0.0108 - val_loss: 2.5513e-04 - val_mean_absolute_error: 0.0129
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8862e-04 - mean_absolute_error: 0.0105 - val_loss: 2.8356e-04 - val_mean_absolute_error: 0.0139
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8068e-04 - mean_absolute_error: 0.0103 - val_loss: 2.9432e-04 - val_mean_absolute_error: 0.0144
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7262e-04 - mean_absolute_error: 0.0102 - val_loss: 2.8125e-04 - val_mean_absolute_error: 0.0141
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.6248e-04 - mean_absolute_error: 0.0099 - val_loss: 2.6336e-04 - val_mean_absolute_error: 0.0136
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5367e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4701e-04 - val_mean_absolute_error: 0.0132
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4481e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3400e-04 - val_mean_absolute_error: 0.0129
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4304e-04 - mean_absolute_error: 0.0094 - val_loss: 2.2729e-04 - val_mean_absolute_error: 0.0127
# Epoch 25/50
# 685/685 [==============================] - 11s 17ms/step - loss: 2.3197e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1778e-04 - val_mean_absolute_error: 0.0124
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2483e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9294e-04 - val_mean_absolute_error: 0.0114
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2569e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9457e-04 - val_mean_absolute_error: 0.0114
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1520e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9152e-04 - val_mean_absolute_error: 0.0112
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0864e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9324e-04 - val_mean_absolute_error: 0.0113
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0453e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8950e-04 - val_mean_absolute_error: 0.0111
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9687e-04 - mean_absolute_error: 0.0082 - val_loss: 1.8208e-04 - val_mean_absolute_error: 0.0108
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9290e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7567e-04 - val_mean_absolute_error: 0.0105
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9047e-04 - mean_absolute_error: 0.0079 - val_loss: 1.7318e-04 - val_mean_absolute_error: 0.0104
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8366e-04 - mean_absolute_error: 0.0078 - val_loss: 1.7516e-04 - val_mean_absolute_error: 0.0105
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8905e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8924e-04 - val_mean_absolute_error: 0.0111
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8601e-04 - mean_absolute_error: 0.0076 - val_loss: 2.0936e-04 - val_mean_absolute_error: 0.0118
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7976e-04 - mean_absolute_error: 0.0076 - val_loss: 1.8229e-04 - val_mean_absolute_error: 0.0109
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7784e-04 - mean_absolute_error: 0.0075 - val_loss: 1.7541e-04 - val_mean_absolute_error: 0.0107
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7756e-04 - mean_absolute_error: 0.0074 - val_loss: 1.6772e-04 - val_mean_absolute_error: 0.0104
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7709e-04 - mean_absolute_error: 0.0074 - val_loss: 1.7705e-04 - val_mean_absolute_error: 0.0108
# Epoch 41/50
# 685/685 [==============================] - 12s 18ms/step - loss: 1.7774e-04 - mean_absolute_error: 0.0074 - val_loss: 1.8348e-04 - val_mean_absolute_error: 0.0110
# Epoch 42/50
# 685/685 [==============================] - 12s 18ms/step - loss: 1.7648e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9140e-04 - val_mean_absolute_error: 0.0112
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6779e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9512e-04 - val_mean_absolute_error: 0.0114
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6599e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9465e-04 - val_mean_absolute_error: 0.0114
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6670e-04 - mean_absolute_error: 0.0071 - val_loss: 1.9749e-04 - val_mean_absolute_error: 0.0114
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6112e-04 - mean_absolute_error: 0.0070 - val_loss: 1.9489e-04 - val_mean_absolute_error: 0.0113
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6011e-04 - mean_absolute_error: 0.0070 - val_loss: 1.9984e-04 - val_mean_absolute_error: 0.0115
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6114e-04 - mean_absolute_error: 0.0069 - val_loss: 2.0036e-04 - val_mean_absolute_error: 0.0115
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6875e-04 - mean_absolute_error: 0.0069 - val_loss: 2.0296e-04 - val_mean_absolute_error: 0.0115
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5885e-04 - mean_absolute_error: 0.0069 - val_loss: 2.0265e-04 - val_mean_absolute_error: 0.0115
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 53.108191243216
#  LSTM의 MAPE : 6.782076481304783
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 19s 18ms/step - loss: 0.0044 - mean_absolute_error: 0.0411 - val_loss: 0.0030 - val_mean_absolute_error: 0.0494
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.8274e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0020 - val_mean_absolute_error: 0.0404
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0736e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0021 - val_mean_absolute_error: 0.0414
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.0002e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0024 - val_mean_absolute_error: 0.0450
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.4539e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0021 - val_mean_absolute_error: 0.0423
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9791e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0020 - val_mean_absolute_error: 0.0407
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.6432e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0018 - val_mean_absolute_error: 0.0382
# Epoch 8/50
# 685/685 [==============================] - 11s 17ms/step - loss: 4.3347e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.1061e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0016 - val_mean_absolute_error: 0.0366
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.9289e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0015 - val_mean_absolute_error: 0.0344
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.7221e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0014 - val_mean_absolute_error: 0.0334
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.5586e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0013 - val_mean_absolute_error: 0.0324
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.3723e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0015 - val_mean_absolute_error: 0.0353
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.2362e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0017 - val_mean_absolute_error: 0.0378
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.1570e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0014 - val_mean_absolute_error: 0.0334
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.0639e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0013 - val_mean_absolute_error: 0.0317
# Epoch 17/50
# 685/685 [==============================] - 14s 20ms/step - loss: 2.9636e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0013 - val_mean_absolute_error: 0.0326
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8754e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7983e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0012 - val_mean_absolute_error: 0.0301
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7129e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0016 - val_mean_absolute_error: 0.0361
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.6609e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0011 - val_mean_absolute_error: 0.0298
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5802e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0012 - val_mean_absolute_error: 0.0308
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5370e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0011 - val_mean_absolute_error: 0.0293
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4810e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0012 - val_mean_absolute_error: 0.0303
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4388e-04 - mean_absolute_error: 0.0109 - val_loss: 9.7294e-04 - val_mean_absolute_error: 0.0274
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.3822e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0013 - val_mean_absolute_error: 0.0322
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.3696e-04 - mean_absolute_error: 0.0107 - val_loss: 9.1904e-04 - val_mean_absolute_error: 0.0265
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.3240e-04 - mean_absolute_error: 0.0106 - val_loss: 8.7360e-04 - val_mean_absolute_error: 0.0257
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2721e-04 - mean_absolute_error: 0.0105 - val_loss: 8.0361e-04 - val_mean_absolute_error: 0.0244
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2356e-04 - mean_absolute_error: 0.0103 - val_loss: 8.3981e-04 - val_mean_absolute_error: 0.0253
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1857e-04 - mean_absolute_error: 0.0102 - val_loss: 8.4666e-04 - val_mean_absolute_error: 0.0254
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1162e-04 - mean_absolute_error: 0.0100 - val_loss: 8.8074e-04 - val_mean_absolute_error: 0.0260
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1005e-04 - mean_absolute_error: 0.0099 - val_loss: 7.9929e-04 - val_mean_absolute_error: 0.0246
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0433e-04 - mean_absolute_error: 0.0098 - val_loss: 7.8658e-04 - val_mean_absolute_error: 0.0246
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0062e-04 - mean_absolute_error: 0.0097 - val_loss: 7.6404e-04 - val_mean_absolute_error: 0.0242
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9769e-04 - mean_absolute_error: 0.0096 - val_loss: 6.9023e-04 - val_mean_absolute_error: 0.0230
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9380e-04 - mean_absolute_error: 0.0095 - val_loss: 6.4660e-04 - val_mean_absolute_error: 0.0222
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9048e-04 - mean_absolute_error: 0.0094 - val_loss: 6.1454e-04 - val_mean_absolute_error: 0.0215
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8806e-04 - mean_absolute_error: 0.0094 - val_loss: 5.8052e-04 - val_mean_absolute_error: 0.0208
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8450e-04 - mean_absolute_error: 0.0092 - val_loss: 5.9735e-04 - val_mean_absolute_error: 0.0212
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8177e-04 - mean_absolute_error: 0.0092 - val_loss: 5.5118e-04 - val_mean_absolute_error: 0.0201
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8025e-04 - mean_absolute_error: 0.0091 - val_loss: 5.6847e-04 - val_mean_absolute_error: 0.0205
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7837e-04 - mean_absolute_error: 0.0091 - val_loss: 5.6968e-04 - val_mean_absolute_error: 0.0205
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7604e-04 - mean_absolute_error: 0.0090 - val_loss: 5.3621e-04 - val_mean_absolute_error: 0.0197
# Epoch 45/50
# 685/685 [==============================] - 12s 17ms/step - loss: 1.7476e-04 - mean_absolute_error: 0.0090 - val_loss: 5.2872e-04 - val_mean_absolute_error: 0.0194
# Epoch 46/50
# 685/685 [==============================] - 13s 20ms/step - loss: 1.7228e-04 - mean_absolute_error: 0.0089 - val_loss: 4.9513e-04 - val_mean_absolute_error: 0.0186
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7029e-04 - mean_absolute_error: 0.0088 - val_loss: 4.7614e-04 - val_mean_absolute_error: 0.0182
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6726e-04 - mean_absolute_error: 0.0087 - val_loss: 6.0467e-04 - val_mean_absolute_error: 0.0215
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6596e-04 - mean_absolute_error: 0.0087 - val_loss: 4.4498e-04 - val_mean_absolute_error: 0.0175
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6381e-04 - mean_absolute_error: 0.0086 - val_loss: 4.4089e-04 - val_mean_absolute_error: 0.0175
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 6.769579849444418
#  LSTM의 MAPE : 17.01056047799432
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 19s 18ms/step - loss: 0.0036 - mean_absolute_error: 0.0361 - val_loss: 0.0019 - val_mean_absolute_error: 0.0380
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.2426e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0017 - val_mean_absolute_error: 0.0358
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.5720e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0017 - val_mean_absolute_error: 0.0353
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3444e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0014 - val_mean_absolute_error: 0.0324
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.8033e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0014 - val_mean_absolute_error: 0.0308
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.3285e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9096e-04 - mean_absolute_error: 0.0151 - val_loss: 9.2970e-04 - val_mean_absolute_error: 0.0250
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.6077e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0010 - val_mean_absolute_error: 0.0266
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.3614e-04 - mean_absolute_error: 0.0142 - val_loss: 8.9901e-04 - val_mean_absolute_error: 0.0255
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.1513e-04 - mean_absolute_error: 0.0138 - val_loss: 7.8705e-04 - val_mean_absolute_error: 0.0241
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.9362e-04 - mean_absolute_error: 0.0134 - val_loss: 6.6305e-04 - val_mean_absolute_error: 0.0221
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.7034e-04 - mean_absolute_error: 0.0130 - val_loss: 5.8052e-04 - val_mean_absolute_error: 0.0206
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.5178e-04 - mean_absolute_error: 0.0126 - val_loss: 5.4528e-04 - val_mean_absolute_error: 0.0200
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.3399e-04 - mean_absolute_error: 0.0123 - val_loss: 4.7516e-04 - val_mean_absolute_error: 0.0187
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.1715e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6402e-04 - val_mean_absolute_error: 0.0185
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.9990e-04 - mean_absolute_error: 0.0116 - val_loss: 4.5591e-04 - val_mean_absolute_error: 0.0183
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8655e-04 - mean_absolute_error: 0.0114 - val_loss: 4.3748e-04 - val_mean_absolute_error: 0.0179
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7731e-04 - mean_absolute_error: 0.0111 - val_loss: 4.5247e-04 - val_mean_absolute_error: 0.0181
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.6578e-04 - mean_absolute_error: 0.0109 - val_loss: 4.6524e-04 - val_mean_absolute_error: 0.0182
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5691e-04 - mean_absolute_error: 0.0107 - val_loss: 5.4743e-04 - val_mean_absolute_error: 0.0198
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5016e-04 - mean_absolute_error: 0.0105 - val_loss: 5.2036e-04 - val_mean_absolute_error: 0.0193
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4404e-04 - mean_absolute_error: 0.0104 - val_loss: 5.0216e-04 - val_mean_absolute_error: 0.0189
# Epoch 23/50
# 685/685 [==============================] - 11s 17ms/step - loss: 2.3777e-04 - mean_absolute_error: 0.0103 - val_loss: 4.6113e-04 - val_mean_absolute_error: 0.0181
# Epoch 24/50
# 685/685 [==============================] - 14s 21ms/step - loss: 2.3182e-04 - mean_absolute_error: 0.0101 - val_loss: 4.3350e-04 - val_mean_absolute_error: 0.0175
# Epoch 25/50
# 685/685 [==============================] - 11s 17ms/step - loss: 2.2642e-04 - mean_absolute_error: 0.0100 - val_loss: 4.1140e-04 - val_mean_absolute_error: 0.0169
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2080e-04 - mean_absolute_error: 0.0098 - val_loss: 3.9624e-04 - val_mean_absolute_error: 0.0166
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1436e-04 - mean_absolute_error: 0.0097 - val_loss: 3.9472e-04 - val_mean_absolute_error: 0.0165
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0862e-04 - mean_absolute_error: 0.0096 - val_loss: 3.7961e-04 - val_mean_absolute_error: 0.0161
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0325e-04 - mean_absolute_error: 0.0095 - val_loss: 3.6480e-04 - val_mean_absolute_error: 0.0157
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9837e-04 - mean_absolute_error: 0.0093 - val_loss: 3.6210e-04 - val_mean_absolute_error: 0.0156
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9404e-04 - mean_absolute_error: 0.0092 - val_loss: 3.6006e-04 - val_mean_absolute_error: 0.0157
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8962e-04 - mean_absolute_error: 0.0091 - val_loss: 3.4517e-04 - val_mean_absolute_error: 0.0153
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8450e-04 - mean_absolute_error: 0.0090 - val_loss: 3.6277e-04 - val_mean_absolute_error: 0.0157
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8073e-04 - mean_absolute_error: 0.0089 - val_loss: 3.7371e-04 - val_mean_absolute_error: 0.0160
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7675e-04 - mean_absolute_error: 0.0089 - val_loss: 3.6665e-04 - val_mean_absolute_error: 0.0159
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7246e-04 - mean_absolute_error: 0.0088 - val_loss: 3.5321e-04 - val_mean_absolute_error: 0.0155
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6866e-04 - mean_absolute_error: 0.0087 - val_loss: 3.4864e-04 - val_mean_absolute_error: 0.0154
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6521e-04 - mean_absolute_error: 0.0086 - val_loss: 3.4642e-04 - val_mean_absolute_error: 0.0153
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6213e-04 - mean_absolute_error: 0.0085 - val_loss: 3.4650e-04 - val_mean_absolute_error: 0.0153
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5933e-04 - mean_absolute_error: 0.0085 - val_loss: 3.4249e-04 - val_mean_absolute_error: 0.0152
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5701e-04 - mean_absolute_error: 0.0084 - val_loss: 3.3830e-04 - val_mean_absolute_error: 0.0152
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5485e-04 - mean_absolute_error: 0.0084 - val_loss: 3.3991e-04 - val_mean_absolute_error: 0.0152
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5284e-04 - mean_absolute_error: 0.0083 - val_loss: 3.3752e-04 - val_mean_absolute_error: 0.0151
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5076e-04 - mean_absolute_error: 0.0082 - val_loss: 3.3549e-04 - val_mean_absolute_error: 0.0151
# Epoch 45/50
# 685/685 [==============================] - 11s 17ms/step - loss: 1.4898e-04 - mean_absolute_error: 0.0082 - val_loss: 3.2881e-04 - val_mean_absolute_error: 0.0150
# Epoch 46/50
# 685/685 [==============================] - 11s 17ms/step - loss: 1.4691e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4322e-04 - val_mean_absolute_error: 0.0154
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4463e-04 - mean_absolute_error: 0.0081 - val_loss: 3.3785e-04 - val_mean_absolute_error: 0.0153
# Epoch 48/50
# 685/685 [==============================] - 11s 17ms/step - loss: 1.4240e-04 - mean_absolute_error: 0.0080 - val_loss: 3.3189e-04 - val_mean_absolute_error: 0.0151
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4087e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3470e-04 - val_mean_absolute_error: 0.0152
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4043e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2767e-04 - val_mean_absolute_error: 0.0150
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 41.26531208883581
#  LSTM의 MAPE : 7.397934152754412
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# train_1 학습
model_1 = create_gru(64, x_train_1)
history_gru_1 = fit_model(model_1, x_train_1, y_train_1, 50, x_val_1, y_val_1)
print('-'*150)

pred_gru_1 = model_1.predict(x_val_1) # 2018년 예측
re_y_val_1 = np.insert(re_y_val_1, 0, pred_gru_1.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_gru_1 = scaler_num[1].inverse_transform(re_y_val_1) # inverse transform


re_y_val_1 = np.delete(re_y_val_1,0,1)
re_y_val_1 = np.insert(re_y_val_1, 0, y_val_1.T, axis = 1)

y_val_1 = scaler_num[1].inverse_transform(re_y_val_1)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_gru_1.T[0], y_val_1.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_gru_1.T[0],  y_val_1.T[0])))
print('-'*150)

# train_2 학습
model_2 = create_gru(64, x_train_2)
history_gru_2 = fit_model(model_2, x_train_2, y_train_2, 50, x_val_2, y_val_2)
print('-'*150)

pred_gru_2 = model_2.predict(x_val_2) # 2018년 예측
re_y_val_2 = np.insert(re_y_val_2, 0, pred_gru_2.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_gru_2 = scaler_num[2].inverse_transform(re_y_val_2) # inverse transform


re_y_val_2 = np.delete(re_y_val_2,0,1)
re_y_val_2 = np.insert(re_y_val_2, 0, y_val_2.T, axis = 1)

y_val_2 = scaler_num[2].inverse_transform(re_y_val_2)

print("gru의 RMSE : {}".format(mean_squared_error(pred_gru_2.T[0], y_val_2.T[0])**0.5),'\n', 'gru의 MAPE : {}'.format(mape(pred_gru_2.T[0],  y_val_2.T[0])))
print('-'*150)

# train_3 학습
model_3 = create_gru(64, x_train_3)
history_gru_3 = fit_model(model_3, x_train_3, y_train_3, 50, x_val_3, y_val_3)
print('-'*150)

pred_gru_3 = model_3.predict(x_val_3) # 2018년 예측
re_y_val_3 = np.insert(re_y_val_3, 0, pred_gru_3.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_gru_3 = scaler_num[3].inverse_transform(re_y_val_3) # inverse transform


re_y_val_3 = np.delete(re_y_val_3,0,1)
re_y_val_3 = np.insert(re_y_val_3, 0, y_val_3.T, axis = 1)

y_val_3 = scaler_num[3].inverse_transform(re_y_val_3)

print("gru의 RMSE : {}".format(mean_squared_error(pred_gru_3.T[0], y_val_3.T[0])**0.5),'\n', 'gru의 MAPE : {}'.format(mape(pred_gru_3.T[0],  y_val_3.T[0])))
print('-'*150)
# Out:
# Epoch 1/50
# 685/685 [==============================] - 19s 18ms/step - loss: 0.0031 - mean_absolute_error: 0.0315 - val_loss: 0.0027 - val_mean_absolute_error: 0.0462
# Epoch 2/50
# 685/685 [==============================] - 10s 15ms/step - loss: 0.0010 - mean_absolute_error: 0.0217 - val_loss: 0.0019 - val_mean_absolute_error: 0.0386
# Epoch 3/50
# 685/685 [==============================] - 11s 15ms/step - loss: 8.0851e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0015 - val_mean_absolute_error: 0.0333
# Epoch 4/50
# 685/685 [==============================] - 11s 15ms/step - loss: 7.0930e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0011 - val_mean_absolute_error: 0.0275
# Epoch 5/50
# 685/685 [==============================] - 11s 15ms/step - loss: 6.3183e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0011 - val_mean_absolute_error: 0.0270
# Epoch 6/50
# 685/685 [==============================] - 11s 15ms/step - loss: 5.7151e-04 - mean_absolute_error: 0.0157 - val_loss: 9.5179e-04 - val_mean_absolute_error: 0.0249
# Epoch 7/50
# 685/685 [==============================] - 11s 15ms/step - loss: 5.2422e-04 - mean_absolute_error: 0.0151 - val_loss: 7.5584e-04 - val_mean_absolute_error: 0.0223
# Epoch 8/50
# 685/685 [==============================] - 11s 15ms/step - loss: 4.7795e-04 - mean_absolute_error: 0.0143 - val_loss: 5.5665e-04 - val_mean_absolute_error: 0.0189
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.4069e-04 - mean_absolute_error: 0.0136 - val_loss: 4.7951e-04 - val_mean_absolute_error: 0.0178
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.9974e-04 - mean_absolute_error: 0.0129 - val_loss: 4.5450e-04 - val_mean_absolute_error: 0.0176
# Epoch 11/50
# 685/685 [==============================] - 11s 15ms/step - loss: 3.5155e-04 - mean_absolute_error: 0.0119 - val_loss: 3.9810e-04 - val_mean_absolute_error: 0.0164
# Epoch 12/50
# 685/685 [==============================] - 11s 15ms/step - loss: 3.1784e-04 - mean_absolute_error: 0.0112 - val_loss: 4.0542e-04 - val_mean_absolute_error: 0.0165
# Epoch 13/50
# 685/685 [==============================] - 11s 15ms/step - loss: 3.0155e-04 - mean_absolute_error: 0.0107 - val_loss: 3.9889e-04 - val_mean_absolute_error: 0.0165
# Epoch 14/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.8550e-04 - mean_absolute_error: 0.0104 - val_loss: 4.0426e-04 - val_mean_absolute_error: 0.0165
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7177e-04 - mean_absolute_error: 0.0100 - val_loss: 3.9986e-04 - val_mean_absolute_error: 0.0165
# Epoch 16/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.6163e-04 - mean_absolute_error: 0.0097 - val_loss: 4.0553e-04 - val_mean_absolute_error: 0.0164
# Epoch 17/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.5210e-04 - mean_absolute_error: 0.0094 - val_loss: 4.1113e-04 - val_mean_absolute_error: 0.0163
# Epoch 18/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.4444e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7217e-04 - val_mean_absolute_error: 0.0149
# Epoch 19/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.3666e-04 - mean_absolute_error: 0.0090 - val_loss: 3.7134e-04 - val_mean_absolute_error: 0.0148
# Epoch 20/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.3058e-04 - mean_absolute_error: 0.0088 - val_loss: 3.6296e-04 - val_mean_absolute_error: 0.0146
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2348e-04 - mean_absolute_error: 0.0086 - val_loss: 3.5494e-04 - val_mean_absolute_error: 0.0145
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1850e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9303e-04 - val_mean_absolute_error: 0.0157
# Epoch 23/50
# 685/685 [==============================] - 13s 19ms/step - loss: 2.1335e-04 - mean_absolute_error: 0.0084 - val_loss: 3.7502e-04 - val_mean_absolute_error: 0.0150
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0704e-04 - mean_absolute_error: 0.0083 - val_loss: 3.4728e-04 - val_mean_absolute_error: 0.0140
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9959e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4536e-04 - val_mean_absolute_error: 0.0140
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9872e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9009e-04 - val_mean_absolute_error: 0.0128
# Epoch 27/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.9487e-04 - mean_absolute_error: 0.0080 - val_loss: 2.7848e-04 - val_mean_absolute_error: 0.0124
# Epoch 28/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.8907e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7480e-04 - val_mean_absolute_error: 0.0123
# Epoch 29/50
# 685/685 [==============================] - 12s 18ms/step - loss: 1.8944e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8939e-04 - val_mean_absolute_error: 0.0126
# Epoch 30/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.8092e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1216e-04 - val_mean_absolute_error: 0.0132
# Epoch 31/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.7785e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2109e-04 - val_mean_absolute_error: 0.0135
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7829e-04 - mean_absolute_error: 0.0076 - val_loss: 3.6209e-04 - val_mean_absolute_error: 0.0146
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7545e-04 - mean_absolute_error: 0.0075 - val_loss: 3.6170e-04 - val_mean_absolute_error: 0.0142
# Epoch 34/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.7498e-04 - mean_absolute_error: 0.0075 - val_loss: 3.4510e-04 - val_mean_absolute_error: 0.0137
# Epoch 35/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.7261e-04 - mean_absolute_error: 0.0074 - val_loss: 3.3496e-04 - val_mean_absolute_error: 0.0136
# Epoch 36/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.6561e-04 - mean_absolute_error: 0.0074 - val_loss: 3.3809e-04 - val_mean_absolute_error: 0.0141
# Epoch 37/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.6281e-04 - mean_absolute_error: 0.0073 - val_loss: 3.4476e-04 - val_mean_absolute_error: 0.0146
# Epoch 38/50
# 685/685 [==============================] - 9s 13ms/step - loss: 1.6092e-04 - mean_absolute_error: 0.0072 - val_loss: 3.4758e-04 - val_mean_absolute_error: 0.0147
# Epoch 39/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.6294e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2632e-04 - val_mean_absolute_error: 0.0142
# Epoch 40/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.6079e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2622e-04 - val_mean_absolute_error: 0.0141
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5916e-04 - mean_absolute_error: 0.0071 - val_loss: 2.5742e-04 - val_mean_absolute_error: 0.0116
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5558e-04 - mean_absolute_error: 0.0070 - val_loss: 3.4425e-04 - val_mean_absolute_error: 0.0142
# Epoch 43/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5488e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8654e-04 - val_mean_absolute_error: 0.0126
# Epoch 44/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5143e-04 - mean_absolute_error: 0.0070 - val_loss: 2.5828e-04 - val_mean_absolute_error: 0.0117
# Epoch 45/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.4641e-04 - mean_absolute_error: 0.0069 - val_loss: 2.5757e-04 - val_mean_absolute_error: 0.0117
# Epoch 46/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5087e-04 - mean_absolute_error: 0.0069 - val_loss: 2.4439e-04 - val_mean_absolute_error: 0.0113
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6358e-04 - mean_absolute_error: 0.0068 - val_loss: 2.5601e-04 - val_mean_absolute_error: 0.0116
# Epoch 48/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.4594e-04 - mean_absolute_error: 0.0068 - val_loss: 2.4727e-04 - val_mean_absolute_error: 0.0114
# Epoch 49/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5759e-04 - mean_absolute_error: 0.0068 - val_loss: 2.4481e-04 - val_mean_absolute_error: 0.0114
# Epoch 50/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.4598e-04 - mean_absolute_error: 0.0067 - val_loss: 2.4553e-04 - val_mean_absolute_error: 0.0113
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 58.456912395676795
#  LSTM의 MAPE : 5.785473921711437
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 18s 17ms/step - loss: 0.0034 - mean_absolute_error: 0.0374 - val_loss: 0.0045 - val_mean_absolute_error: 0.0606
# Epoch 2/50
# 685/685 [==============================] - 11s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0247 - val_loss: 0.0017 - val_mean_absolute_error: 0.0365
# Epoch 3/50
# 685/685 [==============================] - 11s 15ms/step - loss: 8.0054e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0033 - val_mean_absolute_error: 0.0527
# Epoch 4/50
# 685/685 [==============================] - 11s 15ms/step - loss: 6.9601e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0024 - val_mean_absolute_error: 0.0450
# Epoch 5/50
# 685/685 [==============================] - 11s 15ms/step - loss: 6.3315e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0016 - val_mean_absolute_error: 0.0364
# Epoch 6/50
# 685/685 [==============================] - 11s 15ms/step - loss: 5.8226e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0013 - val_mean_absolute_error: 0.0326
# Epoch 7/50
# 685/685 [==============================] - 14s 20ms/step - loss: 5.3133e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0013 - val_mean_absolute_error: 0.0329
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9262e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0013 - val_mean_absolute_error: 0.0331
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.5513e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0015 - val_mean_absolute_error: 0.0353
# Epoch 10/50
# 685/685 [==============================] - 13s 18ms/step - loss: 4.2336e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0016 - val_mean_absolute_error: 0.0371
# Epoch 11/50
# 685/685 [==============================] - 11s 15ms/step - loss: 3.9324e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0017 - val_mean_absolute_error: 0.0383
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.6896e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0018 - val_mean_absolute_error: 0.0396
# Epoch 13/50
# 685/685 [==============================] - 10s 15ms/step - loss: 3.5383e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0017 - val_mean_absolute_error: 0.0375
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.3961e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0015 - val_mean_absolute_error: 0.0354
# Epoch 15/50
# 685/685 [==============================] - 12s 18ms/step - loss: 3.2523e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0015 - val_mean_absolute_error: 0.0361
# Epoch 16/50
# 685/685 [==============================] - 12s 18ms/step - loss: 3.1103e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0016 - val_mean_absolute_error: 0.0369
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.9895e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0015 - val_mean_absolute_error: 0.0353
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8881e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0015 - val_mean_absolute_error: 0.0356
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.7522e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0015 - val_mean_absolute_error: 0.0358
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.6294e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0012 - val_mean_absolute_error: 0.0322
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.5260e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0014 - val_mean_absolute_error: 0.0341
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4104e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0013 - val_mean_absolute_error: 0.0335
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.3490e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0012 - val_mean_absolute_error: 0.0312
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2597e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0011 - val_mean_absolute_error: 0.0296
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1967e-04 - mean_absolute_error: 0.0102 - val_loss: 9.2519e-04 - val_mean_absolute_error: 0.0272
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1251e-04 - mean_absolute_error: 0.0101 - val_loss: 8.5875e-04 - val_mean_absolute_error: 0.0259
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0561e-04 - mean_absolute_error: 0.0099 - val_loss: 8.6989e-04 - val_mean_absolute_error: 0.0262
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0099e-04 - mean_absolute_error: 0.0098 - val_loss: 8.0723e-04 - val_mean_absolute_error: 0.0252
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9624e-04 - mean_absolute_error: 0.0096 - val_loss: 7.4414e-04 - val_mean_absolute_error: 0.0238
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9313e-04 - mean_absolute_error: 0.0095 - val_loss: 7.1697e-04 - val_mean_absolute_error: 0.0235
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8763e-04 - mean_absolute_error: 0.0093 - val_loss: 6.7545e-04 - val_mean_absolute_error: 0.0226
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8307e-04 - mean_absolute_error: 0.0092 - val_loss: 6.5283e-04 - val_mean_absolute_error: 0.0221
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7885e-04 - mean_absolute_error: 0.0091 - val_loss: 6.1530e-04 - val_mean_absolute_error: 0.0212
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7524e-04 - mean_absolute_error: 0.0090 - val_loss: 5.8837e-04 - val_mean_absolute_error: 0.0206
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7207e-04 - mean_absolute_error: 0.0089 - val_loss: 5.8151e-04 - val_mean_absolute_error: 0.0205
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6927e-04 - mean_absolute_error: 0.0088 - val_loss: 5.7793e-04 - val_mean_absolute_error: 0.0204
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6659e-04 - mean_absolute_error: 0.0087 - val_loss: 5.7781e-04 - val_mean_absolute_error: 0.0205
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6416e-04 - mean_absolute_error: 0.0087 - val_loss: 5.9710e-04 - val_mean_absolute_error: 0.0211
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6263e-04 - mean_absolute_error: 0.0086 - val_loss: 5.8679e-04 - val_mean_absolute_error: 0.0208
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5957e-04 - mean_absolute_error: 0.0085 - val_loss: 5.8513e-04 - val_mean_absolute_error: 0.0208
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5789e-04 - mean_absolute_error: 0.0085 - val_loss: 5.8258e-04 - val_mean_absolute_error: 0.0207
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5638e-04 - mean_absolute_error: 0.0084 - val_loss: 5.5632e-04 - val_mean_absolute_error: 0.0201
# Epoch 43/50
# 685/685 [==============================] - 14s 20ms/step - loss: 1.5448e-04 - mean_absolute_error: 0.0084 - val_loss: 5.3450e-04 - val_mean_absolute_error: 0.0195
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5286e-04 - mean_absolute_error: 0.0083 - val_loss: 5.0893e-04 - val_mean_absolute_error: 0.0189
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5140e-04 - mean_absolute_error: 0.0082 - val_loss: 4.8156e-04 - val_mean_absolute_error: 0.0182
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5026e-04 - mean_absolute_error: 0.0082 - val_loss: 4.6377e-04 - val_mean_absolute_error: 0.0176
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4901e-04 - mean_absolute_error: 0.0082 - val_loss: 4.6707e-04 - val_mean_absolute_error: 0.0177
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4771e-04 - mean_absolute_error: 0.0081 - val_loss: 4.7439e-04 - val_mean_absolute_error: 0.0178
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4627e-04 - mean_absolute_error: 0.0080 - val_loss: 4.9934e-04 - val_mean_absolute_error: 0.0184
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4525e-04 - mean_absolute_error: 0.0080 - val_loss: 4.7117e-04 - val_mean_absolute_error: 0.0176
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# gru의 RMSE : 6.998126367992523
#  gru의 MAPE : 19.810282270948864
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 20s 18ms/step - loss: 0.0034 - mean_absolute_error: 0.0336 - val_loss: 0.0022 - val_mean_absolute_error: 0.0412
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.5105e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0011 - val_mean_absolute_error: 0.0293
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.6802e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0016 - val_mean_absolute_error: 0.0341
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.4088e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0016 - val_mean_absolute_error: 0.0332
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.8645e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.4038e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9091e-04 - mean_absolute_error: 0.0155 - val_loss: 8.7013e-04 - val_mean_absolute_error: 0.0243
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.4622e-04 - mean_absolute_error: 0.0147 - val_loss: 8.9656e-04 - val_mean_absolute_error: 0.0252
# Epoch 9/50
# 685/685 [==============================] - 12s 17ms/step - loss: 4.1697e-04 - mean_absolute_error: 0.0142 - val_loss: 8.1996e-04 - val_mean_absolute_error: 0.0243
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.8996e-04 - mean_absolute_error: 0.0137 - val_loss: 7.2675e-04 - val_mean_absolute_error: 0.0229
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.5873e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6436e-04 - val_mean_absolute_error: 0.0176
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.3618e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6928e-04 - val_mean_absolute_error: 0.0156
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.1367e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2750e-04 - val_mean_absolute_error: 0.0146
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.9722e-04 - mean_absolute_error: 0.0118 - val_loss: 3.4769e-04 - val_mean_absolute_error: 0.0152
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8139e-04 - mean_absolute_error: 0.0114 - val_loss: 3.5518e-04 - val_mean_absolute_error: 0.0153
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.6974e-04 - mean_absolute_error: 0.0112 - val_loss: 4.0455e-04 - val_mean_absolute_error: 0.0166
# Epoch 17/50
# 685/685 [==============================] - 10s 15ms/step - loss: 2.5639e-04 - mean_absolute_error: 0.0109 - val_loss: 4.1559e-04 - val_mean_absolute_error: 0.0169
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4455e-04 - mean_absolute_error: 0.0107 - val_loss: 4.2530e-04 - val_mean_absolute_error: 0.0172
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.3182e-04 - mean_absolute_error: 0.0104 - val_loss: 4.4393e-04 - val_mean_absolute_error: 0.0175
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2422e-04 - mean_absolute_error: 0.0102 - val_loss: 4.3541e-04 - val_mean_absolute_error: 0.0172
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1501e-04 - mean_absolute_error: 0.0100 - val_loss: 4.2624e-04 - val_mean_absolute_error: 0.0169
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0678e-04 - mean_absolute_error: 0.0098 - val_loss: 4.1002e-04 - val_mean_absolute_error: 0.0163
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9858e-04 - mean_absolute_error: 0.0096 - val_loss: 4.3123e-04 - val_mean_absolute_error: 0.0169
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8998e-04 - mean_absolute_error: 0.0093 - val_loss: 3.9637e-04 - val_mean_absolute_error: 0.0160
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8311e-04 - mean_absolute_error: 0.0092 - val_loss: 3.8530e-04 - val_mean_absolute_error: 0.0157
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7799e-04 - mean_absolute_error: 0.0090 - val_loss: 3.7240e-04 - val_mean_absolute_error: 0.0153
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7436e-04 - mean_absolute_error: 0.0089 - val_loss: 3.6822e-04 - val_mean_absolute_error: 0.0152
# Epoch 28/50
# 685/685 [==============================] - 14s 20ms/step - loss: 1.7039e-04 - mean_absolute_error: 0.0088 - val_loss: 3.6822e-04 - val_mean_absolute_error: 0.0153
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6684e-04 - mean_absolute_error: 0.0087 - val_loss: 3.7567e-04 - val_mean_absolute_error: 0.0156
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6464e-04 - mean_absolute_error: 0.0086 - val_loss: 3.4808e-04 - val_mean_absolute_error: 0.0149
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6138e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2910e-04 - val_mean_absolute_error: 0.0144
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5822e-04 - mean_absolute_error: 0.0084 - val_loss: 3.2294e-04 - val_mean_absolute_error: 0.0142
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5514e-04 - mean_absolute_error: 0.0083 - val_loss: 3.2333e-04 - val_mean_absolute_error: 0.0141
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5252e-04 - mean_absolute_error: 0.0082 - val_loss: 3.1531e-04 - val_mean_absolute_error: 0.0139
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4989e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0799e-04 - val_mean_absolute_error: 0.0137
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4738e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9984e-04 - val_mean_absolute_error: 0.0135
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4529e-04 - mean_absolute_error: 0.0080 - val_loss: 2.8790e-04 - val_mean_absolute_error: 0.0129
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4345e-04 - mean_absolute_error: 0.0079 - val_loss: 2.8954e-04 - val_mean_absolute_error: 0.0132
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4158e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7836e-04 - val_mean_absolute_error: 0.0128
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4045e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8391e-04 - val_mean_absolute_error: 0.0130
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3870e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8484e-04 - val_mean_absolute_error: 0.0130
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3749e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8988e-04 - val_mean_absolute_error: 0.0132
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3633e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9286e-04 - val_mean_absolute_error: 0.0132
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3562e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0898e-04 - val_mean_absolute_error: 0.0136
# Epoch 45/50
# 685/685 [==============================] - 11s 17ms/step - loss: 1.3546e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1345e-04 - val_mean_absolute_error: 0.0137
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3477e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1749e-04 - val_mean_absolute_error: 0.0136
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3383e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0672e-04 - val_mean_absolute_error: 0.0133
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3305e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1483e-04 - val_mean_absolute_error: 0.0136
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3253e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2219e-04 - val_mean_absolute_error: 0.0137
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3250e-04 - mean_absolute_error: 0.0075 - val_loss: 3.3186e-04 - val_mean_absolute_error: 0.0140
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# gru의 RMSE : 41.52851656104505
#  gru의 MAPE : 6.130066171905822
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# train_4 학습
model_4 = create_bilstm(64, x_train_4)
history_lstm_4 = fit_model(model_4, x_train_4, y_train_4, 50, x_val_4, y_val_4)

print('-'*150)
pred_lstm_4 = model_4.predict(x_val_4) # 2018년 예측
re_y_val_4 = np.insert(re_y_val_4, 0, pred_lstm_4.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_4 = scaler_num[4].inverse_transform(re_y_val_4) # inverse transform


re_y_val_4 = np.delete(re_y_val_4,0,1)
re_y_val_4 = np.insert(re_y_val_4, 0, y_val_4.T, axis = 1)

y_val_4 = scaler_num[4].inverse_transform(re_y_val_4)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_4.T[0], y_val_4.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_4.T[0],  y_val_4.T[0])))
print('-'*150)



# train_5 학습
model_5 = create_bilstm(64, x_train_5)
history_lstm_5 = fit_model(model_5, x_train_5, y_train_5, 50, x_val_5, y_val_5)

print('-'*150)
pred_lstm_5 = model_5.predict(x_val_5) # 2018년 예측
re_y_val_5 = np.insert(re_y_val_5, 0, pred_lstm_5.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_5 = scaler_num[5].inverse_transform(re_y_val_5) # inverse transform


re_y_val_5 = np.delete(re_y_val_5,0,1)
re_y_val_5 = np.insert(re_y_val_5, 0, y_val_5.T, axis = 1)

y_val_5 = scaler_num[5].inverse_transform(re_y_val_5)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_5.T[0], y_val_5.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_5.T[0],  y_val_5.T[0])))
print('-'*150)


# train_6 학습
model_6 = create_bilstm(64, x_train_6)
history_lstm_6 = fit_model(model_6, x_train_6, y_train_6, 50, x_val_6, y_val_6)
print('-'*150)

pred_lstm_6 = model_6.predict(x_val_6) # 2018년 예측
re_y_val_6 = np.insert(re_y_val_6, 0, pred_lstm_6.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_lstm_6 = scaler_num[6].inverse_transform(re_y_val_6) # inverse transform


re_y_val_6 = np.delete(re_y_val_6,0,1)
re_y_val_6 = np.insert(re_y_val_6, 0, y_val_6.T, axis = 1)

y_val_6 = scaler_num[6].inverse_transform(re_y_val_6)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_6.T[0], y_val_6.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_6.T[0],  y_val_6.T[0])))
print('-'*150)
# Out:
# Epoch 1/50
# 685/685 [==============================] - 19s 19ms/step - loss: 0.0037 - mean_absolute_error: 0.0349 - val_loss: 0.0024 - val_mean_absolute_error: 0.0432
# Epoch 2/50
# 685/685 [==============================] - 12s 17ms/step - loss: 8.5606e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0021 - val_mean_absolute_error: 0.0408
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.6086e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0018 - val_mean_absolute_error: 0.0374
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 5.3862e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0015 - val_mean_absolute_error: 0.0340
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.9351e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0013 - val_mean_absolute_error: 0.0308
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.6101e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.3967e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0010 - val_mean_absolute_error: 0.0272
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 4.1937e-04 - mean_absolute_error: 0.0144 - val_loss: 8.8154e-04 - val_mean_absolute_error: 0.0254
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.9829e-04 - mean_absolute_error: 0.0141 - val_loss: 8.5720e-04 - val_mean_absolute_error: 0.0250
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.8586e-04 - mean_absolute_error: 0.0139 - val_loss: 7.2522e-04 - val_mean_absolute_error: 0.0228
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.6410e-04 - mean_absolute_error: 0.0136 - val_loss: 7.7268e-04 - val_mean_absolute_error: 0.0238
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.3339e-04 - mean_absolute_error: 0.0131 - val_loss: 7.5612e-04 - val_mean_absolute_error: 0.0237
# Epoch 13/50
# 685/685 [==============================] - 14s 20ms/step - loss: 3.1251e-04 - mean_absolute_error: 0.0126 - val_loss: 6.4639e-04 - val_mean_absolute_error: 0.0219
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.8306e-04 - mean_absolute_error: 0.0119 - val_loss: 4.9535e-04 - val_mean_absolute_error: 0.0187
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4495e-04 - mean_absolute_error: 0.0111 - val_loss: 4.5090e-04 - val_mean_absolute_error: 0.0176
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2586e-04 - mean_absolute_error: 0.0107 - val_loss: 4.5167e-04 - val_mean_absolute_error: 0.0173
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.1433e-04 - mean_absolute_error: 0.0104 - val_loss: 4.2376e-04 - val_mean_absolute_error: 0.0168
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0447e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3382e-04 - val_mean_absolute_error: 0.0147
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9881e-04 - mean_absolute_error: 0.0099 - val_loss: 3.5106e-04 - val_mean_absolute_error: 0.0152
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9039e-04 - mean_absolute_error: 0.0096 - val_loss: 3.4966e-04 - val_mean_absolute_error: 0.0152
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8463e-04 - mean_absolute_error: 0.0095 - val_loss: 3.6144e-04 - val_mean_absolute_error: 0.0155
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7938e-04 - mean_absolute_error: 0.0093 - val_loss: 3.2749e-04 - val_mean_absolute_error: 0.0145
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7498e-04 - mean_absolute_error: 0.0092 - val_loss: 3.2487e-04 - val_mean_absolute_error: 0.0144
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7112e-04 - mean_absolute_error: 0.0091 - val_loss: 3.4094e-04 - val_mean_absolute_error: 0.0150
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6783e-04 - mean_absolute_error: 0.0090 - val_loss: 3.3506e-04 - val_mean_absolute_error: 0.0148
# Epoch 26/50
# 685/685 [==============================] - 12s 17ms/step - loss: 1.6303e-04 - mean_absolute_error: 0.0089 - val_loss: 3.4344e-04 - val_mean_absolute_error: 0.0150
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6052e-04 - mean_absolute_error: 0.0088 - val_loss: 3.2655e-04 - val_mean_absolute_error: 0.0145
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5732e-04 - mean_absolute_error: 0.0087 - val_loss: 3.1112e-04 - val_mean_absolute_error: 0.0141
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5194e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0166e-04 - val_mean_absolute_error: 0.0137
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4896e-04 - mean_absolute_error: 0.0085 - val_loss: 3.1175e-04 - val_mean_absolute_error: 0.0140
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4617e-04 - mean_absolute_error: 0.0084 - val_loss: 2.9268e-04 - val_mean_absolute_error: 0.0135
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4355e-04 - mean_absolute_error: 0.0083 - val_loss: 2.8498e-04 - val_mean_absolute_error: 0.0134
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4131e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4826e-04 - val_mean_absolute_error: 0.0125
# Epoch 34/50
# 685/685 [==============================] - 11s 17ms/step - loss: 1.3840e-04 - mean_absolute_error: 0.0081 - val_loss: 2.2360e-04 - val_mean_absolute_error: 0.0118
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3507e-04 - mean_absolute_error: 0.0081 - val_loss: 2.2962e-04 - val_mean_absolute_error: 0.0119
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3194e-04 - mean_absolute_error: 0.0080 - val_loss: 2.2577e-04 - val_mean_absolute_error: 0.0119
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2880e-04 - mean_absolute_error: 0.0079 - val_loss: 2.2445e-04 - val_mean_absolute_error: 0.0118
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2593e-04 - mean_absolute_error: 0.0078 - val_loss: 2.2395e-04 - val_mean_absolute_error: 0.0118
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2315e-04 - mean_absolute_error: 0.0077 - val_loss: 2.1645e-04 - val_mean_absolute_error: 0.0116
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2077e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1790e-04 - val_mean_absolute_error: 0.0116
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1879e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1611e-04 - val_mean_absolute_error: 0.0116
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1706e-04 - mean_absolute_error: 0.0075 - val_loss: 2.0875e-04 - val_mean_absolute_error: 0.0113
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1541e-04 - mean_absolute_error: 0.0075 - val_loss: 2.0441e-04 - val_mean_absolute_error: 0.0112
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1402e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0666e-04 - val_mean_absolute_error: 0.0113
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1275e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0451e-04 - val_mean_absolute_error: 0.0112
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1140e-04 - mean_absolute_error: 0.0073 - val_loss: 2.0247e-04 - val_mean_absolute_error: 0.0112
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1013e-04 - mean_absolute_error: 0.0073 - val_loss: 2.0222e-04 - val_mean_absolute_error: 0.0112
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0876e-04 - mean_absolute_error: 0.0072 - val_loss: 2.0278e-04 - val_mean_absolute_error: 0.0112
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0741e-04 - mean_absolute_error: 0.0072 - val_loss: 2.0386e-04 - val_mean_absolute_error: 0.0113
# Epoch 50/50
# 685/685 [==============================] - 14s 20ms/step - loss: 1.0643e-04 - mean_absolute_error: 0.0072 - val_loss: 2.0829e-04 - val_mean_absolute_error: 0.0114
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 68.51714329235512
#  LSTM의 MAPE : 5.068824968784736
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 20s 20ms/step - loss: 0.0013 - mean_absolute_error: 0.0228 - val_loss: 5.4842e-04 - val_mean_absolute_error: 0.0202
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.9293e-04 - mean_absolute_error: 0.0134 - val_loss: 5.7720e-04 - val_mean_absolute_error: 0.0210
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.0595e-04 - mean_absolute_error: 0.0113 - val_loss: 4.1580e-04 - val_mean_absolute_error: 0.0173
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.6414e-04 - mean_absolute_error: 0.0101 - val_loss: 3.2337e-04 - val_mean_absolute_error: 0.0148
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.4358e-04 - mean_absolute_error: 0.0094 - val_loss: 2.7241e-04 - val_mean_absolute_error: 0.0131
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.2585e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1696e-04 - val_mean_absolute_error: 0.0113
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 2.0997e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9629e-04 - val_mean_absolute_error: 0.0105
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9872e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7410e-04 - val_mean_absolute_error: 0.0101
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8967e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7307e-04 - val_mean_absolute_error: 0.0100
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8033e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7263e-04 - val_mean_absolute_error: 0.0101
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7398e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5688e-04 - val_mean_absolute_error: 0.0095
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6786e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6033e-04 - val_mean_absolute_error: 0.0097
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.6188e-04 - mean_absolute_error: 0.0076 - val_loss: 1.6260e-04 - val_mean_absolute_error: 0.0099
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5628e-04 - mean_absolute_error: 0.0075 - val_loss: 1.6160e-04 - val_mean_absolute_error: 0.0099
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4994e-04 - mean_absolute_error: 0.0072 - val_loss: 1.6373e-04 - val_mean_absolute_error: 0.0100
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4178e-04 - mean_absolute_error: 0.0069 - val_loss: 1.5047e-04 - val_mean_absolute_error: 0.0095
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.3603e-04 - mean_absolute_error: 0.0067 - val_loss: 1.6135e-04 - val_mean_absolute_error: 0.0098
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2968e-04 - mean_absolute_error: 0.0065 - val_loss: 1.4881e-04 - val_mean_absolute_error: 0.0093
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2417e-04 - mean_absolute_error: 0.0063 - val_loss: 1.4420e-04 - val_mean_absolute_error: 0.0092
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1839e-04 - mean_absolute_error: 0.0062 - val_loss: 1.4061e-04 - val_mean_absolute_error: 0.0091
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1315e-04 - mean_absolute_error: 0.0060 - val_loss: 1.3739e-04 - val_mean_absolute_error: 0.0090
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0868e-04 - mean_absolute_error: 0.0059 - val_loss: 1.4575e-04 - val_mean_absolute_error: 0.0093
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0458e-04 - mean_absolute_error: 0.0058 - val_loss: 1.3568e-04 - val_mean_absolute_error: 0.0089
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0111e-04 - mean_absolute_error: 0.0056 - val_loss: 1.2146e-04 - val_mean_absolute_error: 0.0085
# Epoch 25/50
# 685/685 [==============================] - 12s 17ms/step - loss: 9.8605e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1663e-04 - val_mean_absolute_error: 0.0083
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.5852e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2151e-04 - val_mean_absolute_error: 0.0085
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.4048e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1885e-04 - val_mean_absolute_error: 0.0085
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.2085e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1868e-04 - val_mean_absolute_error: 0.0084
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.0428e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1630e-04 - val_mean_absolute_error: 0.0083
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.9070e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1260e-04 - val_mean_absolute_error: 0.0082
# Epoch 31/50
# 685/685 [==============================] - 12s 17ms/step - loss: 8.7415e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1574e-04 - val_mean_absolute_error: 0.0083
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.6289e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3123e-04 - val_mean_absolute_error: 0.0090
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.5303e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1417e-04 - val_mean_absolute_error: 0.0083
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.4188e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1252e-04 - val_mean_absolute_error: 0.0083
# Epoch 35/50
# 685/685 [==============================] - 12s 17ms/step - loss: 8.3125e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0541e-04 - val_mean_absolute_error: 0.0080
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.2399e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0231e-04 - val_mean_absolute_error: 0.0079
# Epoch 37/50
# 685/685 [==============================] - 14s 20ms/step - loss: 8.1590e-05 - mean_absolute_error: 0.0048 - val_loss: 9.1795e-05 - val_mean_absolute_error: 0.0075
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.0667e-05 - mean_absolute_error: 0.0047 - val_loss: 9.4173e-05 - val_mean_absolute_error: 0.0076
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.0076e-05 - mean_absolute_error: 0.0047 - val_loss: 8.5166e-05 - val_mean_absolute_error: 0.0073
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.9201e-05 - mean_absolute_error: 0.0047 - val_loss: 8.3311e-05 - val_mean_absolute_error: 0.0072
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.8644e-05 - mean_absolute_error: 0.0046 - val_loss: 9.0064e-05 - val_mean_absolute_error: 0.0075
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.7881e-05 - mean_absolute_error: 0.0046 - val_loss: 8.8383e-05 - val_mean_absolute_error: 0.0073
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.7383e-05 - mean_absolute_error: 0.0046 - val_loss: 8.5120e-05 - val_mean_absolute_error: 0.0072
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.6800e-05 - mean_absolute_error: 0.0045 - val_loss: 8.4329e-05 - val_mean_absolute_error: 0.0071
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.6352e-05 - mean_absolute_error: 0.0045 - val_loss: 8.5526e-05 - val_mean_absolute_error: 0.0071
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.6031e-05 - mean_absolute_error: 0.0045 - val_loss: 8.4606e-05 - val_mean_absolute_error: 0.0070
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.5453e-05 - mean_absolute_error: 0.0045 - val_loss: 8.2879e-05 - val_mean_absolute_error: 0.0069
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.5009e-05 - mean_absolute_error: 0.0045 - val_loss: 8.3194e-05 - val_mean_absolute_error: 0.0069
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.4467e-05 - mean_absolute_error: 0.0045 - val_loss: 8.4212e-05 - val_mean_absolute_error: 0.0069
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.4068e-05 - mean_absolute_error: 0.0044 - val_loss: 8.4788e-05 - val_mean_absolute_error: 0.0069
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 91.30728568306823
#  LSTM의 MAPE : 3.458500882128015
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 20s 19ms/step - loss: 1.6728e-04 - mean_absolute_error: 0.0070 - val_loss: 5.9462e-04 - val_mean_absolute_error: 0.0218
# Epoch 2/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0244e-04 - mean_absolute_error: 0.0049 - val_loss: 4.0774e-04 - val_mean_absolute_error: 0.0181
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.0059e-05 - mean_absolute_error: 0.0044 - val_loss: 3.5650e-04 - val_mean_absolute_error: 0.0169
# Epoch 4/50
# 685/685 [==============================] - 11s 17ms/step - loss: 8.3278e-05 - mean_absolute_error: 0.0041 - val_loss: 2.7155e-04 - val_mean_absolute_error: 0.0148
# Epoch 5/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.8422e-05 - mean_absolute_error: 0.0038 - val_loss: 2.1848e-04 - val_mean_absolute_error: 0.0133
# Epoch 6/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.5392e-05 - mean_absolute_error: 0.0037 - val_loss: 1.9453e-04 - val_mean_absolute_error: 0.0125
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.3177e-05 - mean_absolute_error: 0.0036 - val_loss: 1.6417e-04 - val_mean_absolute_error: 0.0115
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.1496e-05 - mean_absolute_error: 0.0035 - val_loss: 1.4491e-04 - val_mean_absolute_error: 0.0108
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0364e-05 - mean_absolute_error: 0.0034 - val_loss: 1.3156e-04 - val_mean_absolute_error: 0.0103
# Epoch 10/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.9417e-05 - mean_absolute_error: 0.0033 - val_loss: 1.2456e-04 - val_mean_absolute_error: 0.0100
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8887e-05 - mean_absolute_error: 0.0032 - val_loss: 1.2250e-04 - val_mean_absolute_error: 0.0099
# Epoch 12/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8545e-05 - mean_absolute_error: 0.0031 - val_loss: 1.1636e-04 - val_mean_absolute_error: 0.0096
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8684e-05 - mean_absolute_error: 0.0031 - val_loss: 1.1329e-04 - val_mean_absolute_error: 0.0094
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8381e-05 - mean_absolute_error: 0.0030 - val_loss: 1.1066e-04 - val_mean_absolute_error: 0.0093
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8319e-05 - mean_absolute_error: 0.0030 - val_loss: 1.0803e-04 - val_mean_absolute_error: 0.0092
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8240e-05 - mean_absolute_error: 0.0029 - val_loss: 1.0489e-04 - val_mean_absolute_error: 0.0090
# Epoch 17/50
# 685/685 [==============================] - 12s 18ms/step - loss: 6.8240e-05 - mean_absolute_error: 0.0029 - val_loss: 1.0098e-04 - val_mean_absolute_error: 0.0089
# Epoch 18/50
# 685/685 [==============================] - 13s 20ms/step - loss: 6.8075e-05 - mean_absolute_error: 0.0029 - val_loss: 9.9811e-05 - val_mean_absolute_error: 0.0088
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8019e-05 - mean_absolute_error: 0.0029 - val_loss: 1.0017e-04 - val_mean_absolute_error: 0.0088
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7945e-05 - mean_absolute_error: 0.0028 - val_loss: 9.8003e-05 - val_mean_absolute_error: 0.0087
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7779e-05 - mean_absolute_error: 0.0028 - val_loss: 9.4932e-05 - val_mean_absolute_error: 0.0086
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7722e-05 - mean_absolute_error: 0.0028 - val_loss: 8.9460e-05 - val_mean_absolute_error: 0.0084
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7622e-05 - mean_absolute_error: 0.0028 - val_loss: 8.5127e-05 - val_mean_absolute_error: 0.0082
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7512e-05 - mean_absolute_error: 0.0028 - val_loss: 8.0718e-05 - val_mean_absolute_error: 0.0080
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7345e-05 - mean_absolute_error: 0.0027 - val_loss: 7.7249e-05 - val_mean_absolute_error: 0.0078
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7238e-05 - mean_absolute_error: 0.0027 - val_loss: 7.4010e-05 - val_mean_absolute_error: 0.0076
# Epoch 27/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.7002e-05 - mean_absolute_error: 0.0027 - val_loss: 7.0977e-05 - val_mean_absolute_error: 0.0075
# Epoch 28/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.6864e-05 - mean_absolute_error: 0.0027 - val_loss: 6.7601e-05 - val_mean_absolute_error: 0.0073
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.6663e-05 - mean_absolute_error: 0.0026 - val_loss: 6.4362e-05 - val_mean_absolute_error: 0.0071
# Epoch 30/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.6499e-05 - mean_absolute_error: 0.0026 - val_loss: 6.1055e-05 - val_mean_absolute_error: 0.0069
# Epoch 31/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.6341e-05 - mean_absolute_error: 0.0026 - val_loss: 5.8625e-05 - val_mean_absolute_error: 0.0068
# Epoch 32/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.6203e-05 - mean_absolute_error: 0.0026 - val_loss: 5.4706e-05 - val_mean_absolute_error: 0.0065
# Epoch 33/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.6031e-05 - mean_absolute_error: 0.0026 - val_loss: 5.2971e-05 - val_mean_absolute_error: 0.0065
# Epoch 34/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.5820e-05 - mean_absolute_error: 0.0025 - val_loss: 4.9119e-05 - val_mean_absolute_error: 0.0062
# Epoch 35/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.5623e-05 - mean_absolute_error: 0.0025 - val_loss: 4.7151e-05 - val_mean_absolute_error: 0.0061
# Epoch 36/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.5394e-05 - mean_absolute_error: 0.0025 - val_loss: 4.4506e-05 - val_mean_absolute_error: 0.0059
# Epoch 37/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.5092e-05 - mean_absolute_error: 0.0024 - val_loss: 4.4031e-05 - val_mean_absolute_error: 0.0059
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.4753e-05 - mean_absolute_error: 0.0024 - val_loss: 4.1764e-05 - val_mean_absolute_error: 0.0058
# Epoch 39/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.4433e-05 - mean_absolute_error: 0.0024 - val_loss: 3.8260e-05 - val_mean_absolute_error: 0.0055
# Epoch 40/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.4251e-05 - mean_absolute_error: 0.0023 - val_loss: 3.4376e-05 - val_mean_absolute_error: 0.0052
# Epoch 41/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.4062e-05 - mean_absolute_error: 0.0023 - val_loss: 3.2455e-05 - val_mean_absolute_error: 0.0050
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3930e-05 - mean_absolute_error: 0.0023 - val_loss: 3.0107e-05 - val_mean_absolute_error: 0.0048
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3780e-05 - mean_absolute_error: 0.0023 - val_loss: 2.9038e-05 - val_mean_absolute_error: 0.0048
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3645e-05 - mean_absolute_error: 0.0023 - val_loss: 2.6651e-05 - val_mean_absolute_error: 0.0045
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3550e-05 - mean_absolute_error: 0.0022 - val_loss: 2.6016e-05 - val_mean_absolute_error: 0.0045
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3511e-05 - mean_absolute_error: 0.0022 - val_loss: 2.5939e-05 - val_mean_absolute_error: 0.0045
# Epoch 47/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.3444e-05 - mean_absolute_error: 0.0022 - val_loss: 2.6433e-05 - val_mean_absolute_error: 0.0045
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3327e-05 - mean_absolute_error: 0.0022 - val_loss: 2.9096e-05 - val_mean_absolute_error: 0.0047
# Epoch 49/50
# 685/685 [==============================] - 11s 17ms/step - loss: 6.3191e-05 - mean_absolute_error: 0.0022 - val_loss: 2.9335e-05 - val_mean_absolute_error: 0.0048
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3055e-05 - mean_absolute_error: 0.0022 - val_loss: 2.9813e-05 - val_mean_absolute_error: 0.0048
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# LSTM의 RMSE : 36.266395779829494
#  LSTM의 MAPE : 17.271853169544066
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# train_1 학습
model_4 = create_gru(64, x_train_4)
history_gru_4 = fit_model(model_4, x_train_4, y_train_4, 50, x_val_4, y_val_4)
print('-'*150)

pred_gru_4 = model_4.predict(x_val_4) # 2018년 예측
re_y_val_4 = np.insert(re_y_val_4, 0, pred_gru_4.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_gru_4 = scaler_num[4].inverse_transform(re_y_val_4) # inverse transform


re_y_val_4 = np.delete(re_y_val_4,0,1)
re_y_val_4 = np.insert(re_y_val_4, 0, y_val_4.T, axis = 1)

y_val_4 = scaler_num[4].inverse_transform(re_y_val_4)

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_gru_4.T[0], y_val_4.T[0])**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_gru_4.T[0],  y_val_4.T[0])))
print('-'*150)

# train_2 학습
model_5 = create_gru(64, x_train_5)
history_gru_5 = fit_model(model_5, x_train_5, y_train_5, 50, x_val_5, y_val_5)
print('-'*150)

pred_gru_5 = model_5.predict(x_val_5) # 2018년 예측
re_y_val_5 = np.insert(re_y_val_5, 0, pred_gru_5.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_gru_5 = scaler_num[5].inverse_transform(re_y_val_5) # inverse transform


re_y_val_5 = np.delete(re_y_val_5,0,1)
re_y_val_5 = np.insert(re_y_val_5, 0, y_val_5.T, axis = 1)

y_val_5 = scaler_num[5].inverse_transform(re_y_val_5)

print("gru의 RMSE : {}".format(mean_squared_error(pred_gru_5.T[0], y_val_5.T[0])**0.5),'\n', 'gru의 MAPE : {}'.format(mape(pred_gru_5.T[0],  y_val_5.T[0])))
print('-'*150)

# train_3 학습
model_6 = create_gru(64, x_train_6)
history_gru_6 = fit_model(model_6, x_train_6, y_train_6, 50, x_val_6, y_val_6)
print('-'*150)

pred_gru_6 = model_6.predict(x_val_6) # 2018년 예측
re_y_val_6 = np.insert(re_y_val_6, 0, pred_gru_6.T, axis = 1) # min-max inverse transform을 하기위한 전처리
pred_gru_6 = scaler_num[6].inverse_transform(re_y_val_6) # inverse transform


re_y_val_6 = np.delete(re_y_val_6,0,1)
re_y_val_6 = np.insert(re_y_val_6, 0, y_val_6.T, axis = 1)

y_val_6 = scaler_num[6].inverse_transform(re_y_val_6)

print("gru의 RMSE : {}".format(mean_squared_error(pred_gru_6.T[0], y_val_6.T[0])**0.5),'\n', 'gru의 MAPE : {}'.format(mape(pred_gru_6.T[0],  y_val_6.T[0])))
print('-'*150)
# Out:
# Epoch 1/50
# 685/685 [==============================] - 19s 17ms/step - loss: 0.0033 - mean_absolute_error: 0.0332 - val_loss: 0.0032 - val_mean_absolute_error: 0.0511
# Epoch 2/50
# 685/685 [==============================] - 11s 15ms/step - loss: 9.0303e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0027 - val_mean_absolute_error: 0.0464
# Epoch 3/50
# 685/685 [==============================] - 11s 15ms/step - loss: 7.2677e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0019 - val_mean_absolute_error: 0.0385
# Epoch 4/50
# 685/685 [==============================] - 11s 15ms/step - loss: 6.5794e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0016 - val_mean_absolute_error: 0.0344
# Epoch 5/50
# 685/685 [==============================] - 11s 15ms/step - loss: 5.8607e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0014 - val_mean_absolute_error: 0.0324
# Epoch 6/50
# 685/685 [==============================] - 10s 15ms/step - loss: 5.4897e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0011 - val_mean_absolute_error: 0.0286
# Epoch 7/50
# 685/685 [==============================] - 10s 15ms/step - loss: 5.1426e-04 - mean_absolute_error: 0.0160 - val_loss: 9.9387e-04 - val_mean_absolute_error: 0.0279
# Epoch 8/50
# 685/685 [==============================] - 11s 15ms/step - loss: 4.5127e-04 - mean_absolute_error: 0.0151 - val_loss: 7.6303e-04 - val_mean_absolute_error: 0.0245
# Epoch 9/50
# 685/685 [==============================] - 11s 15ms/step - loss: 3.6676e-04 - mean_absolute_error: 0.0136 - val_loss: 5.7401e-04 - val_mean_absolute_error: 0.0208
# Epoch 10/50
# 685/685 [==============================] - 10s 15ms/step - loss: 3.2280e-04 - mean_absolute_error: 0.0128 - val_loss: 4.7333e-04 - val_mean_absolute_error: 0.0186
# Epoch 11/50
# 685/685 [==============================] - 10s 15ms/step - loss: 2.8934e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4654e-04 - val_mean_absolute_error: 0.0180
# Epoch 12/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.5734e-04 - mean_absolute_error: 0.0113 - val_loss: 4.1576e-04 - val_mean_absolute_error: 0.0171
# Epoch 13/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.4124e-04 - mean_absolute_error: 0.0109 - val_loss: 4.2007e-04 - val_mean_absolute_error: 0.0173
# Epoch 14/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.2065e-04 - mean_absolute_error: 0.0105 - val_loss: 3.6380e-04 - val_mean_absolute_error: 0.0158
# Epoch 15/50
# 685/685 [==============================] - 10s 15ms/step - loss: 2.0999e-04 - mean_absolute_error: 0.0101 - val_loss: 4.0096e-04 - val_mean_absolute_error: 0.0168
# Epoch 16/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.9691e-04 - mean_absolute_error: 0.0098 - val_loss: 5.5226e-04 - val_mean_absolute_error: 0.0203
# Epoch 17/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.9413e-04 - mean_absolute_error: 0.0097 - val_loss: 5.1633e-04 - val_mean_absolute_error: 0.0194
# Epoch 18/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.8663e-04 - mean_absolute_error: 0.0095 - val_loss: 4.8381e-04 - val_mean_absolute_error: 0.0183
# Epoch 19/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.8135e-04 - mean_absolute_error: 0.0093 - val_loss: 4.5827e-04 - val_mean_absolute_error: 0.0173
# Epoch 20/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.7502e-04 - mean_absolute_error: 0.0091 - val_loss: 4.3800e-04 - val_mean_absolute_error: 0.0165
# Epoch 21/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.6795e-04 - mean_absolute_error: 0.0089 - val_loss: 4.1503e-04 - val_mean_absolute_error: 0.0158
# Epoch 22/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.6233e-04 - mean_absolute_error: 0.0088 - val_loss: 4.1033e-04 - val_mean_absolute_error: 0.0157
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.5780e-04 - mean_absolute_error: 0.0086 - val_loss: 3.9941e-04 - val_mean_absolute_error: 0.0153
# Epoch 24/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5322e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9623e-04 - val_mean_absolute_error: 0.0152
# Epoch 25/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.4878e-04 - mean_absolute_error: 0.0084 - val_loss: 4.0562e-04 - val_mean_absolute_error: 0.0156
# Epoch 26/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.4499e-04 - mean_absolute_error: 0.0083 - val_loss: 4.1463e-04 - val_mean_absolute_error: 0.0157
# Epoch 27/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.4127e-04 - mean_absolute_error: 0.0081 - val_loss: 3.7774e-04 - val_mean_absolute_error: 0.0152
# Epoch 28/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.3826e-04 - mean_absolute_error: 0.0081 - val_loss: 3.2597e-04 - val_mean_absolute_error: 0.0138
# Epoch 29/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.3467e-04 - mean_absolute_error: 0.0079 - val_loss: 3.1864e-04 - val_mean_absolute_error: 0.0135
# Epoch 30/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.3135e-04 - mean_absolute_error: 0.0078 - val_loss: 3.1609e-04 - val_mean_absolute_error: 0.0135
# Epoch 31/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2798e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1600e-04 - val_mean_absolute_error: 0.0134
# Epoch 32/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.2611e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1389e-04 - val_mean_absolute_error: 0.0133
# Epoch 33/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2381e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2327e-04 - val_mean_absolute_error: 0.0136
# Epoch 34/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2190e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9537e-04 - val_mean_absolute_error: 0.0126
# Epoch 35/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1917e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9766e-04 - val_mean_absolute_error: 0.0126
# Epoch 36/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.1609e-04 - mean_absolute_error: 0.0074 - val_loss: 3.6141e-04 - val_mean_absolute_error: 0.0143
# Epoch 37/50
# 685/685 [==============================] - 10s 15ms/step - loss: 1.1490e-04 - mean_absolute_error: 0.0073 - val_loss: 3.3494e-04 - val_mean_absolute_error: 0.0135
# Epoch 38/50
# 685/685 [==============================] - 12s 18ms/step - loss: 1.1263e-04 - mean_absolute_error: 0.0072 - val_loss: 3.4054e-04 - val_mean_absolute_error: 0.0136
# Epoch 39/50
# 685/685 [==============================] - 12s 17ms/step - loss: 1.1143e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2573e-04 - val_mean_absolute_error: 0.0131
# Epoch 40/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0961e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2263e-04 - val_mean_absolute_error: 0.0129
# Epoch 41/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0797e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2395e-04 - val_mean_absolute_error: 0.0129
# Epoch 42/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0646e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2581e-04 - val_mean_absolute_error: 0.0129
# Epoch 43/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0500e-04 - mean_absolute_error: 0.0070 - val_loss: 3.4194e-04 - val_mean_absolute_error: 0.0133
# Epoch 44/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0372e-04 - mean_absolute_error: 0.0070 - val_loss: 4.1597e-04 - val_mean_absolute_error: 0.0148
# Epoch 45/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0295e-04 - mean_absolute_error: 0.0069 - val_loss: 4.3232e-04 - val_mean_absolute_error: 0.0154
# Epoch 46/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0197e-04 - mean_absolute_error: 0.0069 - val_loss: 4.3273e-04 - val_mean_absolute_error: 0.0154
# Epoch 47/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0131e-04 - mean_absolute_error: 0.0069 - val_loss: 4.2471e-04 - val_mean_absolute_error: 0.0148
# Epoch 48/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.0030e-04 - mean_absolute_error: 0.0068 - val_loss: 4.2888e-04 - val_mean_absolute_error: 0.0151
# Epoch 49/50
# 685/685 [==============================] - 11s 15ms/step - loss: 9.9318e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7828e-04 - val_mean_absolute_error: 0.0139
# Epoch 50/50
# 685/685 [==============================] - 11s 15ms/step - loss: 9.9056e-05 - mean_absolute_error: 0.0068 - val_loss: 4.6947e-04 - val_mean_absolute_error: 0.0157
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 2s 5ms/step
# LSTM의 RMSE : 102.86383053163799
#  LSTM의 MAPE : 6.2022124087943284
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 18s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0218 - val_loss: 6.3548e-04 - val_mean_absolute_error: 0.0221
# Epoch 2/50
# 685/685 [==============================] - 11s 15ms/step - loss: 5.1896e-04 - mean_absolute_error: 0.0142 - val_loss: 7.4310e-04 - val_mean_absolute_error: 0.0241
# Epoch 3/50
# 685/685 [==============================] - 11s 15ms/step - loss: 4.4755e-04 - mean_absolute_error: 0.0124 - val_loss: 4.5641e-04 - val_mean_absolute_error: 0.0186
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 3.3156e-04 - mean_absolute_error: 0.0112 - val_loss: 2.2815e-04 - val_mean_absolute_error: 0.0119
# Epoch 5/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.5068e-04 - mean_absolute_error: 0.0104 - val_loss: 1.7869e-04 - val_mean_absolute_error: 0.0099
# Epoch 6/50
# 685/685 [==============================] - 11s 15ms/step - loss: 2.1903e-04 - mean_absolute_error: 0.0098 - val_loss: 1.6161e-04 - val_mean_absolute_error: 0.0090
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.9837e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4267e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.8239e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4218e-04 - val_mean_absolute_error: 0.0084
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.7188e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4442e-04 - val_mean_absolute_error: 0.0087
# Epoch 10/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.5773e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4649e-04 - val_mean_absolute_error: 0.0092
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.4511e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5628e-04 - val_mean_absolute_error: 0.0099
# Epoch 12/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.3525e-04 - mean_absolute_error: 0.0072 - val_loss: 1.2570e-04 - val_mean_absolute_error: 0.0083
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.2737e-04 - mean_absolute_error: 0.0069 - val_loss: 1.1960e-04 - val_mean_absolute_error: 0.0080
# Epoch 14/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2212e-04 - mean_absolute_error: 0.0067 - val_loss: 1.1504e-04 - val_mean_absolute_error: 0.0078
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1780e-04 - mean_absolute_error: 0.0065 - val_loss: 1.1326e-04 - val_mean_absolute_error: 0.0077
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.1328e-04 - mean_absolute_error: 0.0063 - val_loss: 1.1245e-04 - val_mean_absolute_error: 0.0076
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0922e-04 - mean_absolute_error: 0.0062 - val_loss: 1.1450e-04 - val_mean_absolute_error: 0.0076
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0589e-04 - mean_absolute_error: 0.0060 - val_loss: 1.1659e-04 - val_mean_absolute_error: 0.0077
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0253e-04 - mean_absolute_error: 0.0059 - val_loss: 1.1540e-04 - val_mean_absolute_error: 0.0077
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.9715e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1808e-04 - val_mean_absolute_error: 0.0078
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.7602e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1754e-04 - val_mean_absolute_error: 0.0078
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.5985e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1957e-04 - val_mean_absolute_error: 0.0080
# Epoch 23/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.4152e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1609e-04 - val_mean_absolute_error: 0.0078
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.2618e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1513e-04 - val_mean_absolute_error: 0.0078
# Epoch 25/50
# 685/685 [==============================] - 11s 17ms/step - loss: 9.1692e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1138e-04 - val_mean_absolute_error: 0.0076
# Epoch 26/50
# 685/685 [==============================] - 13s 19ms/step - loss: 9.1069e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1007e-04 - val_mean_absolute_error: 0.0075
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.9217e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0732e-04 - val_mean_absolute_error: 0.0074
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.8097e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0401e-04 - val_mean_absolute_error: 0.0072
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.6949e-05 - mean_absolute_error: 0.0051 - val_loss: 9.9686e-05 - val_mean_absolute_error: 0.0071
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.5533e-05 - mean_absolute_error: 0.0051 - val_loss: 9.6625e-05 - val_mean_absolute_error: 0.0070
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.4032e-05 - mean_absolute_error: 0.0050 - val_loss: 9.6443e-05 - val_mean_absolute_error: 0.0070
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.2719e-05 - mean_absolute_error: 0.0050 - val_loss: 9.7856e-05 - val_mean_absolute_error: 0.0072
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.1823e-05 - mean_absolute_error: 0.0049 - val_loss: 9.8001e-05 - val_mean_absolute_error: 0.0072
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 8.0896e-05 - mean_absolute_error: 0.0049 - val_loss: 9.4368e-05 - val_mean_absolute_error: 0.0071
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.9805e-05 - mean_absolute_error: 0.0048 - val_loss: 9.5764e-05 - val_mean_absolute_error: 0.0071
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.8656e-05 - mean_absolute_error: 0.0048 - val_loss: 9.0624e-05 - val_mean_absolute_error: 0.0069
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.8094e-05 - mean_absolute_error: 0.0048 - val_loss: 8.9352e-05 - val_mean_absolute_error: 0.0068
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.6700e-05 - mean_absolute_error: 0.0047 - val_loss: 8.5980e-05 - val_mean_absolute_error: 0.0066
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.6570e-05 - mean_absolute_error: 0.0047 - val_loss: 8.8918e-05 - val_mean_absolute_error: 0.0069
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.5384e-05 - mean_absolute_error: 0.0046 - val_loss: 8.5135e-05 - val_mean_absolute_error: 0.0067
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.4178e-05 - mean_absolute_error: 0.0046 - val_loss: 7.8946e-05 - val_mean_absolute_error: 0.0063
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.3351e-05 - mean_absolute_error: 0.0045 - val_loss: 7.9612e-05 - val_mean_absolute_error: 0.0065
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.3555e-05 - mean_absolute_error: 0.0045 - val_loss: 8.1221e-05 - val_mean_absolute_error: 0.0065
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.1492e-05 - mean_absolute_error: 0.0044 - val_loss: 8.1746e-05 - val_mean_absolute_error: 0.0064
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.1150e-05 - mean_absolute_error: 0.0044 - val_loss: 7.6257e-05 - val_mean_absolute_error: 0.0062
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.2620e-05 - mean_absolute_error: 0.0044 - val_loss: 7.4071e-05 - val_mean_absolute_error: 0.0061
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.9809e-05 - mean_absolute_error: 0.0044 - val_loss: 7.5287e-05 - val_mean_absolute_error: 0.0062
# Epoch 48/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.1109e-05 - mean_absolute_error: 0.0044 - val_loss: 7.2908e-05 - val_mean_absolute_error: 0.0060
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8729e-05 - mean_absolute_error: 0.0043 - val_loss: 7.3816e-05 - val_mean_absolute_error: 0.0062
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.9105e-05 - mean_absolute_error: 0.0043 - val_loss: 8.0193e-05 - val_mean_absolute_error: 0.0066
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# gru의 RMSE : 88.79833611505447
#  gru의 MAPE : 3.1425681629924975
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/50
# 685/685 [==============================] - 18s 18ms/step - loss: 2.0520e-04 - mean_absolute_error: 0.0074 - val_loss: 7.9121e-04 - val_mean_absolute_error: 0.0252
# Epoch 2/50
# 685/685 [==============================] - 11s 15ms/step - loss: 1.2707e-04 - mean_absolute_error: 0.0058 - val_loss: 6.5767e-04 - val_mean_absolute_error: 0.0229
# Epoch 3/50
# 685/685 [==============================] - 11s 16ms/step - loss: 1.0842e-04 - mean_absolute_error: 0.0053 - val_loss: 4.4689e-04 - val_mean_absolute_error: 0.0189
# Epoch 4/50
# 685/685 [==============================] - 11s 16ms/step - loss: 9.3919e-05 - mean_absolute_error: 0.0048 - val_loss: 3.2347e-04 - val_mean_absolute_error: 0.0161
# Epoch 5/50
# 685/685 [==============================] - 11s 15ms/step - loss: 8.5027e-05 - mean_absolute_error: 0.0044 - val_loss: 2.7612e-04 - val_mean_absolute_error: 0.0149
# Epoch 6/50
# 685/685 [==============================] - 11s 15ms/step - loss: 8.0759e-05 - mean_absolute_error: 0.0042 - val_loss: 2.2669e-04 - val_mean_absolute_error: 0.0135
# Epoch 7/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.7472e-05 - mean_absolute_error: 0.0040 - val_loss: 1.8878e-04 - val_mean_absolute_error: 0.0124
# Epoch 8/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.5269e-05 - mean_absolute_error: 0.0038 - val_loss: 1.3856e-04 - val_mean_absolute_error: 0.0106
# Epoch 9/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.3573e-05 - mean_absolute_error: 0.0036 - val_loss: 9.9128e-05 - val_mean_absolute_error: 0.0089
# Epoch 10/50
# 685/685 [==============================] - 13s 20ms/step - loss: 7.2902e-05 - mean_absolute_error: 0.0035 - val_loss: 8.4009e-05 - val_mean_absolute_error: 0.0082
# Epoch 11/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.3294e-05 - mean_absolute_error: 0.0034 - val_loss: 8.2645e-05 - val_mean_absolute_error: 0.0081
# Epoch 12/50
# 685/685 [==============================] - 11s 15ms/step - loss: 7.2530e-05 - mean_absolute_error: 0.0033 - val_loss: 8.0480e-05 - val_mean_absolute_error: 0.0079
# Epoch 13/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.1710e-05 - mean_absolute_error: 0.0032 - val_loss: 8.1720e-05 - val_mean_absolute_error: 0.0079
# Epoch 14/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.1182e-05 - mean_absolute_error: 0.0031 - val_loss: 7.4883e-05 - val_mean_absolute_error: 0.0075
# Epoch 15/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0940e-05 - mean_absolute_error: 0.0030 - val_loss: 7.7582e-05 - val_mean_absolute_error: 0.0076
# Epoch 16/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0827e-05 - mean_absolute_error: 0.0030 - val_loss: 7.5612e-05 - val_mean_absolute_error: 0.0075
# Epoch 17/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0693e-05 - mean_absolute_error: 0.0030 - val_loss: 9.9120e-05 - val_mean_absolute_error: 0.0086
# Epoch 18/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0628e-05 - mean_absolute_error: 0.0029 - val_loss: 8.6488e-05 - val_mean_absolute_error: 0.0081
# Epoch 19/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0385e-05 - mean_absolute_error: 0.0029 - val_loss: 8.5086e-05 - val_mean_absolute_error: 0.0080
# Epoch 20/50
# 685/685 [==============================] - 11s 16ms/step - loss: 7.0150e-05 - mean_absolute_error: 0.0029 - val_loss: 8.1962e-05 - val_mean_absolute_error: 0.0079
# Epoch 21/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.9792e-05 - mean_absolute_error: 0.0028 - val_loss: 7.9545e-05 - val_mean_absolute_error: 0.0078
# Epoch 22/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.9470e-05 - mean_absolute_error: 0.0028 - val_loss: 7.9762e-05 - val_mean_absolute_error: 0.0078
# Epoch 23/50
# 685/685 [==============================] - 11s 15ms/step - loss: 6.9196e-05 - mean_absolute_error: 0.0028 - val_loss: 7.7782e-05 - val_mean_absolute_error: 0.0077
# Epoch 24/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8898e-05 - mean_absolute_error: 0.0028 - val_loss: 7.5609e-05 - val_mean_absolute_error: 0.0076
# Epoch 25/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8684e-05 - mean_absolute_error: 0.0027 - val_loss: 7.4690e-05 - val_mean_absolute_error: 0.0076
# Epoch 26/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8455e-05 - mean_absolute_error: 0.0027 - val_loss: 7.3830e-05 - val_mean_absolute_error: 0.0076
# Epoch 27/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.8297e-05 - mean_absolute_error: 0.0027 - val_loss: 6.9513e-05 - val_mean_absolute_error: 0.0073
# Epoch 28/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7869e-05 - mean_absolute_error: 0.0026 - val_loss: 6.6064e-05 - val_mean_absolute_error: 0.0072
# Epoch 29/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7441e-05 - mean_absolute_error: 0.0026 - val_loss: 6.1513e-05 - val_mean_absolute_error: 0.0069
# Epoch 30/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.7068e-05 - mean_absolute_error: 0.0025 - val_loss: 5.7207e-05 - val_mean_absolute_error: 0.0067
# Epoch 31/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.6656e-05 - mean_absolute_error: 0.0025 - val_loss: 5.7091e-05 - val_mean_absolute_error: 0.0067
# Epoch 32/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.6241e-05 - mean_absolute_error: 0.0024 - val_loss: 5.6430e-05 - val_mean_absolute_error: 0.0066
# Epoch 33/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.5954e-05 - mean_absolute_error: 0.0024 - val_loss: 5.7071e-05 - val_mean_absolute_error: 0.0067
# Epoch 34/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.5643e-05 - mean_absolute_error: 0.0024 - val_loss: 5.5108e-05 - val_mean_absolute_error: 0.0066
# Epoch 35/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.5336e-05 - mean_absolute_error: 0.0023 - val_loss: 5.2676e-05 - val_mean_absolute_error: 0.0064
# Epoch 36/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.5017e-05 - mean_absolute_error: 0.0023 - val_loss: 5.1798e-05 - val_mean_absolute_error: 0.0064
# Epoch 37/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.4715e-05 - mean_absolute_error: 0.0023 - val_loss: 4.8919e-05 - val_mean_absolute_error: 0.0062
# Epoch 38/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.4443e-05 - mean_absolute_error: 0.0022 - val_loss: 4.8292e-05 - val_mean_absolute_error: 0.0061
# Epoch 39/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.4191e-05 - mean_absolute_error: 0.0022 - val_loss: 4.9242e-05 - val_mean_absolute_error: 0.0062
# Epoch 40/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3928e-05 - mean_absolute_error: 0.0022 - val_loss: 4.7941e-05 - val_mean_absolute_error: 0.0061
# Epoch 41/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3690e-05 - mean_absolute_error: 0.0022 - val_loss: 4.8779e-05 - val_mean_absolute_error: 0.0062
# Epoch 42/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3417e-05 - mean_absolute_error: 0.0021 - val_loss: 4.7265e-05 - val_mean_absolute_error: 0.0061
# Epoch 43/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3346e-05 - mean_absolute_error: 0.0021 - val_loss: 4.5745e-05 - val_mean_absolute_error: 0.0060
# Epoch 44/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.3004e-05 - mean_absolute_error: 0.0021 - val_loss: 4.0489e-05 - val_mean_absolute_error: 0.0056
# Epoch 45/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.2801e-05 - mean_absolute_error: 0.0021 - val_loss: 3.9743e-05 - val_mean_absolute_error: 0.0055
# Epoch 46/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.2623e-05 - mean_absolute_error: 0.0021 - val_loss: 3.4787e-05 - val_mean_absolute_error: 0.0051
# Epoch 47/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.2381e-05 - mean_absolute_error: 0.0021 - val_loss: 3.4328e-05 - val_mean_absolute_error: 0.0051
# Epoch 48/50
# 685/685 [==============================] - 13s 19ms/step - loss: 6.2100e-05 - mean_absolute_error: 0.0020 - val_loss: 3.3063e-05 - val_mean_absolute_error: 0.0050
# Epoch 49/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.2031e-05 - mean_absolute_error: 0.0020 - val_loss: 3.0575e-05 - val_mean_absolute_error: 0.0048
# Epoch 50/50
# 685/685 [==============================] - 11s 16ms/step - loss: 6.1767e-05 - mean_absolute_error: 0.0020 - val_loss: 3.1723e-05 - val_mean_absolute_error: 0.0049
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 273/273 [==============================] - 3s 5ms/step
# gru의 RMSE : 37.41007272289805
#  gru의 MAPE : 17.88194972693921
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
model_list = [model_lstm_0, model_1, model_2, model_3, model_4, model_5, model_6]
num = 0
for i in model_list:
  i.save('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'_1224_2' + '.h5')
  num+=1

# %% [markdown]
# - 코랩 무료 gpu의 한계로 모델을 저장하고 불러오는 방법 선택

# %%
from tensorflow.keras.models import load_model
model_list = ['model_0', 'model_1', 'model_2', 'model_3', 'model_4', 'model_5', 'model_6']
num = 0

for i in model_list:
  globals()['{}'.format(i)] = load_model('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'_1228_2'+'.h5')
  num+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-495251199984> in <module>
#       4
#       5 for i in model_list:
# ----> 6   globals()['{}'.format(i)] = load_model('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'_1224_2'+'.h5')
#       7   num+=1
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    1172   for kwarg in kwargs:
#    1173     if kwarg not in allowed_kwargs:
# -> 1174       raise TypeError(error_message, kwarg)
#    1175
#    1176
#
# TypeError: ('Keyword argument not understood:', 'units')

# %%
model_0 = load_model('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/model_0_1224_1.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-2122d0302ba5> in <module>
# ----> 1 model_0 = load_model('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/model_0_1224_1.h5')
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#    1172   for kwarg in kwargs:
#    1173     if kwarg not in allowed_kwargs:
# -> 1174       raise TypeError(error_message, kwarg)
#    1175
#    1176
#
# TypeError: ('Keyword argument not understood:', 'units')

# %%
from sklearn.metrics import mean_squared_error

def mape(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

y_val_0 = scaler_num[0].inverse_transform(y_val_0.reshape(-1,1))
pred_lstm_0 = scaler_num[0].inverse_transform(model_lstm_0.predict(x_val_0))

print('RMSE : {}'.format(mean_squared_error(y_val_0, pred_lstm_0)**0.5))

y_val_1 = scaler_num[1].inverse_transform(y_val_1.reshape(-1,1))
pred_lstm_1 = scaler_num[1].inverse_transform(model_1.predict(x_val_1))

print('RMSE : {}'.format(mean_squared_error(y_val_1, pred_lstm_1)**0.5))

y_val_2 = scaler_num[2].inverse_transform(y_val_2.reshape(-1,1))
pred_lstm_2 = scaler_num[2].inverse_transform(model_2.predict(x_val_2))

print('RMSE : {}'.format(mean_squared_error(y_val_2, pred_lstm_2)**0.5))

y_val_3 = scaler_num[3].inverse_transform(y_val_3.reshape(-1,1))
pred_lstm_3 = scaler_num[3].inverse_transform(model_3.predict(x_val_3))

print('RMSE : {}'.format(mean_squared_error(y_val_3, pred_lstm_3)**0.5))

y_val_4 = scaler_num[4].inverse_transform(y_val_4.reshape(-1,1))
pred_lstm_4 = scaler_num[4].inverse_transform(model_4.predict(x_val_4))

print('RMSE : {}'.format(mean_squared_error(y_val_4, pred_lstm_4)**0.5))

y_val_5 = scaler_num[5].inverse_transform(y_val_5.reshape(-1,1))
pred_lstm_5 = scaler_num[5].inverse_transform(model_5.predict(x_val_5))

print('RMSE : {}'.format(mean_squared_error(y_val_5, pred_lstm_5)**0.5))

y_val_6 = scaler_num[6].inverse_transform(y_val_6.reshape(-1,1))
pred_lstm_6 = scaler_num[6].inverse_transform(model_6.predict(x_val_6))

print('RMSE : {}'.format(mean_squared_error(y_val_6, pred_lstm_6)**0.5))
# Out:
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 62.862549449180634
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 58.45691346328078
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 6.998125746397716
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 41.528521776484816
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 102.86384868778569
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 88.79832173689961
# 273/273 [==============================] - 1s 5ms/step
# RMSE : 37.41007613940916

# %%
y_val_0
# Out:
# array([0.4378433 , 0.38514582, 0.36488051, ..., 0.70367285, 0.66550066,
#        0.63735427])

# %%
y_val_0
# Out:
# array([[1.05275843e+14],
#        [9.34039063e+13],
#        [8.88384431e+13],
#        ...,
#        [1.65163181e+14],
#        [1.56563570e+14],
#        [1.50222616e+14]])

# %%
y_val_total = (np.concatenate((y_val_0.T[0], y_val_1.T[0], y_val_2.T[0], y_val_3.T[0], y_val_4.T[0], y_val_5.T[0], y_val_6.T[0]), axis=0))
pred_lstm_total = (np.concatenate((pred_lstm_0.T[0], pred_lstm_1.T[0], pred_lstm_2.T[0], pred_lstm_3.T[0], pred_lstm_4.T[0], pred_lstm_5.T[0], pred_lstm_6.T[0]), axis=0))

print('RMSE : {}'.format(mean_squared_error(y_val_total, pred_lstm_total)**0.5))
print('MAPE : {}'.format(mape(y_val_total, pred_lstm_total)))
# Out:
# RMSE : 64.37405183403429
# MAPE : 11.142622124708263

# %%
y_val_total = (np.concatenate((y_val_0.T[0], y_val_1.T[0], y_val_2.T[0], y_val_3.T[0], y_val_4.T[0], y_val_5.T[0], y_val_6.T[0]), axis=0))
pred_lstm_total = (np.concatenate((pred_gru_0.T[0], pred_gru_1.T[0], pred_gru_2.T[0], pred_gru_3.T[0], pred_gru_4.T[0], pred_gru_5.T[0], pred_gru_6.T[0]), axis=0))

print('RMSE : {}'.format(mean_squared_error(y_val_total, pred_lstm_total)**0.5))
print('MAPE : {}'.format(mape(y_val_total, pred_lstm_total)))
# Out:
# RMSE : 65.06467550707038
# MAPE : 11.097106925527052

# %% [markdown]
# RMSE
# - BI-GRU + Attention  :  65.06467550707038
# - BI-LSTM + Attention : 64.37405183403429
#
# MAPE
# - BI-GRU + Attention : 11.097106925527052
# - BI-LSTM + Attention :  11.142622124708263

# %%
pred_vis(pred_lstm_0.T[0], 'Bi_LSTM_0', y_val_0.T[0])
pred_vis(pred_lstm_1.T[0], 'Bi_LSTM_1', y_val_1.T[0])
pred_vis(pred_lstm_2.T[0], 'Bi_LSTM_2', y_val_2.T[0])

# %%
pred_vis(pred_lstm_3.T[0], 'Bi_LSTM_3', y_val_3.T[0])
pred_vis(pred_lstm_4.T[0], 'Bi_LSTM_4', y_val_4.T[0])
pred_vis(pred_lstm_5.T[0], 'Bi_LSTM_5', y_val_5.T[0])

# %%
pred_vis(pred_lstm_6.T[0], 'Bi_LSTM_6', y_val_6.T[0])
pred_vis(pred_lstm_total, 'Bi_LSTM_total', y_val_total)
