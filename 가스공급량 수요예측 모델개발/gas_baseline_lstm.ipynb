# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

total = pd.read_csv('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/train.csv', encoding = 'cp949')
total.head()
# Out:
#           연월일  시간 구분       공급량
# 0  2013-01-01   1  A  2497.129
# 1  2013-01-01   2  A  2363.265
# 2  2013-01-01   3  A  2258.505
# 3  2013-01-01   4  A  2243.969
# 4  2013-01-01   5  A  2344.105

# %%
total['구분'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'G', 'H'], dtype=object)

# %%
d_map = dict()
for i, d in enumerate(total['구분'].unique()):
  d_map[d] = i
# 라벨 인코딩

total['구분'] = total['구분'].map(d_map)

total
# Out:
#                연월일  시간  구분       공급량
# 0       2013-01-01   1   0  2497.129
# 1       2013-01-01   2   0  2363.265
# 2       2013-01-01   3   0  2258.505
# 3       2013-01-01   4   0  2243.969
# 4       2013-01-01   5   0  2344.105
# ...            ...  ..  ..       ...
# 368083  2018-12-31  20   6   681.033
# 368084  2018-12-31  21   6   669.961
# 368085  2018-12-31  22   6   657.941
# 368086  2018-12-31  23   6   610.953
# 368087  2018-12-31  24   6   560.896
#
# [368088 rows x 4 columns]

# %% [markdown]
# - 구분을 숫자로 **변경**

# %%
total['연월일'] = pd.to_datetime(total['연월일'])

total['year'] = total['연월일'].dt.year
total['month'] = total['연월일'].dt.month
total['day'] = total['연월일'].dt.day
total['weekday'] = total['연월일'].dt.weekday

# %%
f, ax = plt.subplots(figsize = (6,3))
total['공급량'].plot()

# %% [markdown]
# - 시계열 데이터라 그런지 뭔가 일정한 패턴이 있어보인다.

# %%
train_years = [2013, 2014, 2015, 2016, 2017]
val_years = [2018] # 시계열 데이터이므로 2018년 1년치의 데이터를 예측, test data set에는 2019년 데이터를 예측

train = total[total['year'].isin(train_years)]
val = total[total['year'].isin(val_years)]

# %%
train[train['구분']==0][['공급량']].reset_index(drop = True).plot()
# 이상치가 있다. 어떤 이유인지 모르겠지만 12000가까운 수치는 저 시계열 데이터상 있을 수 없는 일 인거같다.
# 복합적인 이유일 수 있으니 scaler로 제어해보겠다.
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44553 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44277 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44553 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

scaler_num = ['scaler_0','scaler_1','scaler_2','scaler_3','scaler_4','scaler_5','scaler_6']

for i in range(7):
  #scaler = MinMaxScaler()
  
  scaler_num[i] = RobustScaler()
  globals()['train_{}'.format(i)] = scaler_num[i].fit_transform(train[train['구분']==i][['공급량']].reset_index(drop = True))
  globals()['val_{}'.format(i)] = scaler_num[i].transform(val[val['구분']==i][['공급량']].reset_index(drop = True))
  

print(train_0.shape, val_0.shape)
# Out:
# (43824, 1) (8760, 1)

# %% [markdown]
# - 딥러닝을 사용할 예정이라서 전체 데이터를 전부 넣어도 무방하지만 모델을 더 돌려보자는 취지에서 각 구분별로 모델정의 즉, 7개의 모델을 생성예정
# - 그에 따라 스케일러도 7개 생성

# %%
def create_dataset (X, look_back = 1):
    Xs, ys = [], []
 
    for i in range(len(X)-look_back):
        v = X[i:i+look_back]
        Xs.append(v)
        ys.append(X[i+look_back])
 
    return np.array(Xs), np.array(ys)

LOOK_BACK = 24

x_train_0, y_train_0 = create_dataset(train_0, LOOK_BACK)
x_val_0, y_val_0 = create_dataset(val_0, LOOK_BACK)

#################################################################

x_train_1, y_train_1 = create_dataset(train_1, LOOK_BACK)
x_val_1, y_val_1 = create_dataset(val_1, LOOK_BACK)

#################################################################

x_train_2, y_train_2 = create_dataset(train_2, LOOK_BACK)
x_val_2, y_val_2 = create_dataset(val_2, LOOK_BACK)

#################################################################

x_train_3, y_train_3 = create_dataset(train_3, LOOK_BACK)
x_val_3, y_val_3 = create_dataset(val_3, LOOK_BACK)

#################################################################

x_train_4, y_train_4 = create_dataset(train_4, LOOK_BACK)
x_val_4, y_val_4 = create_dataset(val_4, LOOK_BACK)

#################################################################

x_train_5, y_train_5 = create_dataset(train_5, LOOK_BACK)
x_val_5, y_val_5 = create_dataset(val_5, LOOK_BACK)

#################################################################

x_train_6, y_train_6 = create_dataset(train_6, LOOK_BACK)
x_val_6, y_val_6 = create_dataset(val_6, LOOK_BACK)

# %% [markdown]
# - LOOKBACK을 24로 정하고(시간단위 데이터인데 24시간마다 어떠한 주기가 나타날 것이라고 추측) 데이터변형

# %%
from tensorflow.python.keras.callbacks import History
from tensorflow.keras.layers import Input, Dense, Bidirectional, LSTM, GRU, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping


def create_bilstm(units, x_train):
  inputs = Input(shape = (x_train.shape[1], x_train.shape[2]))
  hidden1 = Bidirectional(LSTM(units = units, return_sequences=True))(inputs)
  hidden2 = Bidirectional(LSTM(units = units))(hidden1)
  output = Dense(1)(hidden2)
  model = Model(inputs = inputs, outputs = output)
  model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_percentage_error'])

  return model

def create_gru(units, x_train):
  inputs = Input(shape = (x_train.shape[1], x_train.shape[2]))
  hidden1 = GRU(units = units, return_sequences=True)(inputs)
  hidden2 = GRU(units = units)(hidden1)
  output = Dense(1)(hidden2)
  model = Model(inputs = inputs, outputs = output)
  model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mean_absolute_percentage_error'])

  return model


def fit_model(model,x_train, y_train, epoch, x_val,y_val):
  early_stop = EarlyStopping(monitor = 'val_loss',
                             patience = 10)
  
  history = model.fit(x_train, y_train, 
                      epochs = epoch, 
                      validation_data = (x_val, y_val),
                      batch_size = 64,
                      shuffle = False,
                      callbacks = [early_stop])
  return history

# %% [markdown]
# - 양방향 LSTM, GRU를 비교할 예정

# %%
from sklearn.metrics import mean_squared_error

def mape(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

# train_0 학습
model_lstm_0 = create_bilstm(64, x_train_0)
history_lstm_0 = fit_model(model_lstm_0, x_train_0, y_train_0, 50, x_val_0, y_val_0)

y_val_0 = scaler_num[0].inverse_transform(y_val_0)
pred_lstm_0 = scaler_num[0].inverse_transform(model_lstm_0.predict(x_val_0))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_0, y_val_0)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_0, y_val_0)))
# Out:
# Epoch 1/50
# 685/685 [==============================] - 31s 34ms/step - loss: 0.0515 - mean_absolute_percentage_error: 213.4370 - val_loss: 0.0239 - val_mean_absolute_percentage_error: 273.7552
# Epoch 2/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0141 - mean_absolute_percentage_error: 129.8848 - val_loss: 0.0185 - val_mean_absolute_percentage_error: 228.8721
# Epoch 3/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0118 - mean_absolute_percentage_error: 111.1412 - val_loss: 0.0194 - val_mean_absolute_percentage_error: 257.7822
# Epoch 4/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0107 - mean_absolute_percentage_error: 96.6916 - val_loss: 0.0171 - val_mean_absolute_percentage_error: 255.1485
# Epoch 5/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0095 - mean_absolute_percentage_error: 88.5317 - val_loss: 0.0149 - val_mean_absolute_percentage_error: 240.8733
# Epoch 6/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0086 - mean_absolute_percentage_error: 80.8438 - val_loss: 0.0159 - val_mean_absolute_percentage_error: 282.9932
# Epoch 7/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0077 - mean_absolute_percentage_error: 75.4904 - val_loss: 0.0144 - val_mean_absolute_percentage_error: 265.1064
# Epoch 8/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0072 - mean_absolute_percentage_error: 76.5580 - val_loss: 0.0133 - val_mean_absolute_percentage_error: 254.2129
# Epoch 9/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0068 - mean_absolute_percentage_error: 74.7129 - val_loss: 0.0137 - val_mean_absolute_percentage_error: 278.3521
# Epoch 10/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0064 - mean_absolute_percentage_error: 72.4426 - val_loss: 0.0129 - val_mean_absolute_percentage_error: 283.4358
# Epoch 11/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0058 - mean_absolute_percentage_error: 65.4197 - val_loss: 0.0147 - val_mean_absolute_percentage_error: 341.6283
# Epoch 12/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0054 - mean_absolute_percentage_error: 61.0520 - val_loss: 0.0104 - val_mean_absolute_percentage_error: 317.9604
# Epoch 13/50
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0051 - mean_absolute_percentage_error: 60.6867 - val_loss: 0.0079 - val_mean_absolute_percentage_error: 250.4092
# Epoch 14/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0048 - mean_absolute_percentage_error: 60.9405 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 230.8626
# Epoch 15/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0048 - mean_absolute_percentage_error: 60.1246 - val_loss: 0.0072 - val_mean_absolute_percentage_error: 214.5317
# Epoch 16/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0045 - mean_absolute_percentage_error: 59.8915 - val_loss: 0.0070 - val_mean_absolute_percentage_error: 229.4340
# Epoch 17/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0045 - mean_absolute_percentage_error: 60.1455 - val_loss: 0.0070 - val_mean_absolute_percentage_error: 224.1870
# Epoch 18/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0043 - mean_absolute_percentage_error: 57.0812 - val_loss: 0.0065 - val_mean_absolute_percentage_error: 220.3574
# Epoch 19/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0041 - mean_absolute_percentage_error: 58.2419 - val_loss: 0.0082 - val_mean_absolute_percentage_error: 236.2096
# Epoch 20/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0041 - mean_absolute_percentage_error: 57.8851 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 210.0857
# Epoch 21/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0040 - mean_absolute_percentage_error: 56.4878 - val_loss: 0.0068 - val_mean_absolute_percentage_error: 207.9655
# Epoch 22/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0039 - mean_absolute_percentage_error: 55.7934 - val_loss: 0.0068 - val_mean_absolute_percentage_error: 214.5714
# Epoch 23/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0038 - mean_absolute_percentage_error: 55.5389 - val_loss: 0.0069 - val_mean_absolute_percentage_error: 201.7898
# Epoch 24/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0038 - mean_absolute_percentage_error: 54.7865 - val_loss: 0.0063 - val_mean_absolute_percentage_error: 182.0925
# Epoch 25/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0037 - mean_absolute_percentage_error: 53.0907 - val_loss: 0.0062 - val_mean_absolute_percentage_error: 168.8639
# Epoch 26/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0037 - mean_absolute_percentage_error: 51.0923 - val_loss: 0.0059 - val_mean_absolute_percentage_error: 145.4025
# Epoch 27/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0037 - mean_absolute_percentage_error: 51.7377 - val_loss: 0.0048 - val_mean_absolute_percentage_error: 136.8123
# Epoch 28/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0036 - mean_absolute_percentage_error: 49.2096 - val_loss: 0.0047 - val_mean_absolute_percentage_error: 153.1310
# Epoch 29/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0036 - mean_absolute_percentage_error: 44.6294 - val_loss: 0.0054 - val_mean_absolute_percentage_error: 167.4913
# Epoch 30/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0036 - mean_absolute_percentage_error: 43.8771 - val_loss: 0.0058 - val_mean_absolute_percentage_error: 171.2645
# Epoch 31/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0036 - mean_absolute_percentage_error: 46.7685 - val_loss: 0.0046 - val_mean_absolute_percentage_error: 165.3739
# Epoch 32/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0035 - mean_absolute_percentage_error: 45.6568 - val_loss: 0.0045 - val_mean_absolute_percentage_error: 161.3455
# Epoch 33/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0035 - mean_absolute_percentage_error: 44.7446 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 161.3581
# Epoch 34/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0035 - mean_absolute_percentage_error: 44.3895 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 157.3955
# Epoch 35/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 43.9296 - val_loss: 0.0051 - val_mean_absolute_percentage_error: 138.5041
# Epoch 36/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 42.1478 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 133.0614
# Epoch 37/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 41.3845 - val_loss: 0.0043 - val_mean_absolute_percentage_error: 109.3468
# Epoch 38/50
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0035 - mean_absolute_percentage_error: 41.0332 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 120.7840
# Epoch 39/50
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0034 - mean_absolute_percentage_error: 40.3286 - val_loss: 0.0038 - val_mean_absolute_percentage_error: 130.0855
# Epoch 40/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 39.5863 - val_loss: 0.0044 - val_mean_absolute_percentage_error: 145.6402
# Epoch 41/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0035 - mean_absolute_percentage_error: 43.9928 - val_loss: 0.0045 - val_mean_absolute_percentage_error: 158.9065
# Epoch 42/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0035 - mean_absolute_percentage_error: 39.7868 - val_loss: 0.0038 - val_mean_absolute_percentage_error: 145.9863
# Epoch 43/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 42.0186 - val_loss: 0.0038 - val_mean_absolute_percentage_error: 142.9062
# Epoch 44/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 41.0858 - val_loss: 0.0036 - val_mean_absolute_percentage_error: 149.0678
# Epoch 45/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 42.0035 - val_loss: 0.0041 - val_mean_absolute_percentage_error: 147.1395
# Epoch 46/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0033 - mean_absolute_percentage_error: 40.0297 - val_loss: 0.0041 - val_mean_absolute_percentage_error: 130.2200
# Epoch 47/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 39.7064 - val_loss: 0.0040 - val_mean_absolute_percentage_error: 123.7991
# Epoch 48/50
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0033 - mean_absolute_percentage_error: 37.7921 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 111.7860
# Epoch 49/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0033 - mean_absolute_percentage_error: 36.7620 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 105.7369
# Epoch 50/50
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0033 - mean_absolute_percentage_error: 36.0563 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 115.9927
# LSTM의 RMSE : 61.53628976988764
#  LSTM의 MAPE : 6.734761324018117

# %%
def loss_vis(history, model_name):
  f, ax = plt.subplots(figsize = (6, 3))
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend(['Train_Loss', 'Val_Loss'])
  plt.title(model_name)

loss_vis(history_lstm_0, 'Bi_LSTM')

# %%
def pred_vis(pred_model, model_name, y_val):
  f, ax = plt.subplots(figsize = (15,8))
  plt.plot(pred_model, label = 'Prediction',  alpha = 0.5)
  plt.plot(y_val, label = 'Val_data',  alpha = 0.3)
  plt.xlabel('Time')
  plt.ylabel('Value')
  plt.legend()
  plt.title(model_name)

# %%
# train_1 학습
model_1 = create_bilstm(64, x_train_1)
history_lstm_1 = fit_model(model_1, x_train_1, y_train_1, 70, x_val_1, y_val_1)
print('-'*150)

y_val_1 = scaler_num[1].inverse_transform(y_val_1)
pred_lstm_1 = scaler_num[1].inverse_transform(model_1.predict(x_val_1))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_1, y_val_1)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_1, y_val_1)))
print('-'*150)

# train_2 학습
model_2 = create_bilstm(64, x_train_2)
history_lstm_2 = fit_model(model_2, x_train_2, y_train_2, 70, x_val_2, y_val_2)
print('-'*150)

y_val_2 = scaler_num[2].inverse_transform(y_val_2)
pred_lstm_2 = scaler_num[2].inverse_transform(model_2.predict(x_val_2))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_2, y_val_2)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_2, y_val_2)))
print('-'*150)

# train_3 학습
model_3 = create_bilstm(64, x_train_3)
history_lstm_3 = fit_model(model_3, x_train_3, y_train_3, 70, x_val_3, y_val_3)
print('-'*150)

y_val_3 = scaler_num[3].inverse_transform(y_val_3)
pred_lstm_3 = scaler_num[3].inverse_transform(model_3.predict(x_val_3))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_3, y_val_3)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_3, y_val_3)))
print('-'*150)
# Out:
# Epoch 1/70
# 685/685 [==============================] - 31s 35ms/step - loss: 0.0463 - mean_absolute_percentage_error: 169.6386 - val_loss: 0.0235 - val_mean_absolute_percentage_error: 248.9355
# Epoch 2/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0116 - mean_absolute_percentage_error: 74.7569 - val_loss: 0.0239 - val_mean_absolute_percentage_error: 279.5636
# Epoch 3/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0106 - mean_absolute_percentage_error: 75.8301 - val_loss: 0.0231 - val_mean_absolute_percentage_error: 285.4313
# Epoch 4/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0097 - mean_absolute_percentage_error: 75.5941 - val_loss: 0.0183 - val_mean_absolute_percentage_error: 255.7267
# Epoch 5/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0086 - mean_absolute_percentage_error: 74.3617 - val_loss: 0.0162 - val_mean_absolute_percentage_error: 280.6541
# Epoch 6/70
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0079 - mean_absolute_percentage_error: 72.3581 - val_loss: 0.0161 - val_mean_absolute_percentage_error: 314.8118
# Epoch 7/70
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0072 - mean_absolute_percentage_error: 67.3381 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 301.2861
# Epoch 8/70
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0065 - mean_absolute_percentage_error: 63.5993 - val_loss: 0.0133 - val_mean_absolute_percentage_error: 306.7162
# Epoch 9/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0059 - mean_absolute_percentage_error: 59.7714 - val_loss: 0.0105 - val_mean_absolute_percentage_error: 285.3399
# Epoch 10/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0053 - mean_absolute_percentage_error: 60.6342 - val_loss: 0.0117 - val_mean_absolute_percentage_error: 311.0363
# Epoch 11/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0049 - mean_absolute_percentage_error: 59.4991 - val_loss: 0.0112 - val_mean_absolute_percentage_error: 334.6137
# Epoch 12/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0049 - mean_absolute_percentage_error: 64.6923 - val_loss: 0.0120 - val_mean_absolute_percentage_error: 310.2344
# Epoch 13/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0046 - mean_absolute_percentage_error: 59.4623 - val_loss: 0.0096 - val_mean_absolute_percentage_error: 254.9237
# Epoch 14/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0042 - mean_absolute_percentage_error: 56.8117 - val_loss: 0.0109 - val_mean_absolute_percentage_error: 260.0716
# Epoch 15/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0041 - mean_absolute_percentage_error: 59.6253 - val_loss: 0.0115 - val_mean_absolute_percentage_error: 254.7818
# Epoch 16/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0040 - mean_absolute_percentage_error: 60.9958 - val_loss: 0.0134 - val_mean_absolute_percentage_error: 243.4686
# Epoch 17/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0039 - mean_absolute_percentage_error: 58.9892 - val_loss: 0.0124 - val_mean_absolute_percentage_error: 255.7462
# Epoch 18/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0036 - mean_absolute_percentage_error: 58.0888 - val_loss: 0.0101 - val_mean_absolute_percentage_error: 249.8458
# Epoch 19/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0034 - mean_absolute_percentage_error: 55.4450 - val_loss: 0.0093 - val_mean_absolute_percentage_error: 262.7756
# Epoch 20/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0033 - mean_absolute_percentage_error: 54.2597 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 284.7234
# Epoch 21/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0032 - mean_absolute_percentage_error: 55.1069 - val_loss: 0.0088 - val_mean_absolute_percentage_error: 285.6058
# Epoch 22/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0032 - mean_absolute_percentage_error: 55.9161 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 276.4716
# Epoch 23/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0031 - mean_absolute_percentage_error: 53.7880 - val_loss: 0.0073 - val_mean_absolute_percentage_error: 244.9621
# Epoch 24/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0029 - mean_absolute_percentage_error: 53.4887 - val_loss: 0.0090 - val_mean_absolute_percentage_error: 240.6841
# Epoch 25/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0029 - mean_absolute_percentage_error: 54.4340 - val_loss: 0.0089 - val_mean_absolute_percentage_error: 226.9131
# Epoch 26/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0028 - mean_absolute_percentage_error: 52.3980 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 219.0882
# Epoch 27/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0027 - mean_absolute_percentage_error: 53.1996 - val_loss: 0.0093 - val_mean_absolute_percentage_error: 231.6654
# Epoch 28/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0026 - mean_absolute_percentage_error: 51.3637 - val_loss: 0.0091 - val_mean_absolute_percentage_error: 241.7794
# Epoch 29/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0026 - mean_absolute_percentage_error: 54.0968 - val_loss: 0.0087 - val_mean_absolute_percentage_error: 273.2844
# Epoch 30/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0026 - mean_absolute_percentage_error: 47.1626 - val_loss: 0.0069 - val_mean_absolute_percentage_error: 216.5985
# Epoch 31/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0023 - mean_absolute_percentage_error: 45.9638 - val_loss: 0.0057 - val_mean_absolute_percentage_error: 177.8021
# Epoch 32/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0023 - mean_absolute_percentage_error: 48.5934 - val_loss: 0.0067 - val_mean_absolute_percentage_error: 171.5530
# Epoch 33/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0023 - mean_absolute_percentage_error: 47.7936 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 155.4744
# Epoch 34/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0022 - mean_absolute_percentage_error: 45.3116 - val_loss: 0.0050 - val_mean_absolute_percentage_error: 143.5780
# Epoch 35/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0022 - mean_absolute_percentage_error: 47.1870 - val_loss: 0.0076 - val_mean_absolute_percentage_error: 206.7999
# Epoch 36/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0022 - mean_absolute_percentage_error: 46.6266 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 183.5136
# Epoch 37/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0021 - mean_absolute_percentage_error: 44.3036 - val_loss: 0.0056 - val_mean_absolute_percentage_error: 185.0137
# Epoch 38/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0020 - mean_absolute_percentage_error: 42.6590 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 188.7023
# Epoch 39/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0020 - mean_absolute_percentage_error: 43.8074 - val_loss: 0.0069 - val_mean_absolute_percentage_error: 215.4592
# Epoch 40/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0021 - mean_absolute_percentage_error: 38.4741 - val_loss: 0.0062 - val_mean_absolute_percentage_error: 169.2618
# Epoch 41/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0021 - mean_absolute_percentage_error: 40.1586 - val_loss: 0.0042 - val_mean_absolute_percentage_error: 130.7200
# Epoch 42/70
# 685/685 [==============================] - 23s 34ms/step - loss: 0.0018 - mean_absolute_percentage_error: 36.7390 - val_loss: 0.0042 - val_mean_absolute_percentage_error: 122.8140
# Epoch 43/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0018 - mean_absolute_percentage_error: 37.0606 - val_loss: 0.0043 - val_mean_absolute_percentage_error: 107.3693
# Epoch 44/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0017 - mean_absolute_percentage_error: 38.8869 - val_loss: 0.0064 - val_mean_absolute_percentage_error: 123.8799
# Epoch 45/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0019 - mean_absolute_percentage_error: 40.5057 - val_loss: 0.0068 - val_mean_absolute_percentage_error: 179.8174
# Epoch 46/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0018 - mean_absolute_percentage_error: 40.9130 - val_loss: 0.0085 - val_mean_absolute_percentage_error: 305.5598
# Epoch 47/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0020 - mean_absolute_percentage_error: 42.4857 - val_loss: 0.0060 - val_mean_absolute_percentage_error: 252.2799
# Epoch 48/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0019 - mean_absolute_percentage_error: 37.1720 - val_loss: 0.0046 - val_mean_absolute_percentage_error: 180.2200
# Epoch 49/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0016 - mean_absolute_percentage_error: 32.9476 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 101.4724
# Epoch 50/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0020 - mean_absolute_percentage_error: 28.8329 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 49.2122
# Epoch 51/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0016 - mean_absolute_percentage_error: 31.3237 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 65.4909
# Epoch 52/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0014 - mean_absolute_percentage_error: 27.3209 - val_loss: 0.0021 - val_mean_absolute_percentage_error: 61.0766
# Epoch 53/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 30.5689 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 48.4581
# Epoch 54/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0014 - mean_absolute_percentage_error: 28.5893 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 51.3396
# Epoch 55/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0014 - mean_absolute_percentage_error: 29.7220 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 71.6086
# Epoch 56/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 34.2726 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 110.1125
# Epoch 57/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 33.3412 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 111.3359
# Epoch 58/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 31.5476 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 83.8946
# Epoch 59/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 29.5926 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 83.2871
# Epoch 60/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 28.7886 - val_loss: 0.0023 - val_mean_absolute_percentage_error: 50.8521
# Epoch 61/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0015 - mean_absolute_percentage_error: 30.9917 - val_loss: 0.0039 - val_mean_absolute_percentage_error: 117.6032
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 60.21708486816066
#  LSTM의 MAPE : 9.616368896517557
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/70
# 685/685 [==============================] - 31s 35ms/step - loss: 0.0440 - mean_absolute_percentage_error: 186.5111 - val_loss: 0.0157 - val_mean_absolute_percentage_error: 375.7190
# Epoch 2/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0149 - mean_absolute_percentage_error: 149.3486 - val_loss: 0.0118 - val_mean_absolute_percentage_error: 443.0770
# Epoch 3/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0105 - mean_absolute_percentage_error: 157.5888 - val_loss: 0.0138 - val_mean_absolute_percentage_error: 586.0780
# Epoch 4/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0087 - mean_absolute_percentage_error: 134.4991 - val_loss: 0.0098 - val_mean_absolute_percentage_error: 431.5371
# Epoch 5/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0069 - mean_absolute_percentage_error: 150.0063 - val_loss: 0.0070 - val_mean_absolute_percentage_error: 365.4010
# Epoch 6/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0061 - mean_absolute_percentage_error: 148.2744 - val_loss: 0.0055 - val_mean_absolute_percentage_error: 271.3089
# Epoch 7/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0054 - mean_absolute_percentage_error: 134.0535 - val_loss: 0.0083 - val_mean_absolute_percentage_error: 198.0495
# Epoch 8/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0050 - mean_absolute_percentage_error: 132.1743 - val_loss: 0.0069 - val_mean_absolute_percentage_error: 205.8446
# Epoch 9/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0046 - mean_absolute_percentage_error: 122.1619 - val_loss: 0.0071 - val_mean_absolute_percentage_error: 292.8647
# Epoch 10/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0047 - mean_absolute_percentage_error: 121.2895 - val_loss: 0.0081 - val_mean_absolute_percentage_error: 418.9765
# Epoch 11/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0046 - mean_absolute_percentage_error: 116.5442 - val_loss: 0.0086 - val_mean_absolute_percentage_error: 488.6248
# Epoch 12/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0045 - mean_absolute_percentage_error: 119.6424 - val_loss: 0.0074 - val_mean_absolute_percentage_error: 340.7976
# Epoch 13/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0045 - mean_absolute_percentage_error: 117.2549 - val_loss: 0.0077 - val_mean_absolute_percentage_error: 449.9455
# Epoch 14/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0045 - mean_absolute_percentage_error: 120.6063 - val_loss: 0.0075 - val_mean_absolute_percentage_error: 346.8201
# Epoch 15/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0046 - mean_absolute_percentage_error: 130.5631 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 566.8389
# Epoch 16/70
# 685/685 [==============================] - 22s 32ms/step - loss: 0.0049 - mean_absolute_percentage_error: 119.6551 - val_loss: 0.0103 - val_mean_absolute_percentage_error: 356.3544
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# LSTM의 RMSE : 7.728374878331371
#  LSTM의 MAPE : 15.79846491467224
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/70
# 177/685 [======>.......................] - ETA: 15s - loss: 0.1141 - mean_absolute_percentage_error: 142.5291

# %%
# train_4 학습
model_4 = create_bilstm(64, x_train_4)
history_lstm_4 = fit_model(model_4, x_train_4, y_train_4, 50, x_val_4, y_val_4)

print('-'*150)
y_val_4 = scaler_num[4].inverse_transform(y_val_4)
pred_lstm_4 = scaler_num[4].inverse_transform(model_4.predict(x_val_4))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_4, y_val_4)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_4, y_val_4)))
print('-'*150)



# train_5 학습
model_5 = create_bilstm(64, x_train_5)
history_lstm_5 = fit_model(model_5, x_train_5, y_train_5, 50, x_val_5, y_val_5)

print('-'*150)
y_val_5 = scaler_num[5].inverse_transform(y_val_5)
pred_lstm_5 = scaler_num[5].inverse_transform(model_5.predict(x_val_5))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_5, y_val_5)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_5, y_val_5)))
print('-'*150)


# train_6 학습
model_6 = create_bilstm(64, x_train_6)
history_lstm_6 = fit_model(model_6, x_train_6, y_train_6, 50, x_val_6, y_val_6)
print('-'*150)

y_val_6 = scaler_num[6].inverse_transform(y_val_6)
pred_lstm_6 = scaler_num[6].inverse_transform(model_6.predict(x_val_6))

print("LSTM의 RMSE : {}".format(mean_squared_error(pred_lstm_6, y_val_6)**0.5),'\n', 'LSTM의 MAPE : {}'.format(mape(pred_lstm_6, y_val_6)))
print('-'*150)

# %%
model_list = [model_lstm_0, model_1, model_2, model_3, model_4, model_5, model_6]
num = 0
for i in model_list:
  i.save('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'.h5')
  num+=1

# %% [markdown]
# - 코랩 무료 gpu의 한계로 모델을 저장하고 불러오는 방법 선택

# %%
from tensorflow.keras.models import load_model
model_list = ['model_0', 'model_1', 'model_2', 'model_3', 'model_4', 'model_5', 'model_6']
num = 0

for i in model_list:
  globals()['{}'.format(i)] = load_model('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/' + 'model_' + str(num)+'.h5')
  num+=1

# %%
from sklearn.metrics import mean_squared_error

def mape(y_test, y_pred):
	return np.mean(np.abs((y_test - y_pred) / y_test)) * 100 

y_val_0 = scaler_num[0].inverse_transform(y_val_0)
pred_lstm_0 = scaler_num[0].inverse_transform(model_0.predict(x_val_0))

print('RMSE : {}'.format(mean_squared_error(y_val_0, pred_lstm_0)))

y_val_1 = scaler_num[1].inverse_transform(y_val_1)
pred_lstm_1 = scaler_num[1].inverse_transform(model_1.predict(x_val_1))

print('RMSE : {}'.format(mean_squared_error(y_val_1, pred_lstm_1)**0.5))

y_val_2 = scaler_num[2].inverse_transform(y_val_2)
pred_lstm_2 = scaler_num[2].inverse_transform(model_2.predict(x_val_2))

print('RMSE : {}'.format(mean_squared_error(y_val_2, pred_lstm_2)**0.5))

y_val_3 = scaler_num[3].inverse_transform(y_val_3)
pred_lstm_3 = scaler_num[3].inverse_transform(model_3.predict(x_val_3))

print('RMSE : {}'.format(mean_squared_error(y_val_3, pred_lstm_3)**0.5))

y_val_4 = scaler_num[4].inverse_transform(y_val_4)
pred_lstm_4 = scaler_num[4].inverse_transform(model_4.predict(x_val_4))

print('RMSE : {}'.format(mean_squared_error(y_val_4, pred_lstm_4)**0.5))

y_val_5 = scaler_num[5].inverse_transform(y_val_5)
pred_lstm_5 = scaler_num[5].inverse_transform(model_5.predict(x_val_5))

print('RMSE : {}'.format(mean_squared_error(y_val_5, pred_lstm_5)**0.5))

y_val_6 = scaler_num[6].inverse_transform(y_val_6)
pred_lstm_6 = scaler_num[6].inverse_transform(model_6.predict(x_val_6))

print('RMSE : {}'.format(mean_squared_error(y_val_6, pred_lstm_6)**0.5))
# Out:
# RMSE : 5368.091565276349

# %%
y_val_total = (np.concatenate((y_val_0, y_val_1, y_val_2, y_val_3, y_val_4, y_val_5, y_val_6), axis=0))
pred_lstm_total = (np.concatenate((pred_lstm_0, pred_lstm_1, pred_lstm_2, pred_lstm_3, pred_lstm_4, pred_lstm_5, pred_lstm_6), axis=0))

print('RMSE : {}'.format(mean_squared_error(y_val_total, pred_lstm_total)**0.5))
print('MAPE : {}'.format(mape(y_val_total, pred_lstm_total)))
# Out:
# RMSE : 69.98451344074019
# MAPE : 17.012626884424094

# %% [markdown]
# - 7개의 모델의 결과값을 합쳐서 다시 결과값을 도출해본 결과 RMSE가 약 70으로 생각보다 괜찮게 나왔고 MAPE는 17로 17%의 오차율이 있다.

# %%
pred_vis(pred_lstm_0, 'Bi_LSTM_0', y_val_0)
pred_vis(pred_lstm_1, 'Bi_LSTM_1', y_val_1)
pred_vis(pred_lstm_2, 'Bi_LSTM_2', y_val_2)

# %%
pred_vis(pred_lstm_3, 'Bi_LSTM_3', y_val_3)
pred_vis(pred_lstm_4, 'Bi_LSTM_4', y_val_4)
pred_vis(pred_lstm_5, 'Bi_LSTM_5', y_val_5)

# %%
pred_vis(pred_lstm_6, 'Bi_LSTM_6', y_val_6)
pred_vis(pred_lstm_total, 'Bi_LSTM_total', y_val_total)

# %% [markdown]
# - 확실히 lgbm baseline보다 잘 나왔다.
# - 아주 훌륭한 성능은 아니지만 이정도면 괜찮은거같다. 이상치부분을 처리만 잘하면 더 좋은 성능을 낼 수 있을것 같다.

# %%
# scaling, autoencoder, 4계절로 잘라서 iqr이상치를 평균으로, 아니면 날씨 정보나 다른것들을 찾아보자, feature 추가
# https://velog.io/@nameunzz/Anomaly-Detection#4-auto-encoder

# 수정사항
## 삽질!
## minmax scaling -> robust scaling

# %%
test = pd.read_csv('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/test.csv')
sub = pd.read_csv('/content/drive/MyDrive/data/DACON_가스공급량_수요예측_모델개발/sample_submission.csv')
